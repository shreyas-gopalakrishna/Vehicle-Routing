# %%
# !pip3 install pulp==1.6.8
# Out:
# Requirement already satisfied: pulp==1.6.8 in /usr/local/lib/python3.6/dist-packages (1.6.8)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from pulp==1.6.8) (2.4.7)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance
import random
import pulp

# %%
# PuLP class for vehicle routing

class CVRP_SPD:
    def __init__(self, numberOfCustomers, numberOfVehicles, capacityOfVehicle, pickups, delivery, costMatrix):
        self.numberOfCustomers = numberOfCustomers
        self.numberOfVehicles  = numberOfVehicles
        self.capacityOfVehicle = capacityOfVehicle
        self.pickups = pickups
        self.delivery = delivery
        self.costMatrix        = costMatrix
        self.initializeLP()
    
    def initializeLP(self):
        self.cvrpLP = pulp.LpProblem("CVRP_PD", pulp.LpMinimize)
        objective = None
        x, y, z = [], [], []
        D, d = [], []
        P, p = [], []
        
        K = self.numberOfVehicles
        N = len(costMatrix)

        # create variables
        for i in range(N):
          xTemp1 = []
          for j in range(N):
            xTemp2 = []
            for k in range(K):
              xTemp3 = pulp.LpVariable('x('+str(i)+','+str(j)+','+str(k)+')', cat='Binary')
              xTemp2.append(xTemp3)
            xTemp1.append(xTemp2)
          x.append(xTemp1)
        
        for i in range(N):
          yTemp1 = []
          for j in range(N):
            yTemp2 = pulp.LpVariable('y('+str(i)+','+str(j)+')', lowBound=0, cat='Continuous')
            yTemp1.append(yTemp2)
          y.append(yTemp1)
        
        for i in range(N):
          zTemp1 = []
          for j in range(N):
            zTemp2 = pulp.LpVariable('z('+str(i)+','+str(j)+')', lowBound=0, cat='Continuous')
            zTemp1.append(zTemp2)
          z.append(zTemp1)
        

        # objective function
        for i in range(N):
          for j in range(N):
            for k in range(K):
            #   print(self.costMatrix[i][j])
            #   print(x[i][j][v])
              objective += self.costMatrix[i][j] * x[i][j][k]
        self.cvrpLP += objective

        #constraints

        #constraint-1
        for i in range(1, N):
          constraint1 = None
          for j in range(N):
            for k in range(K):
              constraint1 += x[i][j][k]
          self.cvrpLP += constraint1 == 1
        
        #constraint-2
        for k in range(K):
            for i in range(N):
                constraint2a, constraint2b = None, None
                for j in range(N):
                    constraint2a += x[i][j][k]
                    constraint2b += x[j][i][k]
                self.cvrpLP += constraint2a - constraint2b == 0
        
        #constraint-3
        for k in range(K):
          constraint3 = None
          for i in range(N):
            constraint3 += x[0][i][k]
          self.cvrpLP += constraint3 <= 1
        
        # constraint-4
        for i in range(N):
            for j in range(N):
                constraint4a = None
                for k in range(K):
                    constraint4a += x[i][j][k]
                self.cvrpLP += y[i][j] + z[i][j] <= self.capacityOfVehicle * constraint4a
        
        #constraint-5
        for i in range(1, N):
            constraint5a, constraint5b = None, None
            for j in range(N):
                constraint5a += y[i][j]
                constraint5b += y[j][i]
            self.cvrpLP += constraint5a - constraint5b == self.pickups[i]

        #constraint-6
        for i in range(1, N):
            constraint6a, constraint6b = None, None
            for j in range(N):
                constraint6a += z[j][i]
                constraint6b += z[i][j]
            self.cvrpLP += constraint6a - constraint6b == self.delivery[i]
        
        print(self.cvrpLP)

    def solve(self):
        status = self.cvrpLP.solve()#pulp.solvers.PULP_CBC_CMD(self.cvrpLP))
        print(pulp.LpStatus[self.cvrpLP.status])
    
    def getResult(self):
        print("Objective value: ", pulp.value(self.cvrpLP.objective))
        for v in self.cvrpLP.variables():
            print(v.name, " = ", v.varValue)

# %%
costMatrix = [[0,9,14,23,32,50,21,49,30,27,35,28,18],
[9,0,21,22,36,52,24,51,36,37,41,30,20],
[14,21,0,25,38,5,31,7,36,43,29,7,6],
[23,22,25,0,42,12,35,17,44,31,31,11,6],
[32,36,38,42,0,22,37,16,46,37,29,13,14],
[50,52,5,12,22,0,41,23,10,39,9,17,16],
[21,24,31,35,37,41,0,26,21,19,10,25,12],
[49,51,7,17,16,23,26,0,30,28,16,27,12],
[30,36,36,44,46,10,21,30,0,25,22,10,20],
[27,37,43,31,37,39,19,28,25,0,20,16,8],
[35,41,29,31,29,9,10,16,22,20,0,10,10],
[28,30,7,11,13,17,25,27,10,16,10,0,10],
[18,20, 6, 6,14,16,12,12,20,8, 10,10,0]]

delivery = [0, 1200, 1700, 1500, 1400, 1700, 1400, 1200, 1900, 1800, 1600, 1700, 1100]
pickups = [1100, 0, 1200, 1700, 1500, 1400, 1700, 1400, 1200, 1900, 1800, 1600, 1700]
capacityOfVehicle = 6000
numberOfVehicles = 4
numberOfCustomers = len(costMatrix) - 1

# %%
lp = CVRP_SPD(numberOfCustomers, numberOfVehicles, capacityOfVehicle, pickups, delivery, costMatrix)
lp.solve()
lp.getResult()
# Out:
# CVRP_PD:
# MINIMIZE
# 9*x(0,1,0) + 9*x(0,1,1) + 9*x(0,1,2) + 9*x(0,1,3) + 35*x(0,10,0) + 35*x(0,10,1) + 35*x(0,10,2) + 35*x(0,10,3) + 28*x(0,11,0) + 28*x(0,11,1) + 28*x(0,11,2) + 28*x(0,11,3) + 18*x(0,12,0) + 18*x(0,12,1) + 18*x(0,12,2) + 18*x(0,12,3) + 14*x(0,2,0) + 14*x(0,2,1) + 14*x(0,2,2) + 14*x(0,2,3) + 23*x(0,3,0) + 23*x(0,3,1) + 23*x(0,3,2) + 23*x(0,3,3) + 32*x(0,4,0) + 32*x(0,4,1) + 32*x(0,4,2) + 32*x(0,4,3) + 50*x(0,5,0) + 50*x(0,5,1) + 50*x(0,5,2) + 50*x(0,5,3) + 21*x(0,6,0) + 21*x(0,6,1) + 21*x(0,6,2) + 21*x(0,6,3) + 49*x(0,7,0) + 49*x(0,7,1) + 49*x(0,7,2) + 49*x(0,7,3) + 30*x(0,8,0) + 30*x(0,8,1) + 30*x(0,8,2) + 30*x(0,8,3) + 27*x(0,9,0) + 27*x(0,9,1) + 27*x(0,9,2) + 27*x(0,9,3) + 9*x(1,0,0) + 9*x(1,0,1) + 9*x(1,0,2) + 9*x(1,0,3) + 41*x(1,10,0) + 41*x(1,10,1) + 41*x(1,10,2) + 41*x(1,10,3) + 30*x(1,11,0) + 30*x(1,11,1) + 30*x(1,11,2) + 30*x(1,11,3) + 20*x(1,12,0) + 20*x(1,12,1) + 20*x(1,12,2) + 20*x(1,12,3) + 21*x(1,2,0) + 21*x(1,2,1) + 21*x(1,2,2) + 21*x(1,2,3) + 22*x(1,3,0) + 22*x(1,3,1) + 22*x(1,3,2) + 22*x(1,3,3) + 36*x(1,4,0) + 36*x(1,4,1) + 36*x(1,4,2) + 36*x(1,4,3) + 52*x(1,5,0) + 52*x(1,5,1) + 52*x(1,5,2) + 52*x(1,5,3) + 24*x(1,6,0) + 24*x(1,6,1) + 24*x(1,6,2) + 24*x(1,6,3) + 51*x(1,7,0) + 51*x(1,7,1) + 51*x(1,7,2) + 51*x(1,7,3) + 36*x(1,8,0) + 36*x(1,8,1) + 36*x(1,8,2) + 36*x(1,8,3) + 37*x(1,9,0) + 37*x(1,9,1) + 37*x(1,9,2) + 37*x(1,9,3) + 35*x(10,0,0) + 35*x(10,0,1) + 35*x(10,0,2) + 35*x(10,0,3) + 41*x(10,1,0) + 41*x(10,1,1) + 41*x(10,1,2) + 41*x(10,1,3) + 10*x(10,11,0) + 10*x(10,11,1) + 10*x(10,11,2) + 10*x(10,11,3) + 10*x(10,12,0) + 10*x(10,12,1) + 10*x(10,12,2) + 10*x(10,12,3) + 29*x(10,2,0) + 29*x(10,2,1) + 29*x(10,2,2) + 29*x(10,2,3) + 31*x(10,3,0) + 31*x(10,3,1) + 31*x(10,3,2) + 31*x(10,3,3) + 29*x(10,4,0) + 29*x(10,4,1) + 29*x(10,4,2) + 29*x(10,4,3) + 9*x(10,5,0) + 9*x(10,5,1) + 9*x(10,5,2) + 9*x(10,5,3) + 10*x(10,6,0) + 10*x(10,6,1) + 10*x(10,6,2) + 10*x(10,6,3) + 16*x(10,7,0) + 16*x(10,7,1) + 16*x(10,7,2) + 16*x(10,7,3) + 22*x(10,8,0) + 22*x(10,8,1) + 22*x(10,8,2) + 22*x(10,8,3) + 20*x(10,9,0) + 20*x(10,9,1) + 20*x(10,9,2) + 20*x(10,9,3) + 28*x(11,0,0) + 28*x(11,0,1) + 28*x(11,0,2) + 28*x(11,0,3) + 30*x(11,1,0) + 30*x(11,1,1) + 30*x(11,1,2) + 30*x(11,1,3) + 10*x(11,10,0) + 10*x(11,10,1) + 10*x(11,10,2) + 10*x(11,10,3) + 10*x(11,12,0) + 10*x(11,12,1) + 10*x(11,12,2) + 10*x(11,12,3) + 7*x(11,2,0) + 7*x(11,2,1) + 7*x(11,2,2) + 7*x(11,2,3) + 11*x(11,3,0) + 11*x(11,3,1) + 11*x(11,3,2) + 11*x(11,3,3) + 13*x(11,4,0) + 13*x(11,4,1) + 13*x(11,4,2) + 13*x(11,4,3) + 17*x(11,5,0) + 17*x(11,5,1) + 17*x(11,5,2) + 17*x(11,5,3) + 25*x(11,6,0) + 25*x(11,6,1) + 25*x(11,6,2) + 25*x(11,6,3) + 27*x(11,7,0) + 27*x(11,7,1) + 27*x(11,7,2) + 27*x(11,7,3) + 10*x(11,8,0) + 10*x(11,8,1) + 10*x(11,8,2) + 10*x(11,8,3) + 16*x(11,9,0) + 16*x(11,9,1) + 16*x(11,9,2) + 16*x(11,9,3) + 18*x(12,0,0) + 18*x(12,0,1) + 18*x(12,0,2) + 18*x(12,0,3) + 20*x(12,1,0) + 20*x(12,1,1) + 20*x(12,1,2) + 20*x(12,1,3) + 10*x(12,10,0) + 10*x(12,10,1) + 10*x(12,10,2) + 10*x(12,10,3) + 10*x(12,11,0) + 10*x(12,11,1) + 10*x(12,11,2) + 10*x(12,11,3) + 6*x(12,2,0) + 6*x(12,2,1) + 6*x(12,2,2) + 6*x(12,2,3) + 6*x(12,3,0) + 6*x(12,3,1) + 6*x(12,3,2) + 6*x(12,3,3) + 14*x(12,4,0) + 14*x(12,4,1) + 14*x(12,4,2) + 14*x(12,4,3) + 16*x(12,5,0) + 16*x(12,5,1) + 16*x(12,5,2) + 16*x(12,5,3) + 12*x(12,6,0) + 12*x(12,6,1) + 12*x(12,6,2) + 12*x(12,6,3) + 12*x(12,7,0) + 12*x(12,7,1) + 12*x(12,7,2) + 12*x(12,7,3) + 20*x(12,8,0) + 20*x(12,8,1) + 20*x(12,8,2) + 20*x(12,8,3) + 8*x(12,9,0) + 8*x(12,9,1) + 8*x(12,9,2) + 8*x(12,9,3) + 14*x(2,0,0) + 14*x(2,0,1) + 14*x(2,0,2) + 14*x(2,0,3) + 21*x(2,1,0) + 21*x(2,1,1) + 21*x(2,1,2) + 21*x(2,1,3) + 29*x(2,10,0) + 29*x(2,10,1) + 29*x(2,10,2) + 29*x(2,10,3) + 7*x(2,11,0) + 7*x(2,11,1) + 7*x(2,11,2) + 7*x(2,11,3) + 6*x(2,12,0) + 6*x(2,12,1) + 6*x(2,12,2) + 6*x(2,12,3) + 25*x(2,3,0) + 25*x(2,3,1) + 25*x(2,3,2) + 25*x(2,3,3) + 38*x(2,4,0) + 38*x(2,4,1) + 38*x(2,4,2) + 38*x(2,4,3) + 5*x(2,5,0) + 5*x(2,5,1) + 5*x(2,5,2) + 5*x(2,5,3) + 31*x(2,6,0) + 31*x(2,6,1) +  ...
# SUBJECT TO
# _C1: x(1,0,0) + x(1,0,1) + x(1,0,2) + x(1,0,3) + x(1,1,0) + x(1,1,1)
#  + x(1,1,2) + x(1,1,3) + x(1,10,0) + x(1,10,1) + x(1,10,2) + x(1,10,3)
#  + x(1,11,0) + x(1,11,1) + x(1,11,2) + x(1,11,3) + x(1,12,0) + x(1,12,1)
#  + x(1,12,2) + x(1,12,3) + x(1,2,0) + x(1,2,1) + x(1,2,2) + x(1,2,3)
#  + x(1,3,0) + x(1,3,1) + x(1,3,2) + x(1,3,3) + x(1,4,0) + x(1,4,1) + x(1,4,2)
#  + x(1,4,3) + x(1,5,0) + x(1,5,1) + x(1,5,2) + x(1,5,3) + x(1,6,0) + x(1,6,1)
#  + x(1,6,2) + x(1,6,3) + x(1,7,0) + x(1,7,1) + x(1,7,2) + x(1,7,3) + x(1,8,0)
#  + x(1,8,1) + x(1,8,2) + x(1,8,3) + x(1,9,0) + x(1,9,1) + x(1,9,2) + x(1,9,3)
#  = 1
#
# _C2: x(2,0,0) + x(2,0,1) + x(2,0,2) + x(2,0,3) + x(2,1,0) + x(2,1,1)
#  + x(2,1,2) + x(2,1,3) + x(2,10,0) + x(2,10,1) + x(2,10,2) + x(2,10,3)
#  + x(2,11,0) + x(2,11,1) + x(2,11,2) + x(2,11,3) + x(2,12,0) + x(2,12,1)
#  + x(2,12,2) + x(2,12,3) + x(2,2,0) + x(2,2,1) + x(2,2,2) + x(2,2,3)
#  + x(2,3,0) + x(2,3,1) + x(2,3,2) + x(2,3,3) + x(2,4,0) + x(2,4,1) + x(2,4,2)
#  + x(2,4,3) + x(2,5,0) + x(2,5,1) + x(2,5,2) + x(2,5,3) + x(2,6,0) + x(2,6,1)
#  + x(2,6,2) + x(2,6,3) + x(2,7,0) + x(2,7,1) + x(2,7,2) + x(2,7,3) + x(2,8,0)
#  + x(2,8,1) + x(2,8,2) + x(2,8,3) + x(2,9,0) + x(2,9,1) + x(2,9,2) + x(2,9,3)
#  = 1
#
# _C3: x(3,0,0) + x(3,0,1) + x(3,0,2) + x(3,0,3) + x(3,1,0) + x(3,1,1)
#  + x(3,1,2) + x(3,1,3) + x(3,10,0) + x(3,10,1) + x(3,10,2) + x(3,10,3)
#  + x(3,11,0) + x(3,11,1) + x(3,11,2) + x(3,11,3) + x(3,12,0) + x(3,12,1)
#  + x(3,12,2) + x(3,12,3) + x(3,2,0) + x(3,2,1) + x(3,2,2) + x(3,2,3)
#  + x(3,3,0) + x(3,3,1) + x(3,3,2) + x(3,3,3) + x(3,4,0) + x(3,4,1) + x(3,4,2)
#  + x(3,4,3) + x(3,5,0) + x(3,5,1) + x(3,5,2) + x(3,5,3) + x(3,6,0) + x(3,6,1)
#  + x(3,6,2) + x(3,6,3) + x(3,7,0) + x(3,7,1) + x(3,7,2) + x(3,7,3) + x(3,8,0)
#  + x(3,8,1) + x(3,8,2) + x(3,8,3) + x(3,9,0) + x(3,9,1) + x(3,9,2) + x(3,9,3)
#  = 1
#
# _C4: x(4,0,0) + x(4,0,1) + x(4,0,2) + x(4,0,3) + x(4,1,0) + x(4,1,1)
#  + x(4,1,2) + x(4,1,3) + x(4,10,0) + x(4,10,1) + x(4,10,2) + x(4,10,3)
#  + x(4,11,0) + x(4,11,1) + x(4,11,2) + x(4,11,3) + x(4,12,0) + x(4,12,1)
#  + x(4,12,2) + x(4,12,3) + x(4,2,0) + x(4,2,1) + x(4,2,2) + x(4,2,3)
#  + x(4,3,0) + x(4,3,1) + x(4,3,2) + x(4,3,3) + x(4,4,0) + x(4,4,1) + x(4,4,2)
#  + x(4,4,3) + x(4,5,0) + x(4,5,1) + x(4,5,2) + x(4,5,3) + x(4,6,0) + x(4,6,1)
#  + x(4,6,2) + x(4,6,3) + x(4,7,0) + x(4,7,1) + x(4,7,2) + x(4,7,3) + x(4,8,0)
#  + x(4,8,1) + x(4,8,2) + x(4,8,3) + x(4,9,0) + x(4,9,1) + x(4,9,2) + x(4,9,3)
#  = 1
#
# _C5: x(5,0,0) + x(5,0,1) + x(5,0,2) + x(5,0,3) + x(5,1,0) + x(5,1,1)
#  + x(5,1,2) + x(5,1,3) + x(5,10,0) + x(5,10,1) + x(5,10,2) + x(5,10,3)
#  + x(5,11,0) + x(5,11,1) + x(5,11,2) + x(5,11,3) + x(5,12,0) + x(5,12,1)
#  + x(5,12,2) + x(5,12,3) + x(5,2,0) + x(5,2,1) + x(5,2,2) + x(5,2,3)
#  + x(5,3,0) + x(5,3,1) + x(5,3,2) + x(5,3,3) + x(5,4,0) + x(5,4,1) + x(5,4,2)
#  + x(5,4,3) + x(5,5,0) + x(5,5,1) + x(5,5,2) + x(5,5,3) + x(5,6,0) + x(5,6,1)
#  + x(5,6,2) + x(5,6,3) + x(5,7,0) + x(5,7,1) + x(5,7,2) + x(5,7,3) + x(5,8,0)
#  + x(5,8,1) + x(5,8,2) + x(5,8,3) + x(5,9,0) + x(5,9,1) + x(5,9,2) + x(5,9,3)
#  = 1
#
# _C6: x(6,0,0) + x(6,0,1) + x(6,0,2) + x(6,0,3) + x(6,1,0) + x(6,1,1)
#  + x(6,1,2) + x(6,1,3) + x(6,10,0) + x(6,10,1) + x(6,10,2) + x(6,10,3)
#  + x(6,11,0) + x(6,11,1) + x(6,11,2) + x(6,11,3) + x(6,12,0) + x(6,12,1)
#  + x(6,12,2) + x(6,12,3) + x(6,2,0) + x(6,2,1) + x(6,2,2) + x(6,2,3)
#  + x(6,3,0) + x(6,3,1) + x(6,3,2) + x(6,3,3) + x(6,4,0) + x(6,4,1) + x(6,4,2)
#  + x(6,4,3) + x(6,5,0) + x(6,5,1) + x(6,5,2) + x(6,5,3) + x(6,6,0) + x(6,6,1)
#  + x(6,6,2) + x(6,6,3) + x(6,7,0) + x(6,7,1) + x(6,7,2) + x(6,7,3) + x(6,8,0)
#  + x(6,8,1) + x(6,8,2) + x(6,8,3) + x(6,9,0) + x(6,9,1) + x(6,9,2) + x(6,9,3)
#  = 1
#
# _C7: x(7,0,0) + x(7,0,1) + x(7,0,2) + x(7,0,3) + x(7,1,0) + x(7,1,1)
#  + x(7,1,2) + x(7,1,3) + x(7,10,0) + x(7,10,1) + x(7,10,2) + x(7,10,3)
#  + x(7,11,0) + x(7,11,1) + x(7,11,2) + x(7,11,3) + x(7,12,0) + x(7,12,1)
#  + x(7,12,2) + x(7,12,3) + x(7,2,0) + x(7,2,1) + x(7,2,2) + x(7,2,3)
#  + x(7,3,0) + x(7,3,1) + x(7,3,2) + x(7,3,3) + x(7,4,0) + x(7,4,1) + x(7,4,2)
#  + x(7,4,3) + x(7,5,0) + x(7,5,1) + x(7,5,2) + x(7,5,3) + x(7,6,0) + x(7,6,1)
#  + x(7,6,2) + x(7,6,3) + x(7,7,0) + x(7,7,1) + x(7,7,2) + x(7,7,3) + x(7,8,0)
#  + x(7,8,1) + x(7,8,2) + x(7,8,3) + x(7,9,0) + x(7,9,1) + x(7,9,2) + x(7,9,3)
#  = 1
#
# _C8: x(8,0,0) + x(8,0,1) + x(8,0,2) + x(8,0,3) + x(8,1,0) + x(8,1,1)
#  + x(8,1,2) + x(8,1,3) + x(8,10,0) + x(8,10,1) + x(8,10,2) + x(8,10,3)
#  + x(8,11,0) + x(8,11,1) + x(8,11,2) + x(8,11,3) + x(8,12,0) + x(8,12,1)
#  + x(8,12,2) + x(8,12,3) + x(8,2,0) + x(8,2,1) + x(8,2,2) + x(8,2,3)
#  + x(8,3,0) + x(8,3,1) + x(8,3,2) + x(8,3,3) + x(8,4,0) + x(8,4,1) + x(8,4,2)
#  + x(8,4,3) + x(8,5,0) + x(8,5,1) + x(8,5,2) + x(8,5,3) + x(8,6,0) + x(8,6,1)
#  + x(8,6,2) + x(8,6,3) + x(8,7,0) + x(8,7,1) + x(8,7,2) + x(8,7,3) + x(8,8,0)
#  + x(8,8,1) + x(8,8,2) + x(8,8,3) + x(8,9,0) + x(8,9,1) + x(8,9,2) + x(8,9,3)
#  = 1
#
# _C9: x(9,0,0) + x(9,0,1) + x(9,0,2) + x(9,0,3) + x(9,1,0) + x(9,1,1)
#  + x(9,1,2) + x(9,1,3) + x(9,10,0) + x(9,10,1) + x(9,10,2) + x(9,10,3)
#  + x(9,11,0) + x(9,11,1) + x(9,11,2) + x(9,11,3) + x(9,12,0) + x(9,12,1)
#  + x(9,12,2) + x(9,12,3) + x(9,2,0) + x(9,2,1) + x(9,2,2) + x(9,2,3)
#  + x(9,3,0) + x(9,3,1) + x(9,3,2) + x(9,3,3) + x(9,4,0) + x(9,4,1) + x(9,4,2)
#  + x(9,4,3) + x(9,5,0) + x(9,5,1) + x(9,5,2) + x(9,5,3) + x(9,6,0) + x(9,6,1)
#  + x(9,6,2) + x(9,6,3) + x(9,7,0) + x(9,7,1) + x(9,7,2) + x(9,7,3) + x(9,8,0)
#  + x(9,8,1) + x(9,8,2) + x(9,8,3) + x(9,9,0) + x(9,9,1) + x(9,9,2) + x(9,9,3)
#  = 1
#
# _C10: x(10,0,0) + x(10,0,1) + x(10,0,2) + x(10,0,3) + x(10,1,0) + x(10,1,1)
#  + x(10,1,2) + x(10,1,3) + x(10,10,0) + x(10,10,1) + x(10,10,2) + x(10,10,3)
#  + x(10,11,0) + x(10,11,1) + x(10,11,2) + x(10,11,3) + x(10,12,0) + x(10,12,1)
#  + x(10,12,2) + x(10,12,3) + x(10,2,0) + x(10,2,1) + x(10,2,2) + x(10,2,3)
#  + x(10,3,0) + x(10,3,1) + x(10,3,2) + x(10,3,3) + x(10,4,0) + x(10,4,1)
#  + x(10,4,2) + x(10,4,3) + x(10,5,0) + x(10,5,1) + x(10,5,2) + x(10,5,3)
#  + x(10,6,0) + x(10,6,1) + x(10,6,2) + x(10,6,3) + x(10,7,0) + x(10,7,1)
#  + x(10,7,2) + x(10,7,3) + x(10,8,0) + x(10,8,1) + x(10,8,2) + x(10,8,3)
#  + x(10,9,0) + x(10,9,1) + x(10,9,2) + x(10,9,3) = 1
#
# _C11: x(11,0,0) + x(11,0,1) + x(11,0,2) + x(11,0,3) + x(11,1,0) + x(11,1,1)
#  + x(11,1,2) + x(11,1,3) + x(11,10,0) + x(11,10,1) + x(11,10,2) + x(11,10,3)
#  + x(11,11,0) + x(11,11,1) + x(11,11,2) + x(11,11,3) + x(11,12,0) + x(11,12,1)
#  + x(11,12,2) + x(11,12,3) + x(11,2,0) + x(11,2,1) + x(11,2,2) + x(11,2,3)
#  + x(11,3,0) + x(11,3,1) + x(11,3,2) + x(11,3,3) + x(11,4,0) + x(11,4,1)
#  + x(11,4,2) + x(11,4,3) + x(11,5,0) + x(11,5,1) + x(11,5,2) + x(11,5,3)
#  + x(11,6,0) + x(11,6,1) + x(11,6,2) + x(11,6,3) + x(11,7,0) + x(11,7,1)
#  + x(11,7,2) + x(11,7,3) + x(11,8,0) + x(11,8,1) + x(11,8,2) + x(11,8,3)
#  + x(11,9,0) + x(11,9,1) + x(11,9,2) + x(11,9,3) = 1
#
# _C12: x(12,0,0) + x(12,0,1) + x(12,0,2) + x(12,0,3) + x(12,1,0) + x(12,1,1)
#  + x(12,1,2) + x(12,1,3) + x(12,10,0) + x(12,10,1) + x(12,10,2) + x(12,10,3)
#  + x(12,11,0) + x(12,11,1) + x(12,11,2) + x(12,11,3) + x(12,12,0) + x(12,12,1)
#  + x(12,12,2) + x(12,12,3) + x(12,2,0) + x(12,2,1) + x(12,2,2) + x(12,2,3)
#  + x(12,3,0) + x(12,3,1) + x(12,3,2) + x(12,3,3) + x(12,4,0) + x(12,4,1)
#  + x(12,4,2) + x(12,4,3) + x(12,5,0) + x(12,5,1) + x(12,5,2) + x(12,5,3)
#  + x(12,6,0) + x(12,6,1) + x(12,6,2) + x(12,6,3) + x(12,7,0) + x(12,7,1)
#  + x(12,7,2) + x(12,7,3) + x(12,8,0) + x(12,8,1) + x(12,8,2) + x(12,8,3)
#  + x(12,9,0) + x(12,9,1) + x(12,9,2) + x(12,9,3) = 1
#
# _C13: 0 x(0,0,0) + x(0,1,0) + x(0,10,0) + x(0,11,0) + x(0,12,0) + x(0,2,0)
#  + x(0,3,0) + x(0,4,0) + x(0,5,0) + x(0,6,0) + x(0,7,0) + x(0,8,0) + x(0,9,0)
#  - x(1,0,0) - x(10,0,0) - x(11,0,0) - x(12,0,0) - x(2,0,0) - x(3,0,0)
#  - x(4,0,0) - x(5,0,0) - x(6,0,0) - x(7,0,0) - x(8,0,0) - x(9,0,0) = 0
#
# _C14: - x(0,1,0) + x(1,0,0) + 0 x(1,1,0) + x(1,10,0) + x(1,11,0) + x(1,12,0)
#  + x(1,2,0) + x(1,3,0) + x(1,4,0) + x(1,5,0) + x(1,6,0) + x(1,7,0) + x(1,8,0)
#  + x(1,9,0) - x(10,1,0) - x(11,1,0) - x(12,1,0) - x(2,1,0) - x(3,1,0)
#  - x(4,1,0) - x(5,1,0) - x(6,1,0) - x(7,1,0) - x(8,1,0) - x(9,1,0) = 0
#
# _C15: - x(0,2,0) - x(1,2,0) - x(10,2,0) - x(11,2,0) - x(12,2,0) + x(2,0,0)
#  + x(2,1,0) + x(2,10,0) + x(2,11,0) + x(2,12,0) + 0 x(2,2,0) + x(2,3,0)
#  + x(2,4,0) + x(2,5,0) + x(2,6,0) + x(2,7,0) + x(2,8,0) + x(2,9,0) - x(3,2,0)
#  - x(4,2,0) - x(5,2,0) - x(6,2,0) - x(7,2,0) - x(8,2,0) - x(9,2,0) = 0
#
# _C16: - x(0,3,0) - x(1,3,0) - x(10,3,0) - x(11,3,0) - x(12,3,0) - x(2,3,0)
#  + x(3,0,0) + x(3,1,0) + x(3,10,0) + x(3,11,0) + x(3,12,0) + x(3,2,0)
#  + 0 x(3,3,0) + x(3,4,0) + x(3,5,0) + x(3,6,0) + x(3,7,0) + x(3,8,0)
#  + x(3,9,0) - x(4,3,0) - x(5,3,0) - x(6,3,0) - x(7,3,0) - x(8,3,0) - x(9,3,0)
#  = 0
#
# _C17: - x(0,4,0) - x(1,4,0) - x(10,4,0) - x(11,4,0) - x(12,4,0) - x(2,4,0)
#  - x(3,4,0) + x(4,0,0) + x(4,1,0) + x(4,10,0) + x(4,11,0) + x(4,12,0)
#  + x(4,2,0) + x(4,3,0) + 0 x(4,4,0) + x(4,5,0) + x(4,6,0) + x(4,7,0)
#  + x(4,8,0) + x(4,9,0) - x(5,4,0) - x(6,4,0) - x(7,4,0) - x(8,4,0) - x(9,4,0)
#  = 0
#
# _C18: - x(0,5,0) - x(1,5,0) - x(10,5,0) - x(11,5,0) - x(12,5,0) - x(2,5,0)
#  - x(3,5,0) - x(4,5,0) + x(5,0,0) + x(5,1,0) + x(5,10,0) + x(5,11,0)
#  + x(5,12,0) + x(5,2,0) + x(5,3,0) + x(5,4,0) + 0 x(5,5,0) + x(5,6,0)
#  + x(5,7,0) + x(5,8,0) + x(5,9,0) - x(6,5,0) - x(7,5,0) - x(8,5,0) - x(9,5,0)
#  = 0
#
# _C19: - x(0,6,0) - x(1,6,0) - x(10,6,0) - x(11,6,0) - x(12,6,0) - x(2,6,0)
#  - x(3,6,0) - x(4,6,0) - x(5,6,0) + x(6,0,0) + x(6,1,0) + x(6,10,0)
#  + x(6,11,0) + x(6,12,0) + x(6,2,0) + x(6,3,0) + x(6,4,0) + x(6,5,0)
#  + 0 x(6,6,0) + x(6,7,0) + x(6,8,0) + x(6,9,0) - x(7,6,0) - x(8,6,0)
#  - x(9,6,0) = 0
#
# _C20: - x(0,7,0) - x(1,7,0) - x(10,7,0) - x(11,7,0) - x(12,7,0) - x(2,7,0)
#  - x(3,7,0) - x(4,7,0) - x(5,7,0) - x(6,7,0) + x(7,0,0) + x(7,1,0) + x(7,10,0)
#  + x(7,11,0) + x(7,12,0) + x(7,2,0) + x(7,3,0) + x(7,4,0) + x(7,5,0)
#  + x(7,6,0) + 0 x(7,7,0) + x(7,8,0) + x(7,9,0) - x(8,7,0) - x(9,7,0) = 0
#
# _C21: - x(0,8,0) - x(1,8,0) - x(10,8,0) - x(11,8,0) - x(12,8,0) - x(2,8,0)
#  - x(3,8,0) - x(4,8,0) - x(5,8,0) - x(6,8,0) - x(7,8,0) + x(8,0,0) + x(8,1,0)
#  + x(8,10,0) + x(8,11,0) + x(8,12,0) + x(8,2,0) + x(8,3,0) + x(8,4,0)
#  + x(8,5,0) + x(8,6,0) + x(8,7,0) + 0 x(8,8,0) + x(8,9,0) - x(9,8,0) = 0
#
# _C22: - x(0,9,0) - x(1,9,0) - x(10,9,0) - x(11,9,0) - x(12,9,0) - x(2,9,0)
#  - x(3,9,0) - x(4,9,0) - x(5,9,0) - x(6,9,0) - x(7,9,0) - x(8,9,0) + x(9,0,0)
#  + x(9,1,0) + x(9,10,0) + x(9,11,0) + x(9,12,0) + x(9,2,0) + x(9,3,0)
#  + x(9,4,0) + x(9,5,0) + x(9,6,0) + x(9,7,0) + x(9,8,0) + 0 x(9,9,0) = 0
#
# _C23: - x(0,10,0) - x(1,10,0) + x(10,0,0) + x(10,1,0) + 0 x(10,10,0)
#  + x(10,11,0) + x(10,12,0) + x(10,2,0) + x(10,3,0) + x(10,4,0) + x(10,5,0)
#  + x(10,6,0) + x(10,7,0) + x(10,8,0) + x(10,9,0) - x(11,10,0) - x(12,10,0)
#  - x(2,10,0) - x(3,10,0) - x(4,10,0) - x(5,10,0) - x(6,10,0) - x(7,10,0)
#  - x(8,10,0) - x(9,10,0) = 0
#
# _C24: - x(0,11,0) - x(1,11,0) - x(10,11,0) + x(11,0,0) + x(11,1,0)
#  + x(11,10,0) + 0 x(11,11,0) + x(11,12,0) + x(11,2,0) + x(11,3,0) + x(11,4,0)
#  + x(11,5,0) + x(11,6,0) + x(11,7,0) + x(11,8,0) + x(11,9,0) - x(12,11,0)
#  - x(2,11,0) - x(3,11,0) - x(4,11,0) - x(5,11,0) - x(6,11,0) - x(7,11,0)
#  - x(8,11,0) - x(9,11,0) = 0
#
# _C25: - x(0,12,0) - x(1,12,0) - x(10,12,0) - x(11,12,0) + x(12,0,0)
#  + x(12,1,0) + x(12,10,0) + x(12,11,0) + 0 x(12,12,0) + x(12,2,0) + x(12,3,0)
#  + x(12,4,0) + x(12,5,0) + x(12,6,0) + x(12,7,0) + x(12,8,0) + x(12,9,0)
#  - x(2,12,0) - x(3,12,0) - x(4,12,0) - x(5,12,0) - x(6,12,0) - x(7,12,0)
#  - x(8,12,0) - x(9,12,0) = 0
#
# _C26: 0 x(0,0,1) + x(0,1,1) + x(0,10,1) + x(0,11,1) + x(0,12,1) + x(0,2,1)
#  + x(0,3,1) + x(0,4,1) + x(0,5,1) + x(0,6,1) + x(0,7,1) + x(0,8,1) + x(0,9,1)
#  - x(1,0,1) - x(10,0,1) - x(11,0,1) - x(12,0,1) - x(2,0,1) - x(3,0,1)
#  - x(4,0,1) - x(5,0,1) - x(6,0,1) - x(7,0,1) - x(8,0,1) - x(9,0,1) = 0
#
# _C27: - x(0,1,1) + x(1,0,1) + 0 x(1,1,1) + x(1,10,1) + x(1,11,1) + x(1,12,1)
#  + x(1,2,1) + x(1,3,1) + x(1,4,1) + x(1,5,1) + x(1,6,1) + x(1,7,1) + x(1,8,1)
#  + x(1,9,1) - x(10,1,1) - x(11,1,1) - x(12,1,1) - x(2,1,1) - x(3,1,1)
#  - x(4,1,1) - x(5,1,1) - x(6,1,1) - x(7,1,1) - x(8,1,1) - x(9,1,1) = 0
#
# _C28: - x(0,2,1) - x(1,2,1) - x(10,2,1) - x(11,2,1) - x(12,2,1) + x(2,0,1)
#  + x(2,1,1) + x(2,10,1) + x(2,11,1) + x(2,12,1) + 0 x(2,2,1) + x(2,3,1)
#  + x(2,4,1) + x(2,5,1) + x(2,6,1) + x(2,7,1) + x(2,8,1) + x(2,9,1) - x(3,2,1)
#  - x(4,2,1) - x(5,2,1) - x(6,2,1) - x(7,2,1) - x(8,2,1) - x(9,2,1) = 0
#
# _C29: - x(0,3,1) - x(1,3,1) - x(10,3,1) - x(11,3,1) - x(12,3,1) - x(2,3,1)
#  + x(3,0,1) + x(3,1,1) + x(3,10,1) + x(3,11,1) + x(3,12,1) + x(3,2,1)
#  + 0 x(3,3,1) + x(3,4,1) + x(3,5,1) + x(3,6,1) + x(3,7,1) + x(3,8,1)
#  + x(3,9,1) - x(4,3,1) - x(5,3,1) - x(6,3,1) - x(7,3,1) - x(8,3,1) - x(9,3,1)
#  = 0
#
# _C30: - x(0,4,1) - x(1,4,1) - x(10,4,1) - x(11,4,1) - x(12,4,1) - x(2,4,1)
#  - x(3,4,1) + x(4,0,1) + x(4,1,1) + x(4,10,1) + x(4,11,1) + x(4,12,1)
#  + x(4,2,1) + x(4,3,1) + 0 x(4,4,1) + x(4,5,1) + x(4,6,1) + x(4,7,1)
#  + x(4,8,1) + x(4,9,1) - x(5,4,1) - x(6,4,1) - x(7,4,1) - x(8,4,1) - x(9,4,1)
#  = 0
#
# _C31: - x(0,5,1) - x(1,5,1) - x(10,5,1) - x(11,5,1) - x(12,5,1) - x(2,5,1)
#  - x(3,5,1) - x(4,5,1) + x(5,0,1) + x(5,1,1) + x(5,10,1) + x(5,11,1)
#  + x(5,12,1) + x(5,2,1) + x(5,3,1) + x(5,4,1) + 0 x(5,5,1) + x(5,6,1)
#  + x(5,7,1) + x(5,8,1) + x(5,9,1) - x(6,5,1) - x(7,5,1) - x(8,5,1) - x(9,5,1)
#  = 0
#
# _C32: - x(0,6,1) - x(1,6,1) - x(10,6,1) - x(11,6,1) - x(12,6,1) - x(2,6,1)
#  - x(3,6,1) - x(4,6,1) - x(5,6,1) + x(6,0,1) + x(6,1,1) + x(6,10,1)
#  + x(6,11,1) + x(6,12,1) + x(6,2,1) + x(6,3,1) + x(6,4,1) + x(6,5,1)
#  + 0 x(6,6,1) + x(6,7,1) + x(6,8,1) + x(6,9,1) - x(7,6,1) - x(8,6,1)
#  - x(9,6,1) = 0
#
# _C33: - x(0,7,1) - x(1,7,1) - x(10,7,1) - x(11,7,1) - x(12,7,1) - x(2,7,1)
#  - x(3,7,1) - x(4,7,1) - x(5,7,1) - x(6,7,1) + x(7,0,1) + x(7,1,1) + x(7,10,1)
#  + x(7,11,1) + x(7,12,1) + x(7,2,1) + x(7,3,1) + x(7,4,1) + x(7,5,1)
#  + x(7,6,1) + 0 x(7,7,1) + x(7,8,1) + x(7,9,1) - x(8,7,1) - x(9,7,1) = 0
#
# _C34: - x(0,8,1) - x(1,8,1) - x(10,8,1) - x(11,8,1) - x(12,8,1) - x(2,8,1)
#  - x(3,8,1) - x(4,8,1) - x(5,8,1) - x(6,8,1) - x(7,8,1) + x(8,0,1) + x(8,1,1)
#  + x(8,10,1) + x(8,11,1) + x(8,12,1) + x(8,2,1) + x(8,3,1) + x(8,4,1)
#  + x(8,5,1) + x(8,6,1) + x(8,7,1) + 0 x(8,8,1) + x(8,9,1) - x(9,8,1) = 0
#
# _C35: - x(0,9,1) - x(1,9,1) - x(10,9,1) - x(11,9,1) - x(12,9,1) - x(2,9,1)
#  - x(3,9,1) - x(4,9,1) - x(5,9,1) - x(6,9,1) - x(7,9,1) - x(8,9,1) + x(9,0,1)
#  + x(9,1,1) + x(9,10,1) + x(9,11,1) + x(9,12,1) + x(9,2,1) + x(9,3,1)
#  + x(9,4,1) + x(9,5,1) + x(9,6,1) + x(9,7,1) + x(9,8,1) + 0 x(9,9,1) = 0
#
# _C36: - x(0,10,1) - x(1,10,1) + x(10,0,1) + x(10,1,1) + 0 x(10,10,1)
#  + x(10,11,1) + x(10,12,1) + x(10,2,1) + x(10,3,1) + x(10,4,1) + x(10,5,1)
#  + x(10,6,1) + x(10,7,1) + x(10,8,1) + x(10,9,1) - x(11,10,1) - x(12,10,1)
#  - x(2,10,1) - x(3,10,1) - x(4,10,1) - x(5,10,1) - x(6,10,1) - x(7,10,1)
#  - x(8,10,1) - x(9,10,1) = 0
#
# _C37: - x(0,11,1) - x(1,11,1) - x(10,11,1) + x(11,0,1) + x(11,1,1)
#  + x(11,10,1) + 0 x(11,11,1) + x(11,12,1) + x(11,2,1) + x(11,3,1) + x(11,4,1)
#  + x(11,5,1) + x(11,6,1) + x(11,7,1) + x(11,8,1) + x(11,9,1) - x(12,11,1)
#  - x(2,11,1) - x(3,11,1) - x(4,11,1) - x(5,11,1) - x(6,11,1) - x(7,11,1)
#  - x(8,11,1) - x(9,11,1) = 0
#
# _C38: - x(0,12,1) - x(1,12,1) - x(10,12,1) - x(11,12,1) + x(12,0,1)
#  + x(12,1,1) + x(12,10,1) + x(12,11,1) + 0 x(12,12,1) + x(12,2,1) + x(12,3,1)
#  + x(12,4,1) + x(12,5,1) + x(12,6,1) + x(12,7,1) + x(12,8,1) + x(12,9,1)
#  - x(2,12,1) - x(3,12,1) - x(4,12,1) - x(5,12,1) - x(6,12,1) - x(7,12,1)
#  - x(8,12,1) - x(9,12,1) = 0
#
# _C39: 0 x(0,0,2) + x(0,1,2) + x(0,10,2) + x(0,11,2) + x(0,12,2) + x(0,2,2)
#  + x(0,3,2) + x(0,4,2) + x(0,5,2) + x(0,6,2) + x(0,7,2) + x(0,8,2) + x(0,9,2)
#  - x(1,0,2) - x(10,0,2) - x(11,0,2) - x(12,0,2) - x(2,0,2) - x(3,0,2)
#  - x(4,0,2) - x(5,0,2) - x(6,0,2) - x(7,0,2) - x(8,0,2) - x(9,0,2) = 0
#
# _C40: - x(0,1,2) + x(1,0,2) + 0 x(1,1,2) + x(1,10,2) + x(1,11,2) + x(1,12,2)
#  + x(1,2,2) + x(1,3,2) + x(1,4,2) + x(1,5,2) + x(1,6,2) + x(1,7,2) + x(1,8,2)
#  + x(1,9,2) - x(10,1,2) - x(11,1,2) - x(12,1,2) - x(2,1,2) - x(3,1,2)
#  - x(4,1,2) - x(5,1,2) - x(6,1,2) - x(7,1,2) - x(8,1,2) - x(9,1,2) = 0
#
# _C41: - x(0,2,2) - x(1,2,2) - x(10,2,2) - x(11,2,2) - x(12,2,2) + x(2,0,2)
#  + x(2,1,2) + x(2,10,2) + x(2,11,2) + x(2,12,2) + 0 x(2,2,2) + x(2,3,2)
#  + x(2,4,2) + x(2,5,2) + x(2,6,2) + x(2,7,2) + x(2,8,2) + x(2,9,2) - x(3,2,2)
#  - x(4,2,2) - x(5,2,2) - x(6,2,2) - x(7,2,2) - x(8,2,2) - x(9,2,2) = 0
#
# _C42: - x(0,3,2) - x(1,3,2) - x(10,3,2) - x(11,3,2) - x(12,3,2) - x(2,3,2)
#  + x(3,0,2) + x(3,1,2) + x(3,10,2) + x(3,11,2) + x(3,12,2) + x(3,2,2)
#  + 0 x(3,3,2) + x(3,4,2) + x(3,5,2) + x(3,6,2) + x(3,7,2) + x(3,8,2)
#  + x(3,9,2) - x(4,3,2) - x(5,3,2) - x(6,3,2) - x(7,3,2) - x(8,3,2) - x(9,3,2)
#  = 0
#
# _C43: - x(0,4,2) - x(1,4,2) - x(10,4,2) - x(11,4,2) - x(12,4,2) - x(2,4,2)
#  - x(3,4,2) + x(4,0,2) + x(4,1,2) + x(4,10,2) + x(4,11,2) + x(4,12,2)
#  + x(4,2,2) + x(4,3,2) + 0 x(4,4,2) + x(4,5,2) + x(4,6,2) + x(4,7,2)
#  + x(4,8,2) + x(4,9,2) - x(5,4,2) - x(6,4,2) - x(7,4,2) - x(8,4,2) - x(9,4,2)
#  = 0
#
# _C44: - x(0,5,2) - x(1,5,2) - x(10,5,2) - x(11,5,2) - x(12,5,2) - x(2,5,2)
#  - x(3,5,2) - x(4,5,2) + x(5,0,2) + x(5,1,2) + x(5,10,2) + x(5,11,2)
#  + x(5,12,2) + x(5,2,2) + x(5,3,2) + x(5,4,2) + 0 x(5,5,2) + x(5,6,2)
#  + x(5,7,2) + x(5,8,2) + x(5,9,2) - x(6,5,2) - x(7,5,2) - x(8,5,2) - x(9,5,2)
#  = 0
#
# _C45: - x(0,6,2) - x(1,6,2) - x(10,6,2) - x(11,6,2) - x(12,6,2) - x(2,6,2)
#  - x(3,6,2) - x(4,6,2) - x(5,6,2) + x(6,0,2) + x(6,1,2) + x(6,10,2)
#  + x(6,11,2) + x(6,12,2) + x(6,2,2) + x(6,3,2) + x(6,4,2) + x(6,5,2)
#  + 0 x(6,6,2) + x(6,7,2) + x(6,8,2) + x(6,9,2) - x(7,6,2) - x(8,6,2)
#  - x(9,6,2) = 0
#
# _C46: - x(0,7,2) - x(1,7,2) - x(10,7,2) - x(11,7,2) - x(12,7,2) - x(2,7,2)
#  - x(3,7,2) - x(4,7,2) - x(5,7,2) - x(6,7,2) + x(7,0,2) + x(7,1,2) + x(7,10,2)
#  + x(7,11,2) + x(7,12,2) + x(7,2,2) + x(7,3,2) + x(7,4,2) + x(7,5,2)
#  + x(7,6,2) + 0 x(7,7,2) + x(7,8,2) + x(7,9,2) - x(8,7,2) - x(9,7,2) = 0
#
# _C47: - x(0,8,2) - x(1,8,2) - x(10,8,2) - x(11,8,2) - x(12,8,2) - x(2,8,2)
#  - x(3,8,2) - x(4,8,2) - x(5,8,2) - x(6,8,2) - x(7,8,2) + x(8,0,2) + x(8,1,2)
#  + x(8,10,2) + x(8,11,2) + x(8,12,2) + x(8,2,2) + x(8,3,2) + x(8,4,2)
#  + x(8,5,2) + x(8,6,2) + x(8,7,2) + 0 x(8,8,2) + x(8,9,2) - x(9,8,2) = 0
#
# _C48: - x(0,9,2) - x(1,9,2) - x(10,9,2) - x(11,9,2) - x(12,9,2) - x(2,9,2)
#  - x(3,9,2) - x(4,9,2) - x(5,9,2) - x(6,9,2) - x(7,9,2) - x(8,9,2) + x(9,0,2)
#  + x(9,1,2) + x(9,10,2) + x(9,11,2) + x(9,12,2) + x(9,2,2) + x(9,3,2)
#  + x(9,4,2) + x(9,5,2) + x(9,6,2) + x(9,7,2) + x(9,8,2) + 0 x(9,9,2) = 0
#
# _C49: - x(0,10,2) - x(1,10,2) + x(10,0,2) + x(10,1,2) + 0 x(10,10,2)
#  + x(10,11,2) + x(10,12,2) + x(10,2,2) + x(10,3,2) + x(10,4,2) + x(10,5,2)
#  + x(10,6,2) + x(10,7,2) + x(10,8,2) + x(10,9,2) - x(11,10,2) - x(12,10,2)
#  - x(2,10,2) - x(3,10,2) - x(4,10,2) - x(5,10,2) - x(6,10,2) - x(7,10,2)
#  - x(8,10,2) - x(9,10,2) = 0
#
# _C50: - x(0,11,2) - x(1,11,2) - x(10,11,2) + x(11,0,2) + x(11,1,2)
#  + x(11,10,2) + 0 x(11,11,2) + x(11,12,2) + x(11,2,2) + x(11,3,2) + x(11,4,2)
#  + x(11,5,2) + x(11,6,2) + x(11,7,2) + x(11,8,2) + x(11,9,2) - x(12,11,2)
#  - x(2,11,2) - x(3,11,2) - x(4,11,2) - x(5,11,2) - x(6,11,2) - x(7,11,2)
#  - x(8,11,2) - x(9,11,2) = 0
#
# _C51: - x(0,12,2) - x(1,12,2) - x(10,12,2) - x(11,12,2) + x(12,0,2)
#  + x(12,1,2) + x(12,10,2) + x(12,11,2) + 0 x(12,12,2) + x(12,2,2) + x(12,3,2)
#  + x(12,4,2) + x(12,5,2) + x(12,6,2) + x(12,7,2) + x(12,8,2) + x(12,9,2)
#  - x(2,12,2) - x(3,12,2) - x(4,12,2) - x(5,12,2) - x(6,12,2) - x(7,12,2)
#  - x(8,12,2) - x(9,12,2) = 0
#
# _C52: 0 x(0,0,3) + x(0,1,3) + x(0,10,3) + x(0,11,3) + x(0,12,3) + x(0,2,3)
#  + x(0,3,3) + x(0,4,3) + x(0,5,3) + x(0,6,3) + x(0,7,3) + x(0,8,3) + x(0,9,3)
#  - x(1,0,3) - x(10,0,3) - x(11,0,3) - x(12,0,3) - x(2,0,3) - x(3,0,3)
#  - x(4,0,3) - x(5,0,3) - x(6,0,3) - x(7,0,3) - x(8,0,3) - x(9,0,3) = 0
#
# _C53: - x(0,1,3) + x(1,0,3) + 0 x(1,1,3) + x(1,10,3) + x(1,11,3) + x(1,12,3)
#  + x(1,2,3) + x(1,3,3) + x(1,4,3) + x(1,5,3) + x(1,6,3) + x(1,7,3) + x(1,8,3)
#  + x(1,9,3) - x(10,1,3) - x(11,1,3) - x(12,1,3) - x(2,1,3) - x(3,1,3)
#  - x(4,1,3) - x(5,1,3) - x(6,1,3) - x(7,1,3) - x(8,1,3) - x(9,1,3) = 0
#
# _C54: - x(0,2,3) - x(1,2,3) - x(10,2,3) - x(11,2,3) - x(12,2,3) + x(2,0,3)
#  + x(2,1,3) + x(2,10,3) + x(2,11,3) + x(2,12,3) + 0 x(2,2,3) + x(2,3,3)
#  + x(2,4,3) + x(2,5,3) + x(2,6,3) + x(2,7,3) + x(2,8,3) + x(2,9,3) - x(3,2,3)
#  - x(4,2,3) - x(5,2,3) - x(6,2,3) - x(7,2,3) - x(8,2,3) - x(9,2,3) = 0
#
# _C55: - x(0,3,3) - x(1,3,3) - x(10,3,3) - x(11,3,3) - x(12,3,3) - x(2,3,3)
#  + x(3,0,3) + x(3,1,3) + x(3,10,3) + x(3,11,3) + x(3,12,3) + x(3,2,3)
#  + 0 x(3,3,3) + x(3,4,3) + x(3,5,3) + x(3,6,3) + x(3,7,3) + x(3,8,3)
#  + x(3,9,3) - x(4,3,3) - x(5,3,3) - x(6,3,3) - x(7,3,3) - x(8,3,3) - x(9,3,3)
#  = 0
#
# _C56: - x(0,4,3) - x(1,4,3) - x(10,4,3) - x(11,4,3) - x(12,4,3) - x(2,4,3)
#  - x(3,4,3) + x(4,0,3) + x(4,1,3) + x(4,10,3) + x(4,11,3) + x(4,12,3)
#  + x(4,2,3) + x(4,3,3) + 0 x(4,4,3) + x(4,5,3) + x(4,6,3) + x(4,7,3)
#  + x(4,8,3) + x(4,9,3) - x(5,4,3) - x(6,4,3) - x(7,4,3) - x(8,4,3) - x(9,4,3)
#  = 0
#
# _C57: - x(0,5,3) - x(1,5,3) - x(10,5,3) - x(11,5,3) - x(12,5,3) - x(2,5,3)
#  - x(3,5,3) - x(4,5,3) + x(5,0,3) + x(5,1,3) + x(5,10,3) + x(5,11,3)
#  + x(5,12,3) + x(5,2,3) + x(5,3,3) + x(5,4,3) + 0 x(5,5,3) + x(5,6,3)
#  + x(5,7,3) + x(5,8,3) + x(5,9,3) - x(6,5,3) - x(7,5,3) - x(8,5,3) - x(9,5,3)
#  = 0
#
# _C58: - x(0,6,3) - x(1,6,3) - x(10,6,3) - x(11,6,3) - x(12,6,3) - x(2,6,3)
#  - x(3,6,3) - x(4,6,3) - x(5,6,3) + x(6,0,3) + x(6,1,3) + x(6,10,3)
#  + x(6,11,3) + x(6,12,3) + x(6,2,3) + x(6,3,3) + x(6,4,3) + x(6,5,3)
#  + 0 x(6,6,3) + x(6,7,3) + x(6,8,3) + x(6,9,3) - x(7,6,3) - x(8,6,3)
#  - x(9,6,3) = 0
#
# _C59: - x(0,7,3) - x(1,7,3) - x(10,7,3) - x(11,7,3) - x(12,7,3) - x(2,7,3)
#  - x(3,7,3) - x(4,7,3) - x(5,7,3) - x(6,7,3) + x(7,0,3) + x(7,1,3) + x(7,10,3)
#  + x(7,11,3) + x(7,12,3) + x(7,2,3) + x(7,3,3) + x(7,4,3) + x(7,5,3)
#  + x(7,6,3) + 0 x(7,7,3) + x(7,8,3) + x(7,9,3) - x(8,7,3) - x(9,7,3) = 0
#
# _C60: - x(0,8,3) - x(1,8,3) - x(10,8,3) - x(11,8,3) - x(12,8,3) - x(2,8,3)
#  - x(3,8,3) - x(4,8,3) - x(5,8,3) - x(6,8,3) - x(7,8,3) + x(8,0,3) + x(8,1,3)
#  + x(8,10,3) + x(8,11,3) + x(8,12,3) + x(8,2,3) + x(8,3,3) + x(8,4,3)
#  + x(8,5,3) + x(8,6,3) + x(8,7,3) + 0 x(8,8,3) + x(8,9,3) - x(9,8,3) = 0
#
# _C61: - x(0,9,3) - x(1,9,3) - x(10,9,3) - x(11,9,3) - x(12,9,3) - x(2,9,3)
#  - x(3,9,3) - x(4,9,3) - x(5,9,3) - x(6,9,3) - x(7,9,3) - x(8,9,3) + x(9,0,3)
#  + x(9,1,3) + x(9,10,3) + x(9,11,3) + x(9,12,3) + x(9,2,3) + x(9,3,3)
#  + x(9,4,3) + x(9,5,3) + x(9,6,3) + x(9,7,3) + x(9,8,3) + 0 x(9,9,3) = 0
#
# _C62: - x(0,10,3) - x(1,10,3) + x(10,0,3) + x(10,1,3) + 0 x(10,10,3)
#  + x(10,11,3) + x(10,12,3) + x(10,2,3) + x(10,3,3) + x(10,4,3) + x(10,5,3)
#  + x(10,6,3) + x(10,7,3) + x(10,8,3) + x(10,9,3) - x(11,10,3) - x(12,10,3)
#  - x(2,10,3) - x(3,10,3) - x(4,10,3) - x(5,10,3) - x(6,10,3) - x(7,10,3)
#  - x(8,10,3) - x(9,10,3) = 0
#
# _C63: - x(0,11,3) - x(1,11,3) - x(10,11,3) + x(11,0,3) + x(11,1,3)
#  + x(11,10,3) + 0 x(11,11,3) + x(11,12,3) + x(11,2,3) + x(11,3,3) + x(11,4,3)
#  + x(11,5,3) + x(11,6,3) + x(11,7,3) + x(11,8,3) + x(11,9,3) - x(12,11,3)
#  - x(2,11,3) - x(3,11,3) - x(4,11,3) - x(5,11,3) - x(6,11,3) - x(7,11,3)
#  - x(8,11,3) - x(9,11,3) = 0
#
# _C64: - x(0,12,3) - x(1,12,3) - x(10,12,3) - x(11,12,3) + x(12,0,3)
#  + x(12,1,3) + x(12,10,3) + x(12,11,3) + 0 x(12,12,3) + x(12,2,3) + x(12,3,3)
#  + x(12,4,3) + x(12,5,3) + x(12,6,3) + x(12,7,3) + x(12,8,3) + x(12,9,3)
#  - x(2,12,3) - x(3,12,3) - x(4,12,3) - x(5,12,3) - x(6,12,3) - x(7,12,3)
#  - x(8,12,3) - x(9,12,3) = 0
#
# _C65: x(0,0,0) + x(0,1,0) + x(0,10,0) + x(0,11,0) + x(0,12,0) + x(0,2,0)
#  + x(0,3,0) + x(0,4,0) + x(0,5,0) + x(0,6,0) + x(0,7,0) + x(0,8,0) + x(0,9,0)
#  <= 1
#
# _C66: x(0,0,1) + x(0,1,1) + x(0,10,1) + x(0,11,1) + x(0,12,1) + x(0,2,1)
#  + x(0,3,1) + x(0,4,1) + x(0,5,1) + x(0,6,1) + x(0,7,1) + x(0,8,1) + x(0,9,1)
#  <= 1
#
# _C67: x(0,0,2) + x(0,1,2) + x(0,10,2) + x(0,11,2) + x(0,12,2) + x(0,2,2)
#  + x(0,3,2) + x(0,4,2) + x(0,5,2) + x(0,6,2) + x(0,7,2) + x(0,8,2) + x(0,9,2)
#  <= 1
#
# _C68: x(0,0,3) + x(0,1,3) + x(0,10,3) + x(0,11,3) + x(0,12,3) + x(0,2,3)
#  + x(0,3,3) + x(0,4,3) + x(0,5,3) + x(0,6,3) + x(0,7,3) + x(0,8,3) + x(0,9,3)
#  <= 1
#
# _C69: - 6000 x(0,0,0) - 6000 x(0,0,1) - 6000 x(0,0,2) - 6000 x(0,0,3) + y(0,0)
#  + z(0,0) <= 0
#
# _C70: - 6000 x(0,1,0) - 6000 x(0,1,1) - 6000 x(0,1,2) - 6000 x(0,1,3) + y(0,1)
#  + z(0,1) <= 0
#
# _C71: - 6000 x(0,2,0) - 6000 x(0,2,1) - 6000 x(0,2,2) - 6000 x(0,2,3) + y(0,2)
#  + z(0,2) <= 0
#
# _C72: - 6000 x(0,3,0) - 6000 x(0,3,1) - 6000 x(0,3,2) - 6000 x(0,3,3) + y(0,3)
#  + z(0,3) <= 0
#
# _C73: - 6000 x(0,4,0) - 6000 x(0,4,1) - 6000 x(0,4,2) - 6000 x(0,4,3) + y(0,4)
#  + z(0,4) <= 0
#
# _C74: - 6000 x(0,5,0) - 6000 x(0,5,1) - 6000 x(0,5,2) - 6000 x(0,5,3) + y(0,5)
#  + z(0,5) <= 0
#
# _C75: - 6000 x(0,6,0) - 6000 x(0,6,1) - 6000 x(0,6,2) - 6000 x(0,6,3) + y(0,6)
#  + z(0,6) <= 0
#
# _C76: - 6000 x(0,7,0) - 6000 x(0,7,1) - 6000 x(0,7,2) - 6000 x(0,7,3) + y(0,7)
#  + z(0,7) <= 0
#
# _C77: - 6000 x(0,8,0) - 6000 x(0,8,1) - 6000 x(0,8,2) - 6000 x(0,8,3) + y(0,8)
#  + z(0,8) <= 0
#
# _C78: - 6000 x(0,9,0) - 6000 x(0,9,1) - 6000 x(0,9,2) - 6000 x(0,9,3) + y(0,9)
#  + z(0,9) <= 0
#
# _C79: - 6000 x(0,10,0) - 6000 x(0,10,1) - 6000 x(0,10,2) - 6000 x(0,10,3)
#  + y(0,10) + z(0,10) <= 0
#
# _C80: - 6000 x(0,11,0) - 6000 x(0,11,1) - 6000 x(0,11,2) - 6000 x(0,11,3)
#  + y(0,11) + z(0,11) <= 0
#
# _C81: - 6000 x(0,12,0) - 6000 x(0,12,1) - 6000 x(0,12,2) - 6000 x(0,12,3)
#  + y(0,12) + z(0,12) <= 0
#
# _C82: - 6000 x(1,0,0) - 6000 x(1,0,1) - 6000 x(1,0,2) - 6000 x(1,0,3) + y(1,0)
#  + z(1,0) <= 0
#
# _C83: - 6000 x(1,1,0) - 6000 x(1,1,1) - 6000 x(1,1,2) - 6000 x(1,1,3) + y(1,1)
#  + z(1,1) <= 0
#
# _C84: - 6000 x(1,2,0) - 6000 x(1,2,1) - 6000 x(1,2,2) - 6000 x(1,2,3) + y(1,2)
#  + z(1,2) <= 0
#
# _C85: - 6000 x(1,3,0) - 6000 x(1,3,1) - 6000 x(1,3,2) - 6000 x(1,3,3) + y(1,3)
#  + z(1,3) <= 0
#
# _C86: - 6000 x(1,4,0) - 6000 x(1,4,1) - 6000 x(1,4,2) - 6000 x(1,4,3) + y(1,4)
#  + z(1,4) <= 0
#
# _C87: - 6000 x(1,5,0) - 6000 x(1,5,1) - 6000 x(1,5,2) - 6000 x(1,5,3) + y(1,5)
#  + z(1,5) <= 0
#
# _C88: - 6000 x(1,6,0) - 6000 x(1,6,1) - 6000 x(1,6,2) - 6000 x(1,6,3) + y(1,6)
#  + z(1,6) <= 0
#
# _C89: - 6000 x(1,7,0) - 6000 x(1,7,1) - 6000 x(1,7,2) - 6000 x(1,7,3) + y(1,7)
#  + z(1,7) <= 0
#
# _C90: - 6000 x(1,8,0) - 6000 x(1,8,1) - 6000 x(1,8,2) - 6000 x(1,8,3) + y(1,8)
#  + z(1,8) <= 0
#
# _C91: - 6000 x(1,9,0) - 6000 x(1,9,1) - 6000 x(1,9,2) - 6000 x(1,9,3) + y(1,9)
#  + z(1,9) <= 0
#
# _C92: - 6000 x(1,10,0) - 6000 x(1,10,1) - 6000 x(1,10,2) - 6000 x(1,10,3)
#  + y(1,10) + z(1,10) <= 0
#
# _C93: - 6000 x(1,11,0) - 6000 x(1,11,1) - 6000 x(1,11,2) - 6000 x(1,11,3)
#  + y(1,11) + z(1,11) <= 0
#
# _C94: - 6000 x(1,12,0) - 6000 x(1,12,1) - 6000 x(1,12,2) - 6000 x(1,12,3)
#  + y(1,12) + z(1,12) <= 0
#
# _C95: - 6000 x(2,0,0) - 6000 x(2,0,1) - 6000 x(2,0,2) - 6000 x(2,0,3) + y(2,0)
#  + z(2,0) <= 0
#
# _C96: - 6000 x(2,1,0) - 6000 x(2,1,1) - 6000 x(2,1,2) - 6000 x(2,1,3) + y(2,1)
#  + z(2,1) <= 0
#
# _C97: - 6000 x(2,2,0) - 6000 x(2,2,1) - 6000 x(2,2,2) - 6000 x(2,2,3) + y(2,2)
#  + z(2,2) <= 0
#
# _C98: - 6000 x(2,3,0) - 6000 x(2,3,1) - 6000 x(2,3,2) - 6000 x(2,3,3) + y(2,3)
#  + z(2,3) <= 0
#
# _C99: - 6000 x(2,4,0) - 6000 x(2,4,1) - 6000 x(2,4,2) - 6000 x(2,4,3) + y(2,4)
#  + z(2,4) <= 0
#
# _C100: - 6000 x(2,5,0) - 6000 x(2,5,1) - 6000 x(2,5,2) - 6000 x(2,5,3)
#  + y(2,5) + z(2,5) <= 0
#
# _C101: - 6000 x(2,6,0) - 6000 x(2,6,1) - 6000 x(2,6,2) - 6000 x(2,6,3)
#  + y(2,6) + z(2,6) <= 0
#
# _C102: - 6000 x(2,7,0) - 6000 x(2,7,1) - 6000 x(2,7,2) - 6000 x(2,7,3)
#  + y(2,7) + z(2,7) <= 0
#
# _C103: - 6000 x(2,8,0) - 6000 x(2,8,1) - 6000 x(2,8,2) - 6000 x(2,8,3)
#  + y(2,8) + z(2,8) <= 0
#
# _C104: - 6000 x(2,9,0) - 6000 x(2,9,1) - 6000 x(2,9,2) - 6000 x(2,9,3)
#  + y(2,9) + z(2,9) <= 0
#
# _C105: - 6000 x(2,10,0) - 6000 x(2,10,1) - 6000 x(2,10,2) - 6000 x(2,10,3)
#  + y(2,10) + z(2,10) <= 0
#
# _C106: - 6000 x(2,11,0) - 6000 x(2,11,1) - 6000 x(2,11,2) - 6000 x(2,11,3)
#  + y(2,11) + z(2,11) <= 0
#
# _C107: - 6000 x(2,12,0) - 6000 x(2,12,1) - 6000 x(2,12,2) - 6000 x(2,12,3)
#  + y(2,12) + z(2,12) <= 0
#
# _C108: - 6000 x(3,0,0) - 6000 x(3,0,1) - 6000 x(3,0,2) - 6000 x(3,0,3)
#  + y(3,0) + z(3,0) <= 0
#
# _C109: - 6000 x(3,1,0) - 6000 x(3,1,1) - 6000 x(3,1,2) - 6000 x(3,1,3)
#  + y(3,1) + z(3,1) <= 0
#
# _C110: - 6000 x(3,2,0) - 6000 x(3,2,1) - 6000 x(3,2,2) - 6000 x(3,2,3)
#  + y(3,2) + z(3,2) <= 0
#
# _C111: - 6000 x(3,3,0) - 6000 x(3,3,1) - 6000 x(3,3,2) - 6000 x(3,3,3)
#  + y(3,3) + z(3,3) <= 0
#
# _C112: - 6000 x(3,4,0) - 6000 x(3,4,1) - 6000 x(3,4,2) - 6000 x(3,4,3)
#  + y(3,4) + z(3,4) <= 0
#
# _C113: - 6000 x(3,5,0) - 6000 x(3,5,1) - 6000 x(3,5,2) - 6000 x(3,5,3)
#  + y(3,5) + z(3,5) <= 0
#
# _C114: - 6000 x(3,6,0) - 6000 x(3,6,1) - 6000 x(3,6,2) - 6000 x(3,6,3)
#  + y(3,6) + z(3,6) <= 0
#
# _C115: - 6000 x(3,7,0) - 6000 x(3,7,1) - 6000 x(3,7,2) - 6000 x(3,7,3)
#  + y(3,7) + z(3,7) <= 0
#
# _C116: - 6000 x(3,8,0) - 6000 x(3,8,1) - 6000 x(3,8,2) - 6000 x(3,8,3)
#  + y(3,8) + z(3,8) <= 0
#
# _C117: - 6000 x(3,9,0) - 6000 x(3,9,1) - 6000 x(3,9,2) - 6000 x(3,9,3)
#  + y(3,9) + z(3,9) <= 0
#
# _C118: - 6000 x(3,10,0) - 6000 x(3,10,1) - 6000 x(3,10,2) - 6000 x(3,10,3)
#  + y(3,10) + z(3,10) <= 0
#
# _C119: - 6000 x(3,11,0) - 6000 x(3,11,1) - 6000 x(3,11,2) - 6000 x(3,11,3)
#  + y(3,11) + z(3,11) <= 0
#
# _C120: - 6000 x(3,12,0) - 6000 x(3,12,1) - 6000 x(3,12,2) - 6000 x(3,12,3)
#  + y(3,12) + z(3,12) <= 0
#
# _C121: - 6000 x(4,0,0) - 6000 x(4,0,1) - 6000 x(4,0,2) - 6000 x(4,0,3)
#  + y(4,0) + z(4,0) <= 0
#
# _C122: - 6000 x(4,1,0) - 6000 x(4,1,1) - 6000 x(4,1,2) - 6000 x(4,1,3)
#  + y(4,1) + z(4,1) <= 0
#
# _C123: - 6000 x(4,2,0) - 6000 x(4,2,1) - 6000 x(4,2,2) - 6000 x(4,2,3)
#  + y(4,2) + z(4,2) <= 0
#
# _C124: - 6000 x(4,3,0) - 6000 x(4,3,1) - 6000 x(4,3,2) - 6000 x(4,3,3)
#  + y(4,3) + z(4,3) <= 0
#
# _C125: - 6000 x(4,4,0) - 6000 x(4,4,1) - 6000 x(4,4,2) - 6000 x(4,4,3)
#  + y(4,4) + z(4,4) <= 0
#
# _C126: - 6000 x(4,5,0) - 6000 x(4,5,1) - 6000 x(4,5,2) - 6000 x(4,5,3)
#  + y(4,5) + z(4,5) <= 0
#
# _C127: - 6000 x(4,6,0) - 6000 x(4,6,1) - 6000 x(4,6,2) - 6000 x(4,6,3)
#  + y(4,6) + z(4,6) <= 0
#
# _C128: - 6000 x(4,7,0) - 6000 x(4,7,1) - 6000 x(4,7,2) - 6000 x(4,7,3)
#  + y(4,7) + z(4,7) <= 0
#
# _C129: - 6000 x(4,8,0) - 6000 x(4,8,1) - 6000 x(4,8,2) - 6000 x(4,8,3)
#  + y(4,8) + z(4,8) <= 0
#
# _C130: - 6000 x(4,9,0) - 6000 x(4,9,1) - 6000 x(4,9,2) - 6000 x(4,9,3)
#  + y(4,9) + z(4,9) <= 0
#
# _C131: - 6000 x(4,10,0) - 6000 x(4,10,1) - 6000 x(4,10,2) - 6000 x(4,10,3)
#  + y(4,10) + z(4,10) <= 0
#
# _C132: - 6000 x(4,11,0) - 6000 x(4,11,1) - 6000 x(4,11,2) - 6000 x(4,11,3)
#  + y(4,11) + z(4,11) <= 0
#
# _C133: - 6000 x(4,12,0) - 6000 x(4,12,1) - 6000 x(4,12,2) - 6000 x(4,12,3)
#  + y(4,12) + z(4,12) <= 0
#
# _C134: - 6000 x(5,0,0) - 6000 x(5,0,1) - 6000 x(5,0,2) - 6000 x(5,0,3)
#  + y(5,0) + z(5,0) <= 0
#
# _C135: - 6000 x(5,1,0) - 6000 x(5,1,1) - 6000 x(5,1,2) - 6000 x(5,1,3)
#  + y(5,1) + z(5,1) <= 0
#
# _C136: - 6000 x(5,2,0) - 6000 x(5,2,1) - 6000 x(5,2,2) - 6000 x(5,2,3)
#  + y(5,2) + z(5,2) <= 0
#
# _C137: - 6000 x(5,3,0) - 6000 x(5,3,1) - 6000 x(5,3,2) - 6000 x(5,3,3)
#  + y(5,3) + z(5,3) <= 0
#
# _C138: - 6000 x(5,4,0) - 6000 x(5,4,1) - 6000 x(5,4,2) - 6000 x(5,4,3)
#  + y(5,4) + z(5,4) <= 0
#
# _C139: - 6000 x(5,5,0) - 6000 x(5,5,1) - 6000 x(5,5,2) - 6000 x(5,5,3)
#  + y(5,5) + z(5,5) <= 0
#
# _C140: - 6000 x(5,6,0) - 6000 x(5,6,1) - 6000 x(5,6,2) - 6000 x(5,6,3)
#  + y(5,6) + z(5,6) <= 0
#
# _C141: - 6000 x(5,7,0) - 6000 x(5,7,1) - 6000 x(5,7,2) - 6000 x(5,7,3)
#  + y(5,7) + z(5,7) <= 0
#
# _C142: - 6000 x(5,8,0) - 6000 x(5,8,1) - 6000 x(5,8,2) - 6000 x(5,8,3)
#  + y(5,8) + z(5,8) <= 0
#
# _C143: - 6000 x(5,9,0) - 6000 x(5,9,1) - 6000 x(5,9,2) - 6000 x(5,9,3)
#  + y(5,9) + z(5,9) <= 0
#
# _C144: - 6000 x(5,10,0) - 6000 x(5,10,1) - 6000 x(5,10,2) - 6000 x(5,10,3)
#  + y(5,10) + z(5,10) <= 0
#
# _C145: - 6000 x(5,11,0) - 6000 x(5,11,1) - 6000 x(5,11,2) - 6000 x(5,11,3)
#  + y(5,11) + z(5,11) <= 0
#
# _C146: - 6000 x(5,12,0) - 6000 x(5,12,1) - 6000 x(5,12,2) - 6000 x(5,12,3)
#  + y(5,12) + z(5,12) <= 0
#
# _C147: - 6000 x(6,0,0) - 6000 x(6,0,1) - 6000 x(6,0,2) - 6000 x(6,0,3)
#  + y(6,0) + z(6,0) <= 0
#
# _C148: - 6000 x(6,1,0) - 6000 x(6,1,1) - 6000 x(6,1,2) - 6000 x(6,1,3)
#  + y(6,1) + z(6,1) <= 0
#
# _C149: - 6000 x(6,2,0) - 6000 x(6,2,1) - 6000 x(6,2,2) - 6000 x(6,2,3)
#  + y(6,2) + z(6,2) <= 0
#
# _C150: - 6000 x(6,3,0) - 6000 x(6,3,1) - 6000 x(6,3,2) - 6000 x(6,3,3)
#  + y(6,3) + z(6,3) <= 0
#
# _C151: - 6000 x(6,4,0) - 6000 x(6,4,1) - 6000 x(6,4,2) - 6000 x(6,4,3)
#  + y(6,4) + z(6,4) <= 0
#
# _C152: - 6000 x(6,5,0) - 6000 x(6,5,1) - 6000 x(6,5,2) - 6000 x(6,5,3)
#  + y(6,5) + z(6,5) <= 0
#
# _C153: - 6000 x(6,6,0) - 6000 x(6,6,1) - 6000 x(6,6,2) - 6000 x(6,6,3)
#  + y(6,6) + z(6,6) <= 0
#
# _C154: - 6000 x(6,7,0) - 6000 x(6,7,1) - 6000 x(6,7,2) - 6000 x(6,7,3)
#  + y(6,7) + z(6,7) <= 0
#
# _C155: - 6000 x(6,8,0) - 6000 x(6,8,1) - 6000 x(6,8,2) - 6000 x(6,8,3)
#  + y(6,8) + z(6,8) <= 0
#
# _C156: - 6000 x(6,9,0) - 6000 x(6,9,1) - 6000 x(6,9,2) - 6000 x(6,9,3)
#  + y(6,9) + z(6,9) <= 0
#
# _C157: - 6000 x(6,10,0) - 6000 x(6,10,1) - 6000 x(6,10,2) - 6000 x(6,10,3)
#  + y(6,10) + z(6,10) <= 0
#
# _C158: - 6000 x(6,11,0) - 6000 x(6,11,1) - 6000 x(6,11,2) - 6000 x(6,11,3)
#  + y(6,11) + z(6,11) <= 0
#
# _C159: - 6000 x(6,12,0) - 6000 x(6,12,1) - 6000 x(6,12,2) - 6000 x(6,12,3)
#  + y(6,12) + z(6,12) <= 0
#
# _C160: - 6000 x(7,0,0) - 6000 x(7,0,1) - 6000 x(7,0,2) - 6000 x(7,0,3)
#  + y(7,0) + z(7,0) <= 0
#
# _C161: - 6000 x(7,1,0) - 6000 x(7,1,1) - 6000 x(7,1,2) - 6000 x(7,1,3)
#  + y(7,1) + z(7,1) <= 0
#
# _C162: - 6000 x(7,2,0) - 6000 x(7,2,1) - 6000 x(7,2,2) - 6000 x(7,2,3)
#  + y(7,2) + z(7,2) <= 0
#
# _C163: - 6000 x(7,3,0) - 6000 x(7,3,1) - 6000 x(7,3,2) - 6000 x(7,3,3)
#  + y(7,3) + z(7,3) <= 0
#
# _C164: - 6000 x(7,4,0) - 6000 x(7,4,1) - 6000 x(7,4,2) - 6000 x(7,4,3)
#  + y(7,4) + z(7,4) <= 0
#
# _C165: - 6000 x(7,5,0) - 6000 x(7,5,1) - 6000 x(7,5,2) - 6000 x(7,5,3)
#  + y(7,5) + z(7,5) <= 0
#
# _C166: - 6000 x(7,6,0) - 6000 x(7,6,1) - 6000 x(7,6,2) - 6000 x(7,6,3)
#  + y(7,6) + z(7,6) <= 0
#
# _C167: - 6000 x(7,7,0) - 6000 x(7,7,1) - 6000 x(7,7,2) - 6000 x(7,7,3)
#  + y(7,7) + z(7,7) <= 0
#
# _C168: - 6000 x(7,8,0) - 6000 x(7,8,1) - 6000 x(7,8,2) - 6000 x(7,8,3)
#  + y(7,8) + z(7,8) <= 0
#
# _C169: - 6000 x(7,9,0) - 6000 x(7,9,1) - 6000 x(7,9,2) - 6000 x(7,9,3)
#  + y(7,9) + z(7,9) <= 0
#
# _C170: - 6000 x(7,10,0) - 6000 x(7,10,1) - 6000 x(7,10,2) - 6000 x(7,10,3)
#  + y(7,10) + z(7,10) <= 0
#
# _C171: - 6000 x(7,11,0) - 6000 x(7,11,1) - 6000 x(7,11,2) - 6000 x(7,11,3)
#  + y(7,11) + z(7,11) <= 0
#
# _C172: - 6000 x(7,12,0) - 6000 x(7,12,1) - 6000 x(7,12,2) - 6000 x(7,12,3)
#  + y(7,12) + z(7,12) <= 0
#
# _C173: - 6000 x(8,0,0) - 6000 x(8,0,1) - 6000 x(8,0,2) - 6000 x(8,0,3)
#  + y(8,0) + z(8,0) <= 0
#
# _C174: - 6000 x(8,1,0) - 6000 x(8,1,1) - 6000 x(8,1,2) - 6000 x(8,1,3)
#  + y(8,1) + z(8,1) <= 0
#
# _C175: - 6000 x(8,2,0) - 6000 x(8,2,1) - 6000 x(8,2,2) - 6000 x(8,2,3)
#  + y(8,2) + z(8,2) <= 0
#
# _C176: - 6000 x(8,3,0) - 6000 x(8,3,1) - 6000 x(8,3,2) - 6000 x(8,3,3)
#  + y(8,3) + z(8,3) <= 0
#
# _C177: - 6000 x(8,4,0) - 6000 x(8,4,1) - 6000 x(8,4,2) - 6000 x(8,4,3)
#  + y(8,4) + z(8,4) <= 0
#
# _C178: - 6000 x(8,5,0) - 6000 x(8,5,1) - 6000 x(8,5,2) - 6000 x(8,5,3)
#  + y(8,5) + z(8,5) <= 0
#
# _C179: - 6000 x(8,6,0) - 6000 x(8,6,1) - 6000 x(8,6,2) - 6000 x(8,6,3)
#  + y(8,6) + z(8,6) <= 0
#
# _C180: - 6000 x(8,7,0) - 6000 x(8,7,1) - 6000 x(8,7,2) - 6000 x(8,7,3)
#  + y(8,7) + z(8,7) <= 0
#
# _C181: - 6000 x(8,8,0) - 6000 x(8,8,1) - 6000 x(8,8,2) - 6000 x(8,8,3)
#  + y(8,8) + z(8,8) <= 0
#
# _C182: - 6000 x(8,9,0) - 6000 x(8,9,1) - 6000 x(8,9,2) - 6000 x(8,9,3)
#  + y(8,9) + z(8,9) <= 0
#
# _C183: - 6000 x(8,10,0) - 6000 x(8,10,1) - 6000 x(8,10,2) - 6000 x(8,10,3)
#  + y(8,10) + z(8,10) <= 0
#
# _C184: - 6000 x(8,11,0) - 6000 x(8,11,1) - 6000 x(8,11,2) - 6000 x(8,11,3)
#  + y(8,11) + z(8,11) <= 0
#
# _C185: - 6000 x(8,12,0) - 6000 x(8,12,1) - 6000 x(8,12,2) - 6000 x(8,12,3)
#  + y(8,12) + z(8,12) <= 0
#
# _C186: - 6000 x(9,0,0) - 6000 x(9,0,1) - 6000 x(9,0,2) - 6000 x(9,0,3)
#  + y(9,0) + z(9,0) <= 0
#
# _C187: - 6000 x(9,1,0) - 6000 x(9,1,1) - 6000 x(9,1,2) - 6000 x(9,1,3)
#  + y(9,1) + z(9,1) <= 0
#
# _C188: - 6000 x(9,2,0) - 6000 x(9,2,1) - 6000 x(9,2,2) - 6000 x(9,2,3)
#  + y(9,2) + z(9,2) <= 0
#
# _C189: - 6000 x(9,3,0) - 6000 x(9,3,1) - 6000 x(9,3,2) - 6000 x(9,3,3)
#  + y(9,3) + z(9,3) <= 0
#
# _C190: - 6000 x(9,4,0) - 6000 x(9,4,1) - 6000 x(9,4,2) - 6000 x(9,4,3)
#  + y(9,4) + z(9,4) <= 0
#
# _C191: - 6000 x(9,5,0) - 6000 x(9,5,1) - 6000 x(9,5,2) - 6000 x(9,5,3)
#  + y(9,5) + z(9,5) <= 0
#
# _C192: - 6000 x(9,6,0) - 6000 x(9,6,1) - 6000 x(9,6,2) - 6000 x(9,6,3)
#  + y(9,6) + z(9,6) <= 0
#
# _C193: - 6000 x(9,7,0) - 6000 x(9,7,1) - 6000 x(9,7,2) - 6000 x(9,7,3)
#  + y(9,7) + z(9,7) <= 0
#
# _C194: - 6000 x(9,8,0) - 6000 x(9,8,1) - 6000 x(9,8,2) - 6000 x(9,8,3)
#  + y(9,8) + z(9,8) <= 0
#
# _C195: - 6000 x(9,9,0) - 6000 x(9,9,1) - 6000 x(9,9,2) - 6000 x(9,9,3)
#  + y(9,9) + z(9,9) <= 0
#
# _C196: - 6000 x(9,10,0) - 6000 x(9,10,1) - 6000 x(9,10,2) - 6000 x(9,10,3)
#  + y(9,10) + z(9,10) <= 0
#
# _C197: - 6000 x(9,11,0) - 6000 x(9,11,1) - 6000 x(9,11,2) - 6000 x(9,11,3)
#  + y(9,11) + z(9,11) <= 0
#
# _C198: - 6000 x(9,12,0) - 6000 x(9,12,1) - 6000 x(9,12,2) - 6000 x(9,12,3)
#  + y(9,12) + z(9,12) <= 0
#
# _C199: - 6000 x(10,0,0) - 6000 x(10,0,1) - 6000 x(10,0,2) - 6000 x(10,0,3)
#  + y(10,0) + z(10,0) <= 0
#
# _C200: - 6000 x(10,1,0) - 6000 x(10,1,1) - 6000 x(10,1,2) - 6000 x(10,1,3)
#  + y(10,1) + z(10,1) <= 0
#
# _C201: - 6000 x(10,2,0) - 6000 x(10,2,1) - 6000 x(10,2,2) - 6000 x(10,2,3)
#  + y(10,2) + z(10,2) <= 0
#
# _C202: - 6000 x(10,3,0) - 6000 x(10,3,1) - 6000 x(10,3,2) - 6000 x(10,3,3)
#  + y(10,3) + z(10,3) <= 0
#
# _C203: - 6000 x(10,4,0) - 6000 x(10,4,1) - 6000 x(10,4,2) - 6000 x(10,4,3)
#  + y(10,4) + z(10,4) <= 0
#
# _C204: - 6000 x(10,5,0) - 6000 x(10,5,1) - 6000 x(10,5,2) - 6000 x(10,5,3)
#  + y(10,5) + z(10,5) <= 0
#
# _C205: - 6000 x(10,6,0) - 6000 x(10,6,1) - 6000 x(10,6,2) - 6000 x(10,6,3)
#  + y(10,6) + z(10,6) <= 0
#
# _C206: - 6000 x(10,7,0) - 6000 x(10,7,1) - 6000 x(10,7,2) - 6000 x(10,7,3)
#  + y(10,7) + z(10,7) <= 0
#
# _C207: - 6000 x(10,8,0) - 6000 x(10,8,1) - 6000 x(10,8,2) - 6000 x(10,8,3)
#  + y(10,8) + z(10,8) <= 0
#
# _C208: - 6000 x(10,9,0) - 6000 x(10,9,1) - 6000 x(10,9,2) - 6000 x(10,9,3)
#  + y(10,9) + z(10,9) <= 0
#
# _C209: - 6000 x(10,10,0) - 6000 x(10,10,1) - 6000 x(10,10,2) - 6000 x(10,10,3)
#  + y(10,10) + z(10,10) <= 0
#
# _C210: - 6000 x(10,11,0) - 6000 x(10,11,1) - 6000 x(10,11,2) - 6000 x(10,11,3)
#  + y(10,11) + z(10,11) <= 0
#
# _C211: - 6000 x(10,12,0) - 6000 x(10,12,1) - 6000 x(10,12,2) - 6000 x(10,12,3)
#  + y(10,12) + z(10,12) <= 0
#
# _C212: - 6000 x(11,0,0) - 6000 x(11,0,1) - 6000 x(11,0,2) - 6000 x(11,0,3)
#  + y(11,0) + z(11,0) <= 0
#
# _C213: - 6000 x(11,1,0) - 6000 x(11,1,1) - 6000 x(11,1,2) - 6000 x(11,1,3)
#  + y(11,1) + z(11,1) <= 0
#
# _C214: - 6000 x(11,2,0) - 6000 x(11,2,1) - 6000 x(11,2,2) - 6000 x(11,2,3)
#  + y(11,2) + z(11,2) <= 0
#
# _C215: - 6000 x(11,3,0) - 6000 x(11,3,1) - 6000 x(11,3,2) - 6000 x(11,3,3)
#  + y(11,3) + z(11,3) <= 0
#
# _C216: - 6000 x(11,4,0) - 6000 x(11,4,1) - 6000 x(11,4,2) - 6000 x(11,4,3)
#  + y(11,4) + z(11,4) <= 0
#
# _C217: - 6000 x(11,5,0) - 6000 x(11,5,1) - 6000 x(11,5,2) - 6000 x(11,5,3)
#  + y(11,5) + z(11,5) <= 0
#
# _C218: - 6000 x(11,6,0) - 6000 x(11,6,1) - 6000 x(11,6,2) - 6000 x(11,6,3)
#  + y(11,6) + z(11,6) <= 0
#
# _C219: - 6000 x(11,7,0) - 6000 x(11,7,1) - 6000 x(11,7,2) - 6000 x(11,7,3)
#  + y(11,7) + z(11,7) <= 0
#
# _C220: - 6000 x(11,8,0) - 6000 x(11,8,1) - 6000 x(11,8,2) - 6000 x(11,8,3)
#  + y(11,8) + z(11,8) <= 0
#
# _C221: - 6000 x(11,9,0) - 6000 x(11,9,1) - 6000 x(11,9,2) - 6000 x(11,9,3)
#  + y(11,9) + z(11,9) <= 0
#
# _C222: - 6000 x(11,10,0) - 6000 x(11,10,1) - 6000 x(11,10,2) - 6000 x(11,10,3)
#  + y(11,10) + z(11,10) <= 0
#
# _C223: - 6000 x(11,11,0) - 6000 x(11,11,1) - 6000 x(11,11,2) - 6000 x(11,11,3)
#  + y(11,11) + z(11,11) <= 0
#
# _C224: - 6000 x(11,12,0) - 6000 x(11,12,1) - 6000 x(11,12,2) - 6000 x(11,12,3)
#  + y(11,12) + z(11,12) <= 0
#
# _C225: - 6000 x(12,0,0) - 6000 x(12,0,1) - 6000 x(12,0,2) - 6000 x(12,0,3)
#  + y(12,0) + z(12,0) <= 0
#
# _C226: - 6000 x(12,1,0) - 6000 x(12,1,1) - 6000 x(12,1,2) - 6000 x(12,1,3)
#  + y(12,1) + z(12,1) <= 0
#
# _C227: - 6000 x(12,2,0) - 6000 x(12,2,1) - 6000 x(12,2,2) - 6000 x(12,2,3)
#  + y(12,2) + z(12,2) <= 0
#
# _C228: - 6000 x(12,3,0) - 6000 x(12,3,1) - 6000 x(12,3,2) - 6000 x(12,3,3)
#  + y(12,3) + z(12,3) <= 0
#
# _C229: - 6000 x(12,4,0) - 6000 x(12,4,1) - 6000 x(12,4,2) - 6000 x(12,4,3)
#  + y(12,4) + z(12,4) <= 0
#
# _C230: - 6000 x(12,5,0) - 6000 x(12,5,1) - 6000 x(12,5,2) - 6000 x(12,5,3)
#  + y(12,5) + z(12,5) <= 0
#
# _C231: - 6000 x(12,6,0) - 6000 x(12,6,1) - 6000 x(12,6,2) - 6000 x(12,6,3)
#  + y(12,6) + z(12,6) <= 0
#
# _C232: - 6000 x(12,7,0) - 6000 x(12,7,1) - 6000 x(12,7,2) - 6000 x(12,7,3)
#  + y(12,7) + z(12,7) <= 0
#
# _C233: - 6000 x(12,8,0) - 6000 x(12,8,1) - 6000 x(12,8,2) - 6000 x(12,8,3)
#  + y(12,8) + z(12,8) <= 0
#
# _C234: - 6000 x(12,9,0) - 6000 x(12,9,1) - 6000 x(12,9,2) - 6000 x(12,9,3)
#  + y(12,9) + z(12,9) <= 0
#
# _C235: - 6000 x(12,10,0) - 6000 x(12,10,1) - 6000 x(12,10,2) - 6000 x(12,10,3)
#  + y(12,10) + z(12,10) <= 0
#
# _C236: - 6000 x(12,11,0) - 6000 x(12,11,1) - 6000 x(12,11,2) - 6000 x(12,11,3)
#  + y(12,11) + z(12,11) <= 0
#
# _C237: - 6000 x(12,12,0) - 6000 x(12,12,1) - 6000 x(12,12,2) - 6000 x(12,12,3)
#  + y(12,12) + z(12,12) <= 0
#
# _C238: - y(0,1) + y(1,0) + 0 y(1,1) + y(1,10) + y(1,11) + y(1,12) + y(1,2)
#  + y(1,3) + y(1,4) + y(1,5) + y(1,6) + y(1,7) + y(1,8) + y(1,9) - y(10,1)
#  - y(11,1) - y(12,1) - y(2,1) - y(3,1) - y(4,1) - y(5,1) - y(6,1) - y(7,1)
#  - y(8,1) - y(9,1) = 0
#
# _C239: - y(0,2) - y(1,2) - y(10,2) - y(11,2) - y(12,2) + y(2,0) + y(2,1)
#  + y(2,10) + y(2,11) + y(2,12) + 0 y(2,2) + y(2,3) + y(2,4) + y(2,5) + y(2,6)
#  + y(2,7) + y(2,8) + y(2,9) - y(3,2) - y(4,2) - y(5,2) - y(6,2) - y(7,2)
#  - y(8,2) - y(9,2) = 1200
#
# _C240: - y(0,3) - y(1,3) - y(10,3) - y(11,3) - y(12,3) - y(2,3) + y(3,0)
#  + y(3,1) + y(3,10) + y(3,11) + y(3,12) + y(3,2) + 0 y(3,3) + y(3,4) + y(3,5)
#  + y(3,6) + y(3,7) + y(3,8) + y(3,9) - y(4,3) - y(5,3) - y(6,3) - y(7,3)
#  - y(8,3) - y(9,3) = 1700
#
# _C241: - y(0,4) - y(1,4) - y(10,4) - y(11,4) - y(12,4) - y(2,4) - y(3,4)
#  + y(4,0) + y(4,1) + y(4,10) + y(4,11) + y(4,12) + y(4,2) + y(4,3) + 0 y(4,4)
#  + y(4,5) + y(4,6) + y(4,7) + y(4,8) + y(4,9) - y(5,4) - y(6,4) - y(7,4)
#  - y(8,4) - y(9,4) = 1500
#
# _C242: - y(0,5) - y(1,5) - y(10,5) - y(11,5) - y(12,5) - y(2,5) - y(3,5)
#  - y(4,5) + y(5,0) + y(5,1) + y(5,10) + y(5,11) + y(5,12) + y(5,2) + y(5,3)
#  + y(5,4) + 0 y(5,5) + y(5,6) + y(5,7) + y(5,8) + y(5,9) - y(6,5) - y(7,5)
#  - y(8,5) - y(9,5) = 1400
#
# _C243: - y(0,6) - y(1,6) - y(10,6) - y(11,6) - y(12,6) - y(2,6) - y(3,6)
#  - y(4,6) - y(5,6) + y(6,0) + y(6,1) + y(6,10) + y(6,11) + y(6,12) + y(6,2)
#  + y(6,3) + y(6,4) + y(6,5) + 0 y(6,6) + y(6,7) + y(6,8) + y(6,9) - y(7,6)
#  - y(8,6) - y(9,6) = 1700
#
# _C244: - y(0,7) - y(1,7) - y(10,7) - y(11,7) - y(12,7) - y(2,7) - y(3,7)
#  - y(4,7) - y(5,7) - y(6,7) + y(7,0) + y(7,1) + y(7,10) + y(7,11) + y(7,12)
#  + y(7,2) + y(7,3) + y(7,4) + y(7,5) + y(7,6) + 0 y(7,7) + y(7,8) + y(7,9)
#  - y(8,7) - y(9,7) = 1400
#
# _C245: - y(0,8) - y(1,8) - y(10,8) - y(11,8) - y(12,8) - y(2,8) - y(3,8)
#  - y(4,8) - y(5,8) - y(6,8) - y(7,8) + y(8,0) + y(8,1) + y(8,10) + y(8,11)
#  + y(8,12) + y(8,2) + y(8,3) + y(8,4) + y(8,5) + y(8,6) + y(8,7) + 0 y(8,8)
#  + y(8,9) - y(9,8) = 1200
#
# _C246: - y(0,9) - y(1,9) - y(10,9) - y(11,9) - y(12,9) - y(2,9) - y(3,9)
#  - y(4,9) - y(5,9) - y(6,9) - y(7,9) - y(8,9) + y(9,0) + y(9,1) + y(9,10)
#  + y(9,11) + y(9,12) + y(9,2) + y(9,3) + y(9,4) + y(9,5) + y(9,6) + y(9,7)
#  + y(9,8) + 0 y(9,9) = 1900
#
# _C247: - y(0,10) - y(1,10) + y(10,0) + y(10,1) + 0 y(10,10) + y(10,11)
#  + y(10,12) + y(10,2) + y(10,3) + y(10,4) + y(10,5) + y(10,6) + y(10,7)
#  + y(10,8) + y(10,9) - y(11,10) - y(12,10) - y(2,10) - y(3,10) - y(4,10)
#  - y(5,10) - y(6,10) - y(7,10) - y(8,10) - y(9,10) = 1800
#
# _C248: - y(0,11) - y(1,11) - y(10,11) + y(11,0) + y(11,1) + y(11,10)
#  + 0 y(11,11) + y(11,12) + y(11,2) + y(11,3) + y(11,4) + y(11,5) + y(11,6)
#  + y(11,7) + y(11,8) + y(11,9) - y(12,11) - y(2,11) - y(3,11) - y(4,11)
#  - y(5,11) - y(6,11) - y(7,11) - y(8,11) - y(9,11) = 1600
#
# _C249: - y(0,12) - y(1,12) - y(10,12) - y(11,12) + y(12,0) + y(12,1)
#  + y(12,10) + y(12,11) + 0 y(12,12) + y(12,2) + y(12,3) + y(12,4) + y(12,5)
#  + y(12,6) + y(12,7) + y(12,8) + y(12,9) - y(2,12) - y(3,12) - y(4,12)
#  - y(5,12) - y(6,12) - y(7,12) - y(8,12) - y(9,12) = 1700
#
# _C250: z(0,1) - z(1,0) + 0 z(1,1) - z(1,10) - z(1,11) - z(1,12) - z(1,2)
#  - z(1,3) - z(1,4) - z(1,5) - z(1,6) - z(1,7) - z(1,8) - z(1,9) + z(10,1)
#  + z(11,1) + z(12,1) + z(2,1) + z(3,1) + z(4,1) + z(5,1) + z(6,1) + z(7,1)
#  + z(8,1) + z(9,1) = 1200
#
# _C251: z(0,2) + z(1,2) + z(10,2) + z(11,2) + z(12,2) - z(2,0) - z(2,1)
#  - z(2,10) - z(2,11) - z(2,12) + 0 z(2,2) - z(2,3) - z(2,4) - z(2,5) - z(2,6)
#  - z(2,7) - z(2,8) - z(2,9) + z(3,2) + z(4,2) + z(5,2) + z(6,2) + z(7,2)
# ...
# 0 <= x(3,1,2) <= 1 Integer
# 0 <= x(3,1,3) <= 1 Integer
# 0 <= x(3,10,0) <= 1 Integer
# 0 <= x(3,10,1) <= 1 Integer
# 0 <= x(3,10,2) <= 1 Integer
# 0 <= x(3,10,3) <= 1 Integer
# 0 <= x(3,11,0) <= 1 Integer
# 0 <= x(3,11,1) <= 1 Integer
# 0 <= x(3,11,2) <= 1 Integer
# 0 <= x(3,11,3) <= 1 Integer
# 0 <= x(3,12,0) <= 1 Integer
# 0 <= x(3,12,1) <= 1 Integer
# 0 <= x(3,12,2) <= 1 Integer
# 0 <= x(3,12,3) <= 1 Integer
# 0 <= x(3,2,0) <= 1 Integer
# 0 <= x(3,2,1) <= 1 Integer
# 0 <= x(3,2,2) <= 1 Integer
# 0 <= x(3,2,3) <= 1 Integer
# 0 <= x(3,3,0) <= 1 Integer
# 0 <= x(3,3,1) <= 1 Integer
# 0 <= x(3,3,2) <= 1 Integer
# 0 <= x(3,3,3) <= 1 Integer
# 0 <= x(3,4,0) <= 1 Integer
# 0 <= x(3,4,1) <= 1 Integer
# 0 <= x(3,4,2) <= 1 Integer
# 0 <= x(3,4,3) <= 1 Integer
# 0 <= x(3,5,0) <= 1 Integer
# 0 <= x(3,5,1) <= 1 Integer
# 0 <= x(3,5,2) <= 1 Integer
# 0 <= x(3,5,3) <= 1 Integer
# 0 <= x(3,6,0) <= 1 Integer
# 0 <= x(3,6,1) <= 1 Integer
# 0 <= x(3,6,2) <= 1 Integer
# 0 <= x(3,6,3) <= 1 Integer
# 0 <= x(3,7,0) <= 1 Integer
# 0 <= x(3,7,1) <= 1 Integer
# 0 <= x(3,7,2) <= 1 Integer
# 0 <= x(3,7,3) <= 1 Integer
# 0 <= x(3,8,0) <= 1 Integer
# 0 <= x(3,8,1) <= 1 Integer
# 0 <= x(3,8,2) <= 1 Integer
# 0 <= x(3,8,3) <= 1 Integer
# 0 <= x(3,9,0) <= 1 Integer
# 0 <= x(3,9,1) <= 1 Integer
# 0 <= x(3,9,2) <= 1 Integer
# 0 <= x(3,9,3) <= 1 Integer
# 0 <= x(4,0,0) <= 1 Integer
# 0 <= x(4,0,1) <= 1 Integer
# 0 <= x(4,0,2) <= 1 Integer
# 0 <= x(4,0,3) <= 1 Integer
# 0 <= x(4,1,0) <= 1 Integer
# 0 <= x(4,1,1) <= 1 Integer
# 0 <= x(4,1,2) <= 1 Integer
# 0 <= x(4,1,3) <= 1 Integer
# 0 <= x(4,10,0) <= 1 Integer
# 0 <= x(4,10,1) <= 1 Integer
# 0 <= x(4,10,2) <= 1 Integer
# 0 <= x(4,10,3) <= 1 Integer
# 0 <= x(4,11,0) <= 1 Integer
# 0 <= x(4,11,1) <= 1 Integer
# 0 <= x(4,11,2) <= 1 Integer
# 0 <= x(4,11,3) <= 1 Integer
# 0 <= x(4,12,0) <= 1 Integer
# 0 <= x(4,12,1) <= 1 Integer
# 0 <= x(4,12,2) <= 1 Integer
# 0 <= x(4,12,3) <= 1 Integer
# 0 <= x(4,2,0) <= 1 Integer
# 0 <= x(4,2,1) <= 1 Integer
# 0 <= x(4,2,2) <= 1 Integer
# 0 <= x(4,2,3) <= 1 Integer
# 0 <= x(4,3,0) <= 1 Integer
# 0 <= x(4,3,1) <= 1 Integer
# 0 <= x(4,3,2) <= 1 Integer
# 0 <= x(4,3,3) <= 1 Integer
# 0 <= x(4,4,0) <= 1 Integer
# 0 <= x(4,4,1) <= 1 Integer
# 0 <= x(4,4,2) <= 1 Integer
# 0 <= x(4,4,3) <= 1 Integer
# 0 <= x(4,5,0) <= 1 Integer
# 0 <= x(4,5,1) <= 1 Integer
# 0 <= x(4,5,2) <= 1 Integer
# 0 <= x(4,5,3) <= 1 Integer
# 0 <= x(4,6,0) <= 1 Integer
# 0 <= x(4,6,1) <= 1 Integer
# 0 <= x(4,6,2) <= 1 Integer
# 0 <= x(4,6,3) <= 1 Integer
# 0 <= x(4,7,0) <= 1 Integer
# 0 <= x(4,7,1) <= 1 Integer
# 0 <= x(4,7,2) <= 1 Integer
# 0 <= x(4,7,3) <= 1 Integer
# 0 <= x(4,8,0) <= 1 Integer
# 0 <= x(4,8,1) <= 1 Integer
# 0 <= x(4,8,2) <= 1 Integer
# 0 <= x(4,8,3) <= 1 Integer
# 0 <= x(4,9,0) <= 1 Integer
# 0 <= x(4,9,1) <= 1 Integer
# 0 <= x(4,9,2) <= 1 Integer
# 0 <= x(4,9,3) <= 1 Integer
# 0 <= x(5,0,0) <= 1 Integer
# 0 <= x(5,0,1) <= 1 Integer
# 0 <= x(5,0,2) <= 1 Integer
# 0 <= x(5,0,3) <= 1 Integer
# 0 <= x(5,1,0) <= 1 Integer
# 0 <= x(5,1,1) <= 1 Integer
# 0 <= x(5,1,2) <= 1 Integer
# 0 <= x(5,1,3) <= 1 Integer
# 0 <= x(5,10,0) <= 1 Integer
# 0 <= x(5,10,1) <= 1 Integer
# 0 <= x(5,10,2) <= 1 Integer
# 0 <= x(5,10,3) <= 1 Integer
# 0 <= x(5,11,0) <= 1 Integer
# 0 <= x(5,11,1) <= 1 Integer
# 0 <= x(5,11,2) <= 1 Integer
# 0 <= x(5,11,3) <= 1 Integer
# 0 <= x(5,12,0) <= 1 Integer
# 0 <= x(5,12,1) <= 1 Integer
# 0 <= x(5,12,2) <= 1 Integer
# 0 <= x(5,12,3) <= 1 Integer
# 0 <= x(5,2,0) <= 1 Integer
# 0 <= x(5,2,1) <= 1 Integer
# 0 <= x(5,2,2) <= 1 Integer
# 0 <= x(5,2,3) <= 1 Integer
# 0 <= x(5,3,0) <= 1 Integer
# 0 <= x(5,3,1) <= 1 Integer
# 0 <= x(5,3,2) <= 1 Integer
# 0 <= x(5,3,3) <= 1 Integer
# 0 <= x(5,4,0) <= 1 Integer
# 0 <= x(5,4,1) <= 1 Integer
# 0 <= x(5,4,2) <= 1 Integer
# 0 <= x(5,4,3) <= 1 Integer
# 0 <= x(5,5,0) <= 1 Integer
# 0 <= x(5,5,1) <= 1 Integer
# 0 <= x(5,5,2) <= 1 Integer
# 0 <= x(5,5,3) <= 1 Integer
# 0 <= x(5,6,0) <= 1 Integer
# 0 <= x(5,6,1) <= 1 Integer
# 0 <= x(5,6,2) <= 1 Integer
# 0 <= x(5,6,3) <= 1 Integer
# 0 <= x(5,7,0) <= 1 Integer
# 0 <= x(5,7,1) <= 1 Integer
# 0 <= x(5,7,2) <= 1 Integer
# 0 <= x(5,7,3) <= 1 Integer
# 0 <= x(5,8,0) <= 1 Integer
# 0 <= x(5,8,1) <= 1 Integer
# 0 <= x(5,8,2) <= 1 Integer
# 0 <= x(5,8,3) <= 1 Integer
# 0 <= x(5,9,0) <= 1 Integer
# 0 <= x(5,9,1) <= 1 Integer
# 0 <= x(5,9,2) <= 1 Integer
# 0 <= x(5,9,3) <= 1 Integer
# 0 <= x(6,0,0) <= 1 Integer
# 0 <= x(6,0,1) <= 1 Integer
# 0 <= x(6,0,2) <= 1 Integer
# 0 <= x(6,0,3) <= 1 Integer
# 0 <= x(6,1,0) <= 1 Integer
# 0 <= x(6,1,1) <= 1 Integer
# 0 <= x(6,1,2) <= 1 Integer
# 0 <= x(6,1,3) <= 1 Integer
# 0 <= x(6,10,0) <= 1 Integer
# 0 <= x(6,10,1) <= 1 Integer
# 0 <= x(6,10,2) <= 1 Integer
# 0 <= x(6,10,3) <= 1 Integer
# 0 <= x(6,11,0) <= 1 Integer
# 0 <= x(6,11,1) <= 1 Integer
# 0 <= x(6,11,2) <= 1 Integer
# 0 <= x(6,11,3) <= 1 Integer
# 0 <= x(6,12,0) <= 1 Integer
# 0 <= x(6,12,1) <= 1 Integer
# 0 <= x(6,12,2) <= 1 Integer
# 0 <= x(6,12,3) <= 1 Integer
# 0 <= x(6,2,0) <= 1 Integer
# 0 <= x(6,2,1) <= 1 Integer
# 0 <= x(6,2,2) <= 1 Integer
# 0 <= x(6,2,3) <= 1 Integer
# 0 <= x(6,3,0) <= 1 Integer
# 0 <= x(6,3,1) <= 1 Integer
# 0 <= x(6,3,2) <= 1 Integer
# 0 <= x(6,3,3) <= 1 Integer
# 0 <= x(6,4,0) <= 1 Integer
# 0 <= x(6,4,1) <= 1 Integer
# 0 <= x(6,4,2) <= 1 Integer
# 0 <= x(6,4,3) <= 1 Integer
# 0 <= x(6,5,0) <= 1 Integer
# 0 <= x(6,5,1) <= 1 Integer
# 0 <= x(6,5,2) <= 1 Integer
# 0 <= x(6,5,3) <= 1 Integer
# 0 <= x(6,6,0) <= 1 Integer
# 0 <= x(6,6,1) <= 1 Integer
# 0 <= x(6,6,2) <= 1 Integer
# 0 <= x(6,6,3) <= 1 Integer
# 0 <= x(6,7,0) <= 1 Integer
# 0 <= x(6,7,1) <= 1 Integer
# 0 <= x(6,7,2) <= 1 Integer
# 0 <= x(6,7,3) <= 1 Integer
# 0 <= x(6,8,0) <= 1 Integer
# 0 <= x(6,8,1) <= 1 Integer
# 0 <= x(6,8,2) <= 1 Integer
# 0 <= x(6,8,3) <= 1 Integer
# 0 <= x(6,9,0) <= 1 Integer
# 0 <= x(6,9,1) <= 1 Integer
# 0 <= x(6,9,2) <= 1 Integer
# 0 <= x(6,9,3) <= 1 Integer
# 0 <= x(7,0,0) <= 1 Integer
# 0 <= x(7,0,1) <= 1 Integer
# 0 <= x(7,0,2) <= 1 Integer
# 0 <= x(7,0,3) <= 1 Integer
# 0 <= x(7,1,0) <= 1 Integer
# 0 <= x(7,1,1) <= 1 Integer
# 0 <= x(7,1,2) <= 1 Integer
# 0 <= x(7,1,3) <= 1 Integer
# 0 <= x(7,10,0) <= 1 Integer
# 0 <= x(7,10,1) <= 1 Integer
# 0 <= x(7,10,2) <= 1 Integer
# 0 <= x(7,10,3) <= 1 Integer
# 0 <= x(7,11,0) <= 1 Integer
# 0 <= x(7,11,1) <= 1 Integer
# 0 <= x(7,11,2) <= 1 Integer
# 0 <= x(7,11,3) <= 1 Integer
# 0 <= x(7,12,0) <= 1 Integer
# 0 <= x(7,12,1) <= 1 Integer
# 0 <= x(7,12,2) <= 1 Integer
# 0 <= x(7,12,3) <= 1 Integer
# 0 <= x(7,2,0) <= 1 Integer
# 0 <= x(7,2,1) <= 1 Integer
# 0 <= x(7,2,2) <= 1 Integer
# 0 <= x(7,2,3) <= 1 Integer
# 0 <= x(7,3,0) <= 1 Integer
# 0 <= x(7,3,1) <= 1 Integer
# 0 <= x(7,3,2) <= 1 Integer
# 0 <= x(7,3,3) <= 1 Integer
# 0 <= x(7,4,0) <= 1 Integer
# 0 <= x(7,4,1) <= 1 Integer
# 0 <= x(7,4,2) <= 1 Integer
# 0 <= x(7,4,3) <= 1 Integer
# 0 <= x(7,5,0) <= 1 Integer
# 0 <= x(7,5,1) <= 1 Integer
# 0 <= x(7,5,2) <= 1 Integer
# 0 <= x(7,5,3) <= 1 Integer
# 0 <= x(7,6,0) <= 1 Integer
# 0 <= x(7,6,1) <= 1 Integer
# 0 <= x(7,6,2) <= 1 Integer
# 0 <= x(7,6,3) <= 1 Integer
# 0 <= x(7,7,0) <= 1 Integer
# 0 <= x(7,7,1) <= 1 Integer
# 0 <= x(7,7,2) <= 1 Integer
# 0 <= x(7,7,3) <= 1 Integer
# 0 <= x(7,8,0) <= 1 Integer
# 0 <= x(7,8,1) <= 1 Integer
# 0 <= x(7,8,2) <= 1 Integer
# 0 <= x(7,8,3) <= 1 Integer
# 0 <= x(7,9,0) <= 1 Integer
# 0 <= x(7,9,1) <= 1 Integer
# 0 <= x(7,9,2) <= 1 Integer
# 0 <= x(7,9,3) <= 1 Integer
# 0 <= x(8,0,0) <= 1 Integer
# 0 <= x(8,0,1) <= 1 Integer
# 0 <= x(8,0,2) <= 1 Integer
# 0 <= x(8,0,3) <= 1 Integer
# 0 <= x(8,1,0) <= 1 Integer
# 0 <= x(8,1,1) <= 1 Integer
# 0 <= x(8,1,2) <= 1 Integer
# 0 <= x(8,1,3) <= 1 Integer
# 0 <= x(8,10,0) <= 1 Integer
# 0 <= x(8,10,1) <= 1 Integer
# 0 <= x(8,10,2) <= 1 Integer
# 0 <= x(8,10,3) <= 1 Integer
# 0 <= x(8,11,0) <= 1 Integer
# 0 <= x(8,11,1) <= 1 Integer
# 0 <= x(8,11,2) <= 1 Integer
# 0 <= x(8,11,3) <= 1 Integer
# 0 <= x(8,12,0) <= 1 Integer
# 0 <= x(8,12,1) <= 1 Integer
# 0 <= x(8,12,2) <= 1 Integer
# 0 <= x(8,12,3) <= 1 Integer
# 0 <= x(8,2,0) <= 1 Integer
# 0 <= x(8,2,1) <= 1 Integer
# 0 <= x(8,2,2) <= 1 Integer
# 0 <= x(8,2,3) <= 1 Integer
# 0 <= x(8,3,0) <= 1 Integer
# 0 <= x(8,3,1) <= 1 Integer
# 0 <= x(8,3,2) <= 1 Integer
# 0 <= x(8,3,3) <= 1 Integer
# 0 <= x(8,4,0) <= 1 Integer
# 0 <= x(8,4,1) <= 1 Integer
# 0 <= x(8,4,2) <= 1 Integer
# 0 <= x(8,4,3) <= 1 Integer
# 0 <= x(8,5,0) <= 1 Integer
# 0 <= x(8,5,1) <= 1 Integer
# 0 <= x(8,5,2) <= 1 Integer
# 0 <= x(8,5,3) <= 1 Integer
# 0 <= x(8,6,0) <= 1 Integer
# 0 <= x(8,6,1) <= 1 Integer
# 0 <= x(8,6,2) <= 1 Integer
# 0 <= x(8,6,3) <= 1 Integer
# 0 <= x(8,7,0) <= 1 Integer
# 0 <= x(8,7,1) <= 1 Integer
# 0 <= x(8,7,2) <= 1 Integer
# 0 <= x(8,7,3) <= 1 Integer
# 0 <= x(8,8,0) <= 1 Integer
# 0 <= x(8,8,1) <= 1 Integer
# 0 <= x(8,8,2) <= 1 Integer
# 0 <= x(8,8,3) <= 1 Integer
# 0 <= x(8,9,0) <= 1 Integer
# 0 <= x(8,9,1) <= 1 Integer
# 0 <= x(8,9,2) <= 1 Integer
# 0 <= x(8,9,3) <= 1 Integer
# 0 <= x(9,0,0) <= 1 Integer
# 0 <= x(9,0,1) <= 1 Integer
# 0 <= x(9,0,2) <= 1 Integer
# 0 <= x(9,0,3) <= 1 Integer
# 0 <= x(9,1,0) <= 1 Integer
# 0 <= x(9,1,1) <= 1 Integer
# 0 <= x(9,1,2) <= 1 Integer
# 0 <= x(9,1,3) <= 1 Integer
# 0 <= x(9,10,0) <= 1 Integer
# 0 <= x(9,10,1) <= 1 Integer
# 0 <= x(9,10,2) <= 1 Integer
# 0 <= x(9,10,3) <= 1 Integer
# 0 <= x(9,11,0) <= 1 Integer
# 0 <= x(9,11,1) <= 1 Integer
# 0 <= x(9,11,2) <= 1 Integer
# 0 <= x(9,11,3) <= 1 Integer
# 0 <= x(9,12,0) <= 1 Integer
# 0 <= x(9,12,1) <= 1 Integer
# 0 <= x(9,12,2) <= 1 Integer
# 0 <= x(9,12,3) <= 1 Integer
# 0 <= x(9,2,0) <= 1 Integer
# 0 <= x(9,2,1) <= 1 Integer
# 0 <= x(9,2,2) <= 1 Integer
# 0 <= x(9,2,3) <= 1 Integer
# 0 <= x(9,3,0) <= 1 Integer
# 0 <= x(9,3,1) <= 1 Integer
# 0 <= x(9,3,2) <= 1 Integer
# 0 <= x(9,3,3) <= 1 Integer
# 0 <= x(9,4,0) <= 1 Integer
# 0 <= x(9,4,1) <= 1 Integer
# 0 <= x(9,4,2) <= 1 Integer
# 0 <= x(9,4,3) <= 1 Integer
# 0 <= x(9,5,0) <= 1 Integer
# 0 <= x(9,5,1) <= 1 Integer
# 0 <= x(9,5,2) <= 1 Integer
# 0 <= x(9,5,3) <= 1 Integer
# 0 <= x(9,6,0) <= 1 Integer
# 0 <= x(9,6,1) <= 1 Integer
# 0 <= x(9,6,2) <= 1 Integer
# 0 <= x(9,6,3) <= 1 Integer
# 0 <= x(9,7,0) <= 1 Integer
# 0 <= x(9,7,1) <= 1 Integer
# 0 <= x(9,7,2) <= 1 Integer
# 0 <= x(9,7,3) <= 1 Integer
# 0 <= x(9,8,0) <= 1 Integer
# 0 <= x(9,8,1) <= 1 Integer
# 0 <= x(9,8,2) <= 1 Integer
# 0 <= x(9,8,3) <= 1 Integer
# 0 <= x(9,9,0) <= 1 Integer
# 0 <= x(9,9,1) <= 1 Integer
# 0 <= x(9,9,2) <= 1 Integer
# 0 <= x(9,9,3) <= 1 Integer
# y(0,0) Continuous
# y(0,1) Continuous
# y(0,10) Continuous
# y(0,11) Continuous
# y(0,12) Continuous
# y(0,2) Continuous
# y(0,3) Continuous
# y(0,4) Continuous
# y(0,5) Continuous
# y(0,6) Continuous
# y(0,7) Continuous
# y(0,8) Continuous
# y(0,9) Continuous
# y(1,0) Continuous
# y(1,1) Continuous
# y(1,10) Continuous
# y(1,11) Continuous
# y(1,12) Continuous
# y(1,2) Continuous
# y(1,3) Continuous
# y(1,4) Continuous
# y(1,5) Continuous
# y(1,6) Continuous
# y(1,7) Continuous
# y(1,8) Continuous
# y(1,9) Continuous
# y(10,0) Continuous
# y(10,1) Continuous
# y(10,10) Continuous
# y(10,11) Continuous
# y(10,12) Continuous
# y(10,2) Continuous
# y(10,3) Continuous
# y(10,4) Continuous
# y(10,5) Continuous
# y(10,6) Continuous
# y(10,7) Continuous
# y(10,8) Continuous
# y(10,9) Continuous
# y(11,0) Continuous
# y(11,1) Continuous
# y(11,10) Continuous
# y(11,11) Continuous
# y(11,12) Continuous
# y(11,2) Continuous
# y(11,3) Continuous
# y(11,4) Continuous
# y(11,5) Continuous
# y(11,6) Continuous
# y(11,7) Continuous
# y(11,8) Continuous
# y(11,9) Continuous
# y(12,0) Continuous
# y(12,1) Continuous
# y(12,10) Continuous
# y(12,11) Continuous
# y(12,12) Continuous
# y(12,2) Continuous
# y(12,3) Continuous
# y(12,4) Continuous
# y(12,5) Continuous
# y(12,6) Continuous
# y(12,7) Continuous
# y(12,8) Continuous
# y(12,9) Continuous
# y(2,0) Continuous
# y(2,1) Continuous
# y(2,10) Continuous
# y(2,11) Continuous
# y(2,12) Continuous
# y(2,2) Continuous
# y(2,3) Continuous
# y(2,4) Continuous
# y(2,5) Continuous
# y(2,6) Continuous
# y(2,7) Continuous
# y(2,8) Continuous
# y(2,9) Continuous
# y(3,0) Continuous
# y(3,1) Continuous
# y(3,10) Continuous
# y(3,11) Continuous
# y(3,12) Continuous
# y(3,2) Continuous
# y(3,3) Continuous
# y(3,4) Continuous
# y(3,5) Continuous
# y(3,6) Continuous
# y(3,7) Continuous
# y(3,8) Continuous
# y(3,9) Continuous
# y(4,0) Continuous
# y(4,1) Continuous
# y(4,10) Continuous
# y(4,11) Continuous
# y(4,12) Continuous
# y(4,2) Continuous
# y(4,3) Continuous
# y(4,4) Continuous
# y(4,5) Continuous
# y(4,6) Continuous
# y(4,7) Continuous
# y(4,8) Continuous
# y(4,9) Continuous
# y(5,0) Continuous
# y(5,1) Continuous
# y(5,10) Continuous
# y(5,11) Continuous
# y(5,12) Continuous
# y(5,2) Continuous
# y(5,3) Continuous
# y(5,4) Continuous
# y(5,5) Continuous
# y(5,6) Continuous
# y(5,7) Continuous
# y(5,8) Continuous
# y(5,9) Continuous
# y(6,0) Continuous
# y(6,1) Continuous
# y(6,10) Continuous
# y(6,11) Continuous
# y(6,12) Continuous
# y(6,2) Continuous
# y(6,3) Continuous
# y(6,4) Continuous
# y(6,5) Continuous
# y(6,6) Continuous
# y(6,7) Continuous
# y(6,8) Continuous
# y(6,9) Continuous
# y(7,0) Continuous
# y(7,1) Continuous
# y(7,10) Continuous
# y(7,11) Continuous
# y(7,12) Continuous
# y(7,2) Continuous
# y(7,3) Continuous
# y(7,4) Continuous
# y(7,5) Continuous
# y(7,6) Continuous
# y(7,7) Continuous
# y(7,8) Continuous
# y(7,9) Continuous
# y(8,0) Continuous
# y(8,1) Continuous
# y(8,10) Continuous
# y(8,11) Continuous
# y(8,12) Continuous
# y(8,2) Continuous
# y(8,3) Continuous
# y(8,4) Continuous
# y(8,5) Continuous
# y(8,6) Continuous
# y(8,7) Continuous
# y(8,8) Continuous
# y(8,9) Continuous
# y(9,0) Continuous
# y(9,1) Continuous
# y(9,10) Continuous
# y(9,11) Continuous
# y(9,12) Continuous
# y(9,2) Continuous
# y(9,3) Continuous
# y(9,4) Continuous
# y(9,5) Continuous
# y(9,6) Continuous
# y(9,7) Continuous
# y(9,8) Continuous
# y(9,9) Continuous
# z(0,0) Continuous
# z(0,1) Continuous
# z(0,10) Continuous
# z(0,11) Continuous
# z(0,12) Continuous
# z(0,2) Continuous
# z(0,3) Continuous
# z(0,4) Continuous
# z(0,5) Continuous
# z(0,6) Continuous
# z(0,7) Continuous
# z(0,8) Continuous
# z(0,9) Continuous
# z(1,0) Continuous
# z(1,1) Continuous
# z(1,10) Continuous
# z(1,11) Continuous
# z(1,12) Continuous
# z(1,2) Continuous
# z(1,3) Continuous
# z(1,4) Continuous
# z(1,5) Continuous
# z(1,6) Continuous
# z(1,7) Continuous
# z(1,8) Continuous
# z(1,9) Continuous
# z(10,0) Continuous
# z(10,1) Continuous
# z(10,10) Continuous
# z(10,11) Continuous
# z(10,12) Continuous
# z(10,2) Continuous
# z(10,3) Continuous
# z(10,4) Continuous
# z(10,5) Continuous
# z(10,6) Continuous
# z(10,7) Continuous
# z(10,8) Continuous
# z(10,9) Continuous
# z(11,0) Continuous
# z(11,1) Continuous
# z(11,10) Continuous
# z(11,11) Continuous
# z(11,12) Continuous
# z(11,2) Continuous
# z(11,3) Continuous
# z(11,4) Continuous
# z(11,5) Continuous
# z(11,6) Continuous
# z(11,7) Continuous
# z(11,8) Continuous
# z(11,9) Continuous
# z(12,0) Continuous
# z(12,1) Continuous
# z(12,10) Continuous
# z(12,11) Continuous
# z(12,12) Continuous
# z(12,2) Continuous
# z(12,3) Continuous
# z(12,4) Continuous
# z(12,5) Continuous
# z(12,6) Continuous
# z(12,7) Continuous
# z(12,8) Continuous
# z(12,9) Continuous
# z(2,0) Continuous
# z(2,1) Continuous
# z(2,10) Continuous
# z(2,11) Continuous
# z(2,12) Continuous
# z(2,2) Continuous
# z(2,3) Continuous
# z(2,4) Continuous
# z(2,5) Continuous
# z(2,6) Continuous
# z(2,7) Continuous
# z(2,8) Continuous
# z(2,9) Continuous
# z(3,0) Continuous
# z(3,1) Continuous
# z(3,10) Continuous
# z(3,11) Continuous
# z(3,12) Continuous
# z(3,2) Continuous
# z(3,3) Continuous
# z(3,4) Continuous
# z(3,5) Continuous
# z(3,6) Continuous
# z(3,7) Continuous
# z(3,8) Continuous
# z(3,9) Continuous
# z(4,0) Continuous
# z(4,1) Continuous
# z(4,10) Continuous
# z(4,11) Continuous
# z(4,12) Continuous
# z(4,2) Continuous
# z(4,3) Continuous
# z(4,4) Continuous
# z(4,5) Continuous
# z(4,6) Continuous
# z(4,7) Continuous
# z(4,8) Continuous
# z(4,9) Continuous
# z(5,0) Continuous
# z(5,1) Continuous
# z(5,10) Continuous
# z(5,11) Continuous
# z(5,12) Continuous
# z(5,2) Continuous
# z(5,3) Continuous
# z(5,4) Continuous
# z(5,5) Continuous
# z(5,6) Continuous
# z(5,7) Continuous
# z(5,8) Continuous
# z(5,9) Continuous
# z(6,0) Continuous
# z(6,1) Continuous
# z(6,10) Continuous
# z(6,11) Continuous
# z(6,12) Continuous
# z(6,2) Continuous
# z(6,3) Continuous
# z(6,4) Continuous
# z(6,5) Continuous
# z(6,6) Continuous
# z(6,7) Continuous
# z(6,8) Continuous
# z(6,9) Continuous
# z(7,0) Continuous
# z(7,1) Continuous
# z(7,10) Continuous
# z(7,11) Continuous
# z(7,12) Continuous
# z(7,2) Continuous
# z(7,3) Continuous
# z(7,4) Continuous
# z(7,5) Continuous
# z(7,6) Continuous
# z(7,7) Continuous
# z(7,8) Continuous
# z(7,9) Continuous
# z(8,0) Continuous
# z(8,1) Continuous
# z(8,10) Continuous
# z(8,11) Continuous
# z(8,12) Continuous
# z(8,2) Continuous
# z(8,3) Continuous
# z(8,4) Continuous
# z(8,5) Continuous
# z(8,6) Continuous
# z(8,7) Continuous
# z(8,8) Continuous
# z(8,9) Continuous
# z(9,0) Continuous
# z(9,1) Continuous
# z(9,10) Continuous
# z(9,11) Continuous
# z(9,12) Continuous
# z(9,2) Continuous
# z(9,3) Continuous
# z(9,4) Continuous
# z(9,5) Continuous
# z(9,6) Continuous
# z(9,7) Continuous
# z(9,8) Continuous
# z(9,9) Continuous
