# %% [markdown]
# ## CSCI 5654 - Linear Programming - Project
#
# ***
# #### Team Members
# #### 1. Ketan Ramesh
# #### 2. Shreyas Gopalakrishna
# ***
#
# ## Vehicle Routing Problem

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance
import random
import pulp

# %%
numberOfCustomers = 5
capacityOfVehicle = 6
numberOfVehicles = 3
C = [i for i in range(1, numberOfCustomers+1)] #set of customers
V = [0] + C + [numberOfCustomers+1] #depot + customer nodes
demandOfCustomers = {i: np.random.randint(1, 10) for i in C}
demandOfCustomers[0] = 0
demandOfCustomers[numberOfCustomers+1] = 0

# %%
#   [0 1 2 3 0]
# 0 [i 1 1 1 0]
# 1 [1 i 1 1 1]
# 2 [1 1 i 1 1]
# 3 [1 1 1 i 1]
# 0 [0 1 1 1 i]

# %%
# Creating random coordinates
xCoordinates = np.random.rand(len(V))*1000
yCoordinates = np.random.rand(len(V))*1000

# Cost matrix
costMatrix = np.ndarray(shape=(len(V),len(V)))
for i in range(len(V)):
    for j in range(len(V)):
        if(i == 0 and j == len(V)-1):
            costMatrix[i][j] = 0
            continue
        
        if(j == 0 and i == len(V)-1):
            costMatrix[i][j] = 0
            continue
        
        if(i!=j):
            costMatrix[i][j] = int(distance.euclidean([xCoordinates[i],yCoordinates[i]], [xCoordinates[j],yCoordinates[j]]))
        else:
            costMatrix[i][j] = 999999
costMatrix
# Out:
# array([[9.99999e+05, 4.04000e+02, 3.07000e+02, 6.21000e+02, 1.18000e+02,
#         3.38000e+02, 0.00000e+00],
#        [4.04000e+02, 9.99999e+05, 3.30000e+02, 9.24000e+02, 5.23000e+02,
#         7.33000e+02, 3.42000e+02],
#        [3.07000e+02, 3.30000e+02, 9.99999e+05, 6.13000e+02, 3.96000e+02,
#         5.24000e+02, 2.63000e+02],
#        [6.21000e+02, 9.24000e+02, 6.13000e+02, 9.99999e+05, 5.66000e+02,
#         3.91000e+02, 6.51000e+02],
#        [1.18000e+02, 5.23000e+02, 3.96000e+02, 5.66000e+02, 9.99999e+05,
#         2.34000e+02, 1.82000e+02],
#        [3.38000e+02, 7.33000e+02, 5.24000e+02, 3.91000e+02, 2.34000e+02,
#         9.99999e+05, 3.95000e+02],
#        [0.00000e+00, 3.42000e+02, 2.63000e+02, 6.51000e+02, 1.82000e+02,
#         3.95000e+02, 9.99999e+05]])

# %%
costMatrix2 = np.copy(costMatrix)

# %%
costMatrix2
# Out:
# array([[9.99999e+05, 4.04000e+02, 3.07000e+02, 6.21000e+02, 1.18000e+02,
#         3.38000e+02, 0.00000e+00],
#        [4.04000e+02, 9.99999e+05, 3.30000e+02, 9.24000e+02, 5.23000e+02,
#         7.33000e+02, 3.42000e+02],
#        [3.07000e+02, 3.30000e+02, 9.99999e+05, 6.13000e+02, 3.96000e+02,
#         5.24000e+02, 2.63000e+02],
#        [6.21000e+02, 9.24000e+02, 6.13000e+02, 9.99999e+05, 5.66000e+02,
#         3.91000e+02, 6.51000e+02],
#        [1.18000e+02, 5.23000e+02, 3.96000e+02, 5.66000e+02, 9.99999e+05,
#         2.34000e+02, 1.82000e+02],
#        [3.38000e+02, 7.33000e+02, 5.24000e+02, 3.91000e+02, 2.34000e+02,
#         9.99999e+05, 3.95000e+02],
#        [0.00000e+00, 3.42000e+02, 2.63000e+02, 6.51000e+02, 1.82000e+02,
#         3.95000e+02, 9.99999e+05]])

# %%
len(costMatrix)
print(costMatrix[0][1]+costMatrix[1][3]+costMatrix[3][2]+costMatrix[2][4])
# Out:
# 2337.0

# %%
# PuLP class for vehicle routing

class CVRP:
    def __init__(self, numberOfCustomers, numberOfVehicles, capacityOfVehicle, demandOfCustomers, costMatrix):
        self.numberOfCustomers = numberOfCustomers
        self.numberOfVehicles  = numberOfVehicles
        self.capacityOfVehicle = capacityOfVehicle
        self.demandOfCustomers = demandOfCustomers
        self.costMatrix        = costMatrix
        self.initializeLP()
    
    def initializeLP(self):
        self.cvrpLP = pulp.LpProblem("CVRP", pulp.LpMinimize)
        objective = None
        x,y = [], []
        constraint1 = None
        
        # objective function and variables
        for i in range(len(costMatrix)): #adding depot
            xTemp1 = []
            for j in range(len(costMatrix)):
#                 if(i != j):
                xTemp2 = pulp.LpVariable('x('+str(i)+','+str(j)+')', cat='Binary')
                xTemp1.append(xTemp2)
#                 if(i != j):
                objective += xTemp2 * costMatrix[i][j]
#                 else:
#                     xTemp1.append(None)
            x.append(xTemp1) 
        self.cvrpLP += objective
        
        for i in range(len(costMatrix)):
            y.append(pulp.LpVariable('y'+str(i), lowBound=0, cat='Continuous'))
        
        
        # constraints
        # ensure that all customers are visited exactly once
        for i in range(1, len(costMatrix) - 1): #adding depot
            constraint1 = None
            for j in range(1, len(costMatrix)):
                if(i != j):
                    constraint1 += x[i][j]
            self.cvrpLP += constraint1 == 1
        
        # limits the maximum number of routes to the number of vehicles
        constraint2 = None
        for j in range(1, len(costMatrix) - 1): #not include depot
            constraint2 += x[0][j]
        self.cvrpLP += constraint2 <= self.numberOfVehicles
        
        # ensure together that the vehicle capacity is not exceeded
        for i in range(len(costMatrix)):
            constarint3a, constarint3b  = None, None
#             constarint3a = self.demandOfCustomers[i] <= y[i] 
            constarint3b = y[i] <= self.capacityOfVehicle
#             self.cvrpLP += constarint3a
            self.cvrpLP += constarint3b
        
        # ensure together that the vehicle capacity is not exceeded
        for i in range(len(costMatrix)): #adding depot
            for j in range(len(costMatrix)):
                constraint4 = None
#                 if(i != j):
                constraint4 += y[j] >= y[i] + self.demandOfCustomers[j]*x[i][j] - self.capacityOfVehicle*(1-x[i][j])
                self.cvrpLP += constraint4
        
        #guarantee the correct flow of vehicles through the arcs, by stating that if a vehicle arrives to a node
        #then it must depart from this node
        for h in range(1, len(costMatrix) - 1):
            constraint5a, constraint5b = None, None
            for i in range(0, len(costMatrix) - 1):
                if(i != h):
                    constraint5a += x[i][h]
            for j in range(1, len(costMatrix)):
                if(j != h):
                    constraint5b += x[h][j]
            self.cvrpLP += constraint5a - constraint5b == 0
        
        print(self.cvrpLP)
        
    def solve(self):
        status = self.cvrpLP.solve()
        print(pulp.LpStatus[self.cvrpLP.status])
    
    def getResult(self):
        print("Objective value: ", pulp.value(self.cvrpLP.objective))
        for v in self.cvrpLP.variables():
            print(v.name, " = ", v.varValue)

# %%
lp = CVRP(numberOfCustomers, numberOfVehicles, capacityOfVehicle, demandOfCustomers, costMatrix)
# Out:
# CVRP:
# MINIMIZE
# 999999.0*x(0,0) + 404.0*x(0,1) + 307.0*x(0,2) + 621.0*x(0,3) + 118.0*x(0,4) + 338.0*x(0,5) + 404.0*x(1,0) + 999999.0*x(1,1) + 330.0*x(1,2) + 924.0*x(1,3) + 523.0*x(1,4) + 733.0*x(1,5) + 342.0*x(1,6) + 307.0*x(2,0) + 330.0*x(2,1) + 999999.0*x(2,2) + 613.0*x(2,3) + 396.0*x(2,4) + 524.0*x(2,5) + 263.0*x(2,6) + 621.0*x(3,0) + 924.0*x(3,1) + 613.0*x(3,2) + 999999.0*x(3,3) + 566.0*x(3,4) + 391.0*x(3,5) + 651.0*x(3,6) + 118.0*x(4,0) + 523.0*x(4,1) + 396.0*x(4,2) + 566.0*x(4,3) + 999999.0*x(4,4) + 234.0*x(4,5) + 182.0*x(4,6) + 338.0*x(5,0) + 733.0*x(5,1) + 524.0*x(5,2) + 391.0*x(5,3) + 234.0*x(5,4) + 999999.0*x(5,5) + 395.0*x(5,6) + 342.0*x(6,1) + 263.0*x(6,2) + 651.0*x(6,3) + 182.0*x(6,4) + 395.0*x(6,5) + 999999.0*x(6,6) + 0.0
# SUBJECT TO
# _C1: x(1,2) + x(1,3) + x(1,4) + x(1,5) + x(1,6) = 1
#
# _C2: x(2,1) + x(2,3) + x(2,4) + x(2,5) + x(2,6) = 1
#
# _C3: x(3,1) + x(3,2) + x(3,4) + x(3,5) + x(3,6) = 1
#
# _C4: x(4,1) + x(4,2) + x(4,3) + x(4,5) + x(4,6) = 1
#
# _C5: x(5,1) + x(5,2) + x(5,3) + x(5,4) + x(5,6) = 1
#
# _C6: x(0,1) + x(0,2) + x(0,3) + x(0,4) + x(0,5) <= 3
#
# _C7: y0 >= 0
#
# _C8: y0 <= 6
#
# _C9: y1 >= 6
#
# _C10: y1 <= 6
#
# _C11: y2 >= 5
#
# _C12: y2 <= 6
#
# _C13: y3 >= 1
#
# _C14: y3 <= 6
#
# _C15: y4 >= 1
#
# _C16: y4 <= 6
#
# _C17: y5 >= 5
#
# _C18: y5 <= 6
#
# _C19: y6 >= 0
#
# _C20: y6 <= 6
#
# _C21: - 6 x(0,0) + 0 y0 >= -6
#
# _C22: - 12 x(0,1) - y0 + y1 >= -6
#
# _C23: - 11 x(0,2) - y0 + y2 >= -6
#
# _C24: - 7 x(0,3) - y0 + y3 >= -6
#
# _C25: - 7 x(0,4) - y0 + y4 >= -6
#
# _C26: - 11 x(0,5) - y0 + y5 >= -6
#
# _C27: - 6 x(0,6) - y0 + y6 >= -6
#
# _C28: - 6 x(1,0) + y0 - y1 >= -6
#
# _C29: - 12 x(1,1) + 0 y1 >= -6
#
# _C30: - 11 x(1,2) - y1 + y2 >= -6
#
# _C31: - 7 x(1,3) - y1 + y3 >= -6
#
# _C32: - 7 x(1,4) - y1 + y4 >= -6
#
# _C33: - 11 x(1,5) - y1 + y5 >= -6
#
# _C34: - 6 x(1,6) - y1 + y6 >= -6
#
# _C35: - 6 x(2,0) + y0 - y2 >= -6
#
# _C36: - 12 x(2,1) + y1 - y2 >= -6
#
# _C37: - 11 x(2,2) + 0 y2 >= -6
#
# _C38: - 7 x(2,3) - y2 + y3 >= -6
#
# _C39: - 7 x(2,4) - y2 + y4 >= -6
#
# _C40: - 11 x(2,5) - y2 + y5 >= -6
#
# _C41: - 6 x(2,6) - y2 + y6 >= -6
#
# _C42: - 6 x(3,0) + y0 - y3 >= -6
#
# _C43: - 12 x(3,1) + y1 - y3 >= -6
#
# _C44: - 11 x(3,2) + y2 - y3 >= -6
#
# _C45: - 7 x(3,3) + 0 y3 >= -6
#
# _C46: - 7 x(3,4) - y3 + y4 >= -6
#
# _C47: - 11 x(3,5) - y3 + y5 >= -6
#
# _C48: - 6 x(3,6) - y3 + y6 >= -6
#
# _C49: - 6 x(4,0) + y0 - y4 >= -6
#
# _C50: - 12 x(4,1) + y1 - y4 >= -6
#
# _C51: - 11 x(4,2) + y2 - y4 >= -6
#
# _C52: - 7 x(4,3) + y3 - y4 >= -6
#
# _C53: - 7 x(4,4) + 0 y4 >= -6
#
# _C54: - 11 x(4,5) - y4 + y5 >= -6
#
# _C55: - 6 x(4,6) - y4 + y6 >= -6
#
# _C56: - 6 x(5,0) + y0 - y5 >= -6
#
# _C57: - 12 x(5,1) + y1 - y5 >= -6
#
# _C58: - 11 x(5,2) + y2 - y5 >= -6
#
# _C59: - 7 x(5,3) + y3 - y5 >= -6
#
# _C60: - 7 x(5,4) + y4 - y5 >= -6
#
# _C61: - 11 x(5,5) + 0 y5 >= -6
#
# _C62: - 6 x(5,6) - y5 + y6 >= -6
#
# _C63: - 6 x(6,0) + y0 - y6 >= -6
#
# _C64: - 12 x(6,1) + y1 - y6 >= -6
#
# _C65: - 11 x(6,2) + y2 - y6 >= -6
#
# _C66: - 7 x(6,3) + y3 - y6 >= -6
#
# _C67: - 7 x(6,4) + y4 - y6 >= -6
#
# _C68: - 11 x(6,5) + y5 - y6 >= -6
#
# _C69: - 6 x(6,6) + 0 y6 >= -6
#
# _C70: x(0,1) - x(1,2) - x(1,3) - x(1,4) - x(1,5) - x(1,6) + x(2,1) + x(3,1)
#  + x(4,1) + x(5,1) = 0
#
# _C71: x(0,2) + x(1,2) - x(2,1) - x(2,3) - x(2,4) - x(2,5) - x(2,6) + x(3,2)
#  + x(4,2) + x(5,2) = 0
#
# _C72: x(0,3) + x(1,3) + x(2,3) - x(3,1) - x(3,2) - x(3,4) - x(3,5) - x(3,6)
#  + x(4,3) + x(5,3) = 0
#
# _C73: x(0,4) + x(1,4) + x(2,4) + x(3,4) - x(4,1) - x(4,2) - x(4,3) - x(4,5)
#  - x(4,6) + x(5,4) = 0
#
# _C74: x(0,5) + x(1,5) + x(2,5) + x(3,5) + x(4,5) - x(5,1) - x(5,2) - x(5,3)
#  - x(5,4) - x(5,6) = 0
#
# VARIABLES
# 0 <= x(0,0) <= 1 Integer
# 0 <= x(0,1) <= 1 Integer
# 0 <= x(0,2) <= 1 Integer
# 0 <= x(0,3) <= 1 Integer
# 0 <= x(0,4) <= 1 Integer
# 0 <= x(0,5) <= 1 Integer
# 0 <= x(0,6) <= 1 Integer
# 0 <= x(1,0) <= 1 Integer
# 0 <= x(1,1) <= 1 Integer
# 0 <= x(1,2) <= 1 Integer
# 0 <= x(1,3) <= 1 Integer
# 0 <= x(1,4) <= 1 Integer
# 0 <= x(1,5) <= 1 Integer
# 0 <= x(1,6) <= 1 Integer
# 0 <= x(2,0) <= 1 Integer
# 0 <= x(2,1) <= 1 Integer
# 0 <= x(2,2) <= 1 Integer
# 0 <= x(2,3) <= 1 Integer
# 0 <= x(2,4) <= 1 Integer
# 0 <= x(2,5) <= 1 Integer
# 0 <= x(2,6) <= 1 Integer
# 0 <= x(3,0) <= 1 Integer
# 0 <= x(3,1) <= 1 Integer
# 0 <= x(3,2) <= 1 Integer
# 0 <= x(3,3) <= 1 Integer
# 0 <= x(3,4) <= 1 Integer
# 0 <= x(3,5) <= 1 Integer
# 0 <= x(3,6) <= 1 Integer
# 0 <= x(4,0) <= 1 Integer
# 0 <= x(4,1) <= 1 Integer
# 0 <= x(4,2) <= 1 Integer
# 0 <= x(4,3) <= 1 Integer
# 0 <= x(4,4) <= 1 Integer
# 0 <= x(4,5) <= 1 Integer
# 0 <= x(4,6) <= 1 Integer
# 0 <= x(5,0) <= 1 Integer
# 0 <= x(5,1) <= 1 Integer
# 0 <= x(5,2) <= 1 Integer
# 0 <= x(5,3) <= 1 Integer
# 0 <= x(5,4) <= 1 Integer
# 0 <= x(5,5) <= 1 Integer
# 0 <= x(5,6) <= 1 Integer
# 0 <= x(6,0) <= 1 Integer
# 0 <= x(6,1) <= 1 Integer
# 0 <= x(6,2) <= 1 Integer
# 0 <= x(6,3) <= 1 Integer
# 0 <= x(6,4) <= 1 Integer
# 0 <= x(6,5) <= 1 Integer
# 0 <= x(6,6) <= 1 Integer
# y0 Continuous
# y1 Continuous
# y2 Continuous
# y3 Continuous
# y4 Continuous
# y5 Continuous
# y6 Continuous

# %%
lp.solve()
lp.getResult()
# Out:
# Optimal
# Objective value:  2903.0
# x(0,0)  =  0.0
# x(0,1)  =  1.0
# x(0,2)  =  0.0
# x(0,3)  =  0.0
# x(0,4)  =  1.0
# x(0,5)  =  1.0
# x(0,6)  =  0.0
# x(1,0)  =  0.0
# x(1,1)  =  0.0
# x(1,2)  =  0.0
# x(1,3)  =  0.0
# x(1,4)  =  0.0
# x(1,5)  =  0.0
# x(1,6)  =  1.0
# x(2,0)  =  0.0
# x(2,1)  =  0.0
# x(2,2)  =  0.0
# x(2,3)  =  0.0
# x(2,4)  =  0.0
# x(2,5)  =  0.0
# x(2,6)  =  1.0
# x(3,0)  =  0.0
# x(3,1)  =  0.0
# x(3,2)  =  0.0
# x(3,3)  =  0.0
# x(3,4)  =  0.0
# x(3,5)  =  0.0
# x(3,6)  =  1.0
# x(4,0)  =  0.0
# x(4,1)  =  0.0
# x(4,2)  =  1.0
# x(4,3)  =  0.0
# x(4,4)  =  0.0
# x(4,5)  =  0.0
# x(4,6)  =  0.0
# x(5,0)  =  0.0
# x(5,1)  =  0.0
# x(5,2)  =  0.0
# x(5,3)  =  1.0
# x(5,4)  =  0.0
# x(5,5)  =  0.0
# x(5,6)  =  0.0
# x(6,0)  =  0.0
# x(6,1)  =  0.0
# x(6,2)  =  0.0
# x(6,3)  =  0.0
# x(6,4)  =  0.0
# x(6,5)  =  0.0
# x(6,6)  =  0.0
# y0  =  0.0
# y1  =  6.0
# y2  =  6.0
# y3  =  6.0
# y4  =  1.0
# y5  =  5.0
# y6  =  6.0

# %% [markdown]
# #### TESTING

# %%
numberOfCustomers = 31
capacityOfVehicle = 100
numberOfVehicles = 5
C = [i for i in range(1, numberOfCustomers+1)] #set of customers
V = [0] + C + [numberOfCustomers+1] #depot + customer nodes
demandOfCustomers = {0:0,1:19,2:21,3:6,4:19,5:7,6:12,7:16,8:6,9:16,10:8,11:14,12:21,13:16,14:3,15:22,16:18,17:19,18:1,19:24,20:8,21:12,22:4,23:8,24:24,25:24,26:2,27:20,28:15,29:2,30:14,31:9}
# demandOfCustomers[0] = 0
demandOfCustomers[numberOfCustomers+1] = 0

# %%
xCoordinates = [82,96,50,49,13,29,58,84,14,2,3,5,98,84,61,1,88,91,19,93,50,98,5,42,61,9,80,57,23,20,85,98,82]
yCoordinates = [76,44,5,8,7,89,30,39,24,39,82,10,52,25,59,65,51,2,32,3,93,14,42,9,62,97,55,69,15,70,60,5,76]

# Cost matrix
costMatrix = np.ndarray(shape=(len(V),len(V)))
for i in range(len(V)):
    for j in range(len(V)):
        if(i == 0 and j == len(V)-1):
            costMatrix[i][j] = 0
            continue
        
        if(j == 0 and i == len(V)-1):
            costMatrix[i][j] = 0
            continue
        
        if(i!=j):
            costMatrix[i][j] = int(distance.euclidean([xCoordinates[i],yCoordinates[i]], [xCoordinates[j],yCoordinates[j]]))
        else:
            costMatrix[i][j] = 999999

# %%
len(costMatrix[0])
# Out:
# 33

# %%
lp = CVRP(numberOfCustomers, numberOfVehicles, capacityOfVehicle, demandOfCustomers, costMatrix)
# Out:
# CVRP:
# MINIMIZE
# 999999.0*x(0,0) + 34.0*x(0,1) + 79.0*x(0,10) + 101.0*x(0,11) + 28.0*x(0,12) + 51.0*x(0,13) + 27.0*x(0,14) + 81.0*x(0,15) + 25.0*x(0,16) + 74.0*x(0,17) + 76.0*x(0,18) + 73.0*x(0,19) + 77.0*x(0,2) + 36.0*x(0,20) + 64.0*x(0,21) + 84.0*x(0,22) + 78.0*x(0,23) + 25.0*x(0,24) + 75.0*x(0,25) + 21.0*x(0,26) + 25.0*x(0,27) + 84.0*x(0,28) + 62.0*x(0,29) + 75.0*x(0,3) + 16.0*x(0,30) + 72.0*x(0,31) + 97.0*x(0,4) + 54.0*x(0,5) + 51.0*x(0,6) + 37.0*x(0,7) + 85.0*x(0,8) + 88.0*x(0,9) + 34.0*x(1,0) + 999999.0*x(1,1) + 100.0*x(1,10) + 97.0*x(1,11) + 8.0*x(1,12) + 22.0*x(1,13) + 38.0*x(1,14) + 97.0*x(1,15) + 10.0*x(1,16) + 42.0*x(1,17) + 77.0*x(1,18) + 41.0*x(1,19) + 60.0*x(1,2) + 67.0*x(1,20) + 30.0*x(1,21) + 91.0*x(1,22) + 64.0*x(1,23) + 39.0*x(1,24) + 101.0*x(1,25) + 19.0*x(1,26) + 46.0*x(1,27) + 78.0*x(1,28) + 80.0*x(1,29) + 59.0*x(1,3) + 19.0*x(1,30) + 39.0*x(1,31) + 34.0*x(1,32) + 90.0*x(1,4) + 80.0*x(1,5) + 40.0*x(1,6) + 13.0*x(1,7) + 84.0*x(1,8) + 94.0*x(1,9) + 79.0*x(10,0) + 100.0*x(10,1) + 999999.0*x(10,10) + 72.0*x(10,11) + 99.0*x(10,12) + 99.0*x(10,13) + 62.0*x(10,14) + 17.0*x(10,15) + 90.0*x(10,16) + 118.0*x(10,17) + 52.0*x(10,18) + 119.0*x(10,19) + 90.0*x(10,2) + 48.0*x(10,20) + 116.0*x(10,21) + 40.0*x(10,22) + 82.0*x(10,23) + 61.0*x(10,24) + 16.0*x(10,25) + 81.0*x(10,26) + 55.0*x(10,27) + 69.0*x(10,28) + 20.0*x(10,29) + 87.0*x(10,3) + 84.0*x(10,30) + 122.0*x(10,31) + 79.0*x(10,32) + 75.0*x(10,4) + 26.0*x(10,5) + 75.0*x(10,6) + 91.0*x(10,7) + 59.0*x(10,8) + 43.0*x(10,9) + 101.0*x(11,0) + 97.0*x(11,1) + 72.0*x(11,10) + 999999.0*x(11,11) + 102.0*x(11,12) + 80.0*x(11,13) + 74.0*x(11,14) + 55.0*x(11,15) + 92.0*x(11,16) + 86.0*x(11,17) + 26.0*x(11,18) + 88.0*x(11,19) + 45.0*x(11,2) + 94.0*x(11,20) + 93.0*x(11,21) + 32.0*x(11,22) + 37.0*x(11,23) + 76.0*x(11,24) + 87.0*x(11,25) + 87.0*x(11,26) + 78.0*x(11,27) + 18.0*x(11,28) + 61.0*x(11,29) + 44.0*x(11,3) + 94.0*x(11,30) + 93.0*x(11,31) + 101.0*x(11,32) + 8.0*x(11,4) + 82.0*x(11,5) + 56.0*x(11,6) + 84.0*x(11,7) + 16.0*x(11,8) + 29.0*x(11,9) + 28.0*x(12,0) + 8.0*x(12,1) + 99.0*x(12,10) + 102.0*x(12,11) + 999999.0*x(12,12) + 30.0*x(12,13) + 37.0*x(12,14) + 97.0*x(12,15) + 10.0*x(12,16) + 50.0*x(12,17) + 81.0*x(12,18) + 49.0*x(12,19) + 67.0*x(12,2) + 63.0*x(12,20) + 38.0*x(12,21) + 93.0*x(12,22) + 70.0*x(12,23) + 38.0*x(12,24) + 99.0*x(12,25) + 18.0*x(12,26) + 44.0*x(12,27) + 83.0*x(12,28) + 80.0*x(12,29) + 65.0*x(12,3) + 15.0*x(12,30) + 47.0*x(12,31) + 28.0*x(12,32) + 96.0*x(12,4) + 78.0*x(12,5) + 45.0*x(12,6) + 19.0*x(12,7) + 88.0*x(12,8) + 96.0*x(12,9) + 51.0*x(13,0) + 22.0*x(13,1) + 99.0*x(13,10) + 80.0*x(13,11) + 30.0*x(13,12) + 999999.0*x(13,13) + 41.0*x(13,14) + 92.0*x(13,15) + 26.0*x(13,16) + 24.0*x(13,17) + 65.0*x(13,18) + 23.0*x(13,19) + 39.0*x(13,2) + 76.0*x(13,20) + 17.0*x(13,21) + 80.0*x(13,22) + 44.0*x(13,23) + 43.0*x(13,24) + 103.0*x(13,25) + 30.0*x(13,26) + 51.0*x(13,27) + 61.0*x(13,28) + 78.0*x(13,29) + 38.0*x(13,3) + 35.0*x(13,30) + 24.0*x(13,31) + 51.0*x(13,32) + 73.0*x(13,4) + 84.0*x(13,5) + 26.0*x(13,6) + 14.0*x(13,7) + 70.0*x(13,8) + 83.0*x(13,9) + 27.0*x(14,0) + 38.0*x(14,1) + 62.0*x(14,10) + 74.0*x(14,11) + 37.0*x(14,12) + 41.0*x(14,13) + 999999.0*x(14,14) + 60.0*x(14,15) + 28.0*x(14,16) + 64.0*x(14,17) + 49.0*x(14,18) + 64.0*x(14,19) + 55.0*x(14,2) + 35.0*x(14,20) + 58.0*x(14,21) + 58.0*x(14,22) + 53.0*x(14,23) + 3.0*x(14,24) + 64.0*x(14,25) + 19.0*x(14,26) + 10.0*x(14,27) + 58.0*x(14,28) + 42.0*x(14,29) + 52.0*x(14,3) + 24.0*x(14,30) + 65.0*x(14,31) + 27.0*x(14,32) + 70.0*x(14,4) + 43.0*x(14,5) + 29.0*x(14,6) + 30.0*x(14,7) + 58.0*x(14,8) + 62.0*x(14,9) + 81.0*x(15,0) + 97.0*x(15,1) + 17.0*x(15,10) + 55.0*x(15,11) + 97.0*x(15,12) + 92.0*x(15,13) + 60.0*x(15,14) + 999999.0*x(15,15) + 88.0*x(15,16) + 109.0*x(15,17) + 37.0*x(15,18) + 110.0*x(15,19) + 77.0*x(15,2) + 56.0*x(15,20) + 109.0*x(15,21) + 23.0*x(15,22) + 69.0*x(15,23) + 60.0*x(15,24) + 32.0*x(15,25) + 79.0*x(15,26) + 56.0*x(15,27) + 54.0*x(15,28) + 19.0*x(15,29) + 74.0*x(15,3) + 84.0*x(15,30) + 114.0*x(15,31)  ...
# SUBJECT TO
# _C1: x(1,10) + x(1,11) + x(1,12) + x(1,13) + x(1,14) + x(1,15) + x(1,16)
#  + x(1,17) + x(1,18) + x(1,19) + x(1,2) + x(1,20) + x(1,21) + x(1,22)
#  + x(1,23) + x(1,24) + x(1,25) + x(1,26) + x(1,27) + x(1,28) + x(1,29)
#  + x(1,3) + x(1,30) + x(1,31) + x(1,32) + x(1,4) + x(1,5) + x(1,6) + x(1,7)
#  + x(1,8) + x(1,9) = 1
#
# _C2: x(2,1) + x(2,10) + x(2,11) + x(2,12) + x(2,13) + x(2,14) + x(2,15)
#  + x(2,16) + x(2,17) + x(2,18) + x(2,19) + x(2,20) + x(2,21) + x(2,22)
#  + x(2,23) + x(2,24) + x(2,25) + x(2,26) + x(2,27) + x(2,28) + x(2,29)
#  + x(2,3) + x(2,30) + x(2,31) + x(2,32) + x(2,4) + x(2,5) + x(2,6) + x(2,7)
#  + x(2,8) + x(2,9) = 1
#
# _C3: x(3,1) + x(3,10) + x(3,11) + x(3,12) + x(3,13) + x(3,14) + x(3,15)
#  + x(3,16) + x(3,17) + x(3,18) + x(3,19) + x(3,2) + x(3,20) + x(3,21)
#  + x(3,22) + x(3,23) + x(3,24) + x(3,25) + x(3,26) + x(3,27) + x(3,28)
#  + x(3,29) + x(3,30) + x(3,31) + x(3,32) + x(3,4) + x(3,5) + x(3,6) + x(3,7)
#  + x(3,8) + x(3,9) = 1
#
# _C4: x(4,1) + x(4,10) + x(4,11) + x(4,12) + x(4,13) + x(4,14) + x(4,15)
#  + x(4,16) + x(4,17) + x(4,18) + x(4,19) + x(4,2) + x(4,20) + x(4,21)
#  + x(4,22) + x(4,23) + x(4,24) + x(4,25) + x(4,26) + x(4,27) + x(4,28)
#  + x(4,29) + x(4,3) + x(4,30) + x(4,31) + x(4,32) + x(4,5) + x(4,6) + x(4,7)
#  + x(4,8) + x(4,9) = 1
#
# _C5: x(5,1) + x(5,10) + x(5,11) + x(5,12) + x(5,13) + x(5,14) + x(5,15)
#  + x(5,16) + x(5,17) + x(5,18) + x(5,19) + x(5,2) + x(5,20) + x(5,21)
#  + x(5,22) + x(5,23) + x(5,24) + x(5,25) + x(5,26) + x(5,27) + x(5,28)
#  + x(5,29) + x(5,3) + x(5,30) + x(5,31) + x(5,32) + x(5,4) + x(5,6) + x(5,7)
#  + x(5,8) + x(5,9) = 1
#
# _C6: x(6,1) + x(6,10) + x(6,11) + x(6,12) + x(6,13) + x(6,14) + x(6,15)
#  + x(6,16) + x(6,17) + x(6,18) + x(6,19) + x(6,2) + x(6,20) + x(6,21)
#  + x(6,22) + x(6,23) + x(6,24) + x(6,25) + x(6,26) + x(6,27) + x(6,28)
#  + x(6,29) + x(6,3) + x(6,30) + x(6,31) + x(6,32) + x(6,4) + x(6,5) + x(6,7)
#  + x(6,8) + x(6,9) = 1
#
# _C7: x(7,1) + x(7,10) + x(7,11) + x(7,12) + x(7,13) + x(7,14) + x(7,15)
#  + x(7,16) + x(7,17) + x(7,18) + x(7,19) + x(7,2) + x(7,20) + x(7,21)
#  + x(7,22) + x(7,23) + x(7,24) + x(7,25) + x(7,26) + x(7,27) + x(7,28)
#  + x(7,29) + x(7,3) + x(7,30) + x(7,31) + x(7,32) + x(7,4) + x(7,5) + x(7,6)
#  + x(7,8) + x(7,9) = 1
#
# _C8: x(8,1) + x(8,10) + x(8,11) + x(8,12) + x(8,13) + x(8,14) + x(8,15)
#  + x(8,16) + x(8,17) + x(8,18) + x(8,19) + x(8,2) + x(8,20) + x(8,21)
#  + x(8,22) + x(8,23) + x(8,24) + x(8,25) + x(8,26) + x(8,27) + x(8,28)
#  + x(8,29) + x(8,3) + x(8,30) + x(8,31) + x(8,32) + x(8,4) + x(8,5) + x(8,6)
#  + x(8,7) + x(8,9) = 1
#
# _C9: x(9,1) + x(9,10) + x(9,11) + x(9,12) + x(9,13) + x(9,14) + x(9,15)
#  + x(9,16) + x(9,17) + x(9,18) + x(9,19) + x(9,2) + x(9,20) + x(9,21)
#  + x(9,22) + x(9,23) + x(9,24) + x(9,25) + x(9,26) + x(9,27) + x(9,28)
#  + x(9,29) + x(9,3) + x(9,30) + x(9,31) + x(9,32) + x(9,4) + x(9,5) + x(9,6)
#  + x(9,7) + x(9,8) = 1
#
# _C10: x(10,1) + x(10,11) + x(10,12) + x(10,13) + x(10,14) + x(10,15)
#  + x(10,16) + x(10,17) + x(10,18) + x(10,19) + x(10,2) + x(10,20) + x(10,21)
#  + x(10,22) + x(10,23) + x(10,24) + x(10,25) + x(10,26) + x(10,27) + x(10,28)
#  + x(10,29) + x(10,3) + x(10,30) + x(10,31) + x(10,32) + x(10,4) + x(10,5)
#  + x(10,6) + x(10,7) + x(10,8) + x(10,9) = 1
#
# _C11: x(11,1) + x(11,10) + x(11,12) + x(11,13) + x(11,14) + x(11,15)
#  + x(11,16) + x(11,17) + x(11,18) + x(11,19) + x(11,2) + x(11,20) + x(11,21)
#  + x(11,22) + x(11,23) + x(11,24) + x(11,25) + x(11,26) + x(11,27) + x(11,28)
#  + x(11,29) + x(11,3) + x(11,30) + x(11,31) + x(11,32) + x(11,4) + x(11,5)
#  + x(11,6) + x(11,7) + x(11,8) + x(11,9) = 1
#
# _C12: x(12,1) + x(12,10) + x(12,11) + x(12,13) + x(12,14) + x(12,15)
#  + x(12,16) + x(12,17) + x(12,18) + x(12,19) + x(12,2) + x(12,20) + x(12,21)
#  + x(12,22) + x(12,23) + x(12,24) + x(12,25) + x(12,26) + x(12,27) + x(12,28)
#  + x(12,29) + x(12,3) + x(12,30) + x(12,31) + x(12,32) + x(12,4) + x(12,5)
#  + x(12,6) + x(12,7) + x(12,8) + x(12,9) = 1
#
# _C13: x(13,1) + x(13,10) + x(13,11) + x(13,12) + x(13,14) + x(13,15)
#  + x(13,16) + x(13,17) + x(13,18) + x(13,19) + x(13,2) + x(13,20) + x(13,21)
#  + x(13,22) + x(13,23) + x(13,24) + x(13,25) + x(13,26) + x(13,27) + x(13,28)
#  + x(13,29) + x(13,3) + x(13,30) + x(13,31) + x(13,32) + x(13,4) + x(13,5)
#  + x(13,6) + x(13,7) + x(13,8) + x(13,9) = 1
#
# _C14: x(14,1) + x(14,10) + x(14,11) + x(14,12) + x(14,13) + x(14,15)
#  + x(14,16) + x(14,17) + x(14,18) + x(14,19) + x(14,2) + x(14,20) + x(14,21)
#  + x(14,22) + x(14,23) + x(14,24) + x(14,25) + x(14,26) + x(14,27) + x(14,28)
#  + x(14,29) + x(14,3) + x(14,30) + x(14,31) + x(14,32) + x(14,4) + x(14,5)
#  + x(14,6) + x(14,7) + x(14,8) + x(14,9) = 1
#
# _C15: x(15,1) + x(15,10) + x(15,11) + x(15,12) + x(15,13) + x(15,14)
#  + x(15,16) + x(15,17) + x(15,18) + x(15,19) + x(15,2) + x(15,20) + x(15,21)
#  + x(15,22) + x(15,23) + x(15,24) + x(15,25) + x(15,26) + x(15,27) + x(15,28)
#  + x(15,29) + x(15,3) + x(15,30) + x(15,31) + x(15,32) + x(15,4) + x(15,5)
#  + x(15,6) + x(15,7) + x(15,8) + x(15,9) = 1
#
# _C16: x(16,1) + x(16,10) + x(16,11) + x(16,12) + x(16,13) + x(16,14)
#  + x(16,15) + x(16,17) + x(16,18) + x(16,19) + x(16,2) + x(16,20) + x(16,21)
#  + x(16,22) + x(16,23) + x(16,24) + x(16,25) + x(16,26) + x(16,27) + x(16,28)
#  + x(16,29) + x(16,3) + x(16,30) + x(16,31) + x(16,32) + x(16,4) + x(16,5)
#  + x(16,6) + x(16,7) + x(16,8) + x(16,9) = 1
#
# _C17: x(17,1) + x(17,10) + x(17,11) + x(17,12) + x(17,13) + x(17,14)
#  + x(17,15) + x(17,16) + x(17,18) + x(17,19) + x(17,2) + x(17,20) + x(17,21)
#  + x(17,22) + x(17,23) + x(17,24) + x(17,25) + x(17,26) + x(17,27) + x(17,28)
#  + x(17,29) + x(17,3) + x(17,30) + x(17,31) + x(17,32) + x(17,4) + x(17,5)
#  + x(17,6) + x(17,7) + x(17,8) + x(17,9) = 1
#
# _C18: x(18,1) + x(18,10) + x(18,11) + x(18,12) + x(18,13) + x(18,14)
#  + x(18,15) + x(18,16) + x(18,17) + x(18,19) + x(18,2) + x(18,20) + x(18,21)
#  + x(18,22) + x(18,23) + x(18,24) + x(18,25) + x(18,26) + x(18,27) + x(18,28)
#  + x(18,29) + x(18,3) + x(18,30) + x(18,31) + x(18,32) + x(18,4) + x(18,5)
#  + x(18,6) + x(18,7) + x(18,8) + x(18,9) = 1
#
# _C19: x(19,1) + x(19,10) + x(19,11) + x(19,12) + x(19,13) + x(19,14)
#  + x(19,15) + x(19,16) + x(19,17) + x(19,18) + x(19,2) + x(19,20) + x(19,21)
#  + x(19,22) + x(19,23) + x(19,24) + x(19,25) + x(19,26) + x(19,27) + x(19,28)
#  + x(19,29) + x(19,3) + x(19,30) + x(19,31) + x(19,32) + x(19,4) + x(19,5)
#  + x(19,6) + x(19,7) + x(19,8) + x(19,9) = 1
#
# _C20: x(20,1) + x(20,10) + x(20,11) + x(20,12) + x(20,13) + x(20,14)
#  + x(20,15) + x(20,16) + x(20,17) + x(20,18) + x(20,19) + x(20,2) + x(20,21)
#  + x(20,22) + x(20,23) + x(20,24) + x(20,25) + x(20,26) + x(20,27) + x(20,28)
#  + x(20,29) + x(20,3) + x(20,30) + x(20,31) + x(20,32) + x(20,4) + x(20,5)
#  + x(20,6) + x(20,7) + x(20,8) + x(20,9) = 1
#
# _C21: x(21,1) + x(21,10) + x(21,11) + x(21,12) + x(21,13) + x(21,14)
#  + x(21,15) + x(21,16) + x(21,17) + x(21,18) + x(21,19) + x(21,2) + x(21,20)
#  + x(21,22) + x(21,23) + x(21,24) + x(21,25) + x(21,26) + x(21,27) + x(21,28)
#  + x(21,29) + x(21,3) + x(21,30) + x(21,31) + x(21,32) + x(21,4) + x(21,5)
#  + x(21,6) + x(21,7) + x(21,8) + x(21,9) = 1
#
# _C22: x(22,1) + x(22,10) + x(22,11) + x(22,12) + x(22,13) + x(22,14)
#  + x(22,15) + x(22,16) + x(22,17) + x(22,18) + x(22,19) + x(22,2) + x(22,20)
#  + x(22,21) + x(22,23) + x(22,24) + x(22,25) + x(22,26) + x(22,27) + x(22,28)
#  + x(22,29) + x(22,3) + x(22,30) + x(22,31) + x(22,32) + x(22,4) + x(22,5)
#  + x(22,6) + x(22,7) + x(22,8) + x(22,9) = 1
#
# _C23: x(23,1) + x(23,10) + x(23,11) + x(23,12) + x(23,13) + x(23,14)
#  + x(23,15) + x(23,16) + x(23,17) + x(23,18) + x(23,19) + x(23,2) + x(23,20)
#  + x(23,21) + x(23,22) + x(23,24) + x(23,25) + x(23,26) + x(23,27) + x(23,28)
#  + x(23,29) + x(23,3) + x(23,30) + x(23,31) + x(23,32) + x(23,4) + x(23,5)
#  + x(23,6) + x(23,7) + x(23,8) + x(23,9) = 1
#
# _C24: x(24,1) + x(24,10) + x(24,11) + x(24,12) + x(24,13) + x(24,14)
#  + x(24,15) + x(24,16) + x(24,17) + x(24,18) + x(24,19) + x(24,2) + x(24,20)
#  + x(24,21) + x(24,22) + x(24,23) + x(24,25) + x(24,26) + x(24,27) + x(24,28)
#  + x(24,29) + x(24,3) + x(24,30) + x(24,31) + x(24,32) + x(24,4) + x(24,5)
#  + x(24,6) + x(24,7) + x(24,8) + x(24,9) = 1
#
# _C25: x(25,1) + x(25,10) + x(25,11) + x(25,12) + x(25,13) + x(25,14)
#  + x(25,15) + x(25,16) + x(25,17) + x(25,18) + x(25,19) + x(25,2) + x(25,20)
#  + x(25,21) + x(25,22) + x(25,23) + x(25,24) + x(25,26) + x(25,27) + x(25,28)
#  + x(25,29) + x(25,3) + x(25,30) + x(25,31) + x(25,32) + x(25,4) + x(25,5)
#  + x(25,6) + x(25,7) + x(25,8) + x(25,9) = 1
#
# _C26: x(26,1) + x(26,10) + x(26,11) + x(26,12) + x(26,13) + x(26,14)
#  + x(26,15) + x(26,16) + x(26,17) + x(26,18) + x(26,19) + x(26,2) + x(26,20)
#  + x(26,21) + x(26,22) + x(26,23) + x(26,24) + x(26,25) + x(26,27) + x(26,28)
#  + x(26,29) + x(26,3) + x(26,30) + x(26,31) + x(26,32) + x(26,4) + x(26,5)
#  + x(26,6) + x(26,7) + x(26,8) + x(26,9) = 1
#
# _C27: x(27,1) + x(27,10) + x(27,11) + x(27,12) + x(27,13) + x(27,14)
#  + x(27,15) + x(27,16) + x(27,17) + x(27,18) + x(27,19) + x(27,2) + x(27,20)
#  + x(27,21) + x(27,22) + x(27,23) + x(27,24) + x(27,25) + x(27,26) + x(27,28)
#  + x(27,29) + x(27,3) + x(27,30) + x(27,31) + x(27,32) + x(27,4) + x(27,5)
#  + x(27,6) + x(27,7) + x(27,8) + x(27,9) = 1
#
# _C28: x(28,1) + x(28,10) + x(28,11) + x(28,12) + x(28,13) + x(28,14)
#  + x(28,15) + x(28,16) + x(28,17) + x(28,18) + x(28,19) + x(28,2) + x(28,20)
#  + x(28,21) + x(28,22) + x(28,23) + x(28,24) + x(28,25) + x(28,26) + x(28,27)
#  + x(28,29) + x(28,3) + x(28,30) + x(28,31) + x(28,32) + x(28,4) + x(28,5)
#  + x(28,6) + x(28,7) + x(28,8) + x(28,9) = 1
#
# _C29: x(29,1) + x(29,10) + x(29,11) + x(29,12) + x(29,13) + x(29,14)
#  + x(29,15) + x(29,16) + x(29,17) + x(29,18) + x(29,19) + x(29,2) + x(29,20)
#  + x(29,21) + x(29,22) + x(29,23) + x(29,24) + x(29,25) + x(29,26) + x(29,27)
#  + x(29,28) + x(29,3) + x(29,30) + x(29,31) + x(29,32) + x(29,4) + x(29,5)
#  + x(29,6) + x(29,7) + x(29,8) + x(29,9) = 1
#
# _C30: x(30,1) + x(30,10) + x(30,11) + x(30,12) + x(30,13) + x(30,14)
#  + x(30,15) + x(30,16) + x(30,17) + x(30,18) + x(30,19) + x(30,2) + x(30,20)
#  + x(30,21) + x(30,22) + x(30,23) + x(30,24) + x(30,25) + x(30,26) + x(30,27)
#  + x(30,28) + x(30,29) + x(30,3) + x(30,31) + x(30,32) + x(30,4) + x(30,5)
#  + x(30,6) + x(30,7) + x(30,8) + x(30,9) = 1
#
# _C31: x(31,1) + x(31,10) + x(31,11) + x(31,12) + x(31,13) + x(31,14)
#  + x(31,15) + x(31,16) + x(31,17) + x(31,18) + x(31,19) + x(31,2) + x(31,20)
#  + x(31,21) + x(31,22) + x(31,23) + x(31,24) + x(31,25) + x(31,26) + x(31,27)
#  + x(31,28) + x(31,29) + x(31,3) + x(31,30) + x(31,32) + x(31,4) + x(31,5)
#  + x(31,6) + x(31,7) + x(31,8) + x(31,9) = 1
#
# _C32: x(0,1) + x(0,10) + x(0,11) + x(0,12) + x(0,13) + x(0,14) + x(0,15)
#  + x(0,16) + x(0,17) + x(0,18) + x(0,19) + x(0,2) + x(0,20) + x(0,21)
#  + x(0,22) + x(0,23) + x(0,24) + x(0,25) + x(0,26) + x(0,27) + x(0,28)
#  + x(0,29) + x(0,3) + x(0,30) + x(0,31) + x(0,4) + x(0,5) + x(0,6) + x(0,7)
#  + x(0,8) + x(0,9) <= 5
#
# _C33: y0 >= 0
#
# _C34: y0 <= 100
#
# _C35: y1 >= 19
#
# _C36: y1 <= 100
#
# _C37: y2 >= 21
#
# _C38: y2 <= 100
#
# _C39: y3 >= 6
#
# _C40: y3 <= 100
#
# _C41: y4 >= 19
#
# _C42: y4 <= 100
#
# _C43: y5 >= 7
#
# _C44: y5 <= 100
#
# _C45: y6 >= 12
#
# _C46: y6 <= 100
#
# _C47: y7 >= 16
#
# _C48: y7 <= 100
#
# _C49: y8 >= 6
#
# _C50: y8 <= 100
#
# _C51: y9 >= 16
#
# _C52: y9 <= 100
#
# _C53: y10 >= 8
#
# _C54: y10 <= 100
#
# _C55: y11 >= 14
#
# _C56: y11 <= 100
#
# _C57: y12 >= 21
#
# _C58: y12 <= 100
#
# _C59: y13 >= 16
#
# _C60: y13 <= 100
#
# _C61: y14 >= 3
#
# _C62: y14 <= 100
#
# _C63: y15 >= 22
#
# _C64: y15 <= 100
#
# _C65: y16 >= 18
#
# _C66: y16 <= 100
#
# _C67: y17 >= 19
#
# _C68: y17 <= 100
#
# _C69: y18 >= 1
#
# _C70: y18 <= 100
#
# _C71: y19 >= 24
#
# _C72: y19 <= 100
#
# _C73: y20 >= 8
#
# _C74: y20 <= 100
#
# _C75: y21 >= 12
#
# _C76: y21 <= 100
#
# _C77: y22 >= 4
#
# _C78: y22 <= 100
#
# _C79: y23 >= 8
#
# _C80: y23 <= 100
#
# _C81: y24 >= 24
#
# _C82: y24 <= 100
#
# _C83: y25 >= 24
#
# _C84: y25 <= 100
#
# _C85: y26 >= 2
#
# _C86: y26 <= 100
#
# _C87: y27 >= 20
#
# _C88: y27 <= 100
#
# _C89: y28 >= 15
#
# _C90: y28 <= 100
#
# _C91: y29 >= 2
#
# _C92: y29 <= 100
#
# _C93: y30 >= 14
#
# _C94: y30 <= 100
#
# _C95: y31 >= 9
#
# _C96: y31 <= 100
#
# _C97: y32 >= 0
#
# _C98: y32 <= 100
#
# _C99: - 100 x(0,0) + 0 y0 >= -100
#
# _C100: - 119 x(0,1) - y0 + y1 >= -100
#
# _C101: - 121 x(0,2) - y0 + y2 >= -100
#
# _C102: - 106 x(0,3) - y0 + y3 >= -100
#
# _C103: - 119 x(0,4) - y0 + y4 >= -100
#
# _C104: - 107 x(0,5) - y0 + y5 >= -100
#
# _C105: - 112 x(0,6) - y0 + y6 >= -100
#
# _C106: - 116 x(0,7) - y0 + y7 >= -100
#
# _C107: - 106 x(0,8) - y0 + y8 >= -100
#
# _C108: - 116 x(0,9) - y0 + y9 >= -100
#
# _C109: - 108 x(0,10) - y0 + y10 >= -100
#
# _C110: - 114 x(0,11) - y0 + y11 >= -100
#
# _C111: - 121 x(0,12) - y0 + y12 >= -100
#
# _C112: - 116 x(0,13) - y0 + y13 >= -100
#
# _C113: - 103 x(0,14) - y0 + y14 >= -100
#
# _C114: - 122 x(0,15) - y0 + y15 >= -100
#
# _C115: - 118 x(0,16) - y0 + y16 >= -100
#
# _C116: - 119 x(0,17) - y0 + y17 >= -100
#
# _C117: - 101 x(0,18) - y0 + y18 >= -100
#
# _C118: - 124 x(0,19) - y0 + y19 >= -100
#
# _C119: - 108 x(0,20) - y0 + y20 >= -100
#
# _C120: - 112 x(0,21) - y0 + y21 >= -100
#
# _C121: - 104 x(0,22) - y0 + y22 >= -100
#
# _C122: - 108 x(0,23) - y0 + y23 >= -100
#
# _C123: - 124 x(0,24) - y0 + y24 >= -100
#
# _C124: - 124 x(0,25) - y0 + y25 >= -100
#
# _C125: - 102 x(0,26) - y0 + y26 >= -100
#
# _C126: - 120 x(0,27) - y0 + y27 >= -100
#
# _C127: - 115 x(0,28) - y0 + y28 >= -100
#
# _C128: - 102 x(0,29) - y0 + y29 >= -100
#
# _C129: - 114 x(0,30) - y0 + y30 >= -100
#
# _C130: - 109 x(0,31) - y0 + y31 >= -100
#
# _C131: - 100 x(0,32) - y0 + y32 >= -100
#
# _C132: - 100 x(1,0) + y0 - y1 >= -100
#
# _C133: - 119 x(1,1) + 0 y1 >= -100
#
# _C134: - 121 x(1,2) - y1 + y2 >= -100
#
# _C135: - 106 x(1,3) - y1 + y3 >= -100
#
# _C136: - 119 x(1,4) - y1 + y4 >= -100
#
# _C137: - 107 x(1,5) - y1 + y5 >= -100
#
# _C138: - 112 x(1,6) - y1 + y6 >= -100
#
# _C139: - 116 x(1,7) - y1 + y7 >= -100
#
# _C140: - 106 x(1,8) - y1 + y8 >= -100
#
# _C141: - 116 x(1,9) - y1 + y9 >= -100
#
# _C142: - 108 x(1,10) - y1 + y10 >= -100
#
# _C143: - 114 x(1,11) - y1 + y11 >= -100
#
# _C144: - 121 x(1,12) - y1 + y12 >= -100
#
# _C145: - 116 x(1,13) - y1 + y13 >= -100
#
# _C146: - 103 x(1,14) - y1 + y14 >= -100
#
# _C147: - 122 x(1,15) - y1 + y15 >= -100
#
# _C148: - 118 x(1,16) - y1 + y16 >= -100
#
# _C149: - 119 x(1,17) - y1 + y17 >= -100
#
# _C150: - 101 x(1,18) - y1 + y18 >= -100
#
# _C151: - 124 x(1,19) - y1 + y19 >= -100
#
# _C152: - 108 x(1,20) - y1 + y20 >= -100
#
# _C153: - 112 x(1,21) - y1 + y21 >= -100
#
# _C154: - 104 x(1,22) - y1 + y22 >= -100
#
# _C155: - 108 x(1,23) - y1 + y23 >= -100
#
# _C156: - 124 x(1,24) - y1 + y24 >= -100
#
# _C157: - 124 x(1,25) - y1 + y25 >= -100
#
# _C158: - 102 x(1,26) - y1 + y26 >= -100
#
# _C159: - 120 x(1,27) - y1 + y27 >= -100
#
# _C160: - 115 x(1,28) - y1 + y28 >= -100
#
# _C161: - 102 x(1,29) - y1 + y29 >= -100
#
# _C162: - 114 x(1,30) - y1 + y30 >= -100
#
# _C163: - 109 x(1,31) - y1 + y31 >= -100
#
# _C164: - 100 x(1,32) - y1 + y32 >= -100
#
# _C165: - 100 x(2,0) + y0 - y2 >= -100
#
# _C166: - 119 x(2,1) + y1 - y2 >= -100
#
# _C167: - 121 x(2,2) + 0 y2 >= -100
#
# _C168: - 106 x(2,3) - y2 + y3 >= -100
#
# _C169: - 119 x(2,4) - y2 + y4 >= -100
#
# _C170: - 107 x(2,5) - y2 + y5 >= -100
#
# _C171: - 112 x(2,6) - y2 + y6 >= -100
#
# _C172: - 116 x(2,7) - y2 + y7 >= -100
#
# _C173: - 106 x(2,8) - y2 + y8 >= -100
#
# _C174: - 116 x(2,9) - y2 + y9 >= -100
#
# _C175: - 108 x(2,10) + y10 - y2 >= -100
#
# _C176: - 114 x(2,11) + y11 - y2 >= -100
#
# _C177: - 121 x(2,12) + y12 - y2 >= -100
#
# _C178: - 116 x(2,13) + y13 - y2 >= -100
#
# _C179: - 103 x(2,14) + y14 - y2 >= -100
#
# _C180: - 122 x(2,15) + y15 - y2 >= -100
#
# _C181: - 118 x(2,16) + y16 - y2 >= -100
#
# _C182: - 119 x(2,17) + y17 - y2 >= -100
#
# _C183: - 101 x(2,18) + y18 - y2 >= -100
#
# _C184: - 124 x(2,19) + y19 - y2 >= -100
#
# _C185: - 108 x(2,20) - y2 + y20 >= -100
#
# _C186: - 112 x(2,21) - y2 + y21 >= -100
#
# _C187: - 104 x(2,22) - y2 + y22 >= -100
#
# _C188: - 108 x(2,23) - y2 + y23 >= -100
#
# _C189: - 124 x(2,24) - y2 + y24 >= -100
#
# _C190: - 124 x(2,25) - y2 + y25 >= -100
#
# _C191: - 102 x(2,26) - y2 + y26 >= -100
#
# _C192: - 120 x(2,27) - y2 + y27 >= -100
#
# _C193: - 115 x(2,28) - y2 + y28 >= -100
#
# _C194: - 102 x(2,29) - y2 + y29 >= -100
#
# _C195: - 114 x(2,30) - y2 + y30 >= -100
#
# _C196: - 109 x(2,31) - y2 + y31 >= -100
#
# _C197: - 100 x(2,32) - y2 + y32 >= -100
#
# _C198: - 100 x(3,0) + y0 - y3 >= -100
#
# _C199: - 119 x(3,1) + y1 - y3 >= -100
#
# _C200: - 121 x(3,2) + y2 - y3 >= -100
#
# _C201: - 106 x(3,3) + 0 y3 >= -100
#
# _C202: - 119 x(3,4) - y3 + y4 >= -100
#
# _C203: - 107 x(3,5) - y3 + y5 >= -100
#
# _C204: - 112 x(3,6) - y3 + y6 >= -100
#
# _C205: - 116 x(3,7) - y3 + y7 >= -100
#
# _C206: - 106 x(3,8) - y3 + y8 >= -100
#
# _C207: - 116 x(3,9) - y3 + y9 >= -100
#
# _C208: - 108 x(3,10) + y10 - y3 >= -100
#
# _C209: - 114 x(3,11) + y11 - y3 >= -100
#
# _C210: - 121 x(3,12) + y12 - y3 >= -100
#
# _C211: - 116 x(3,13) + y13 - y3 >= -100
#
# _C212: - 103 x(3,14) + y14 - y3 >= -100
#
# _C213: - 122 x(3,15) + y15 - y3 >= -100
#
# _C214: - 118 x(3,16) + y16 - y3 >= -100
#
# _C215: - 119 x(3,17) + y17 - y3 >= -100
#
# _C216: - 101 x(3,18) + y18 - y3 >= -100
#
# _C217: - 124 x(3,19) + y19 - y3 >= -100
#
# _C218: - 108 x(3,20) + y20 - y3 >= -100
#
# _C219: - 112 x(3,21) + y21 - y3 >= -100
#
# _C220: - 104 x(3,22) + y22 - y3 >= -100
#
# _C221: - 108 x(3,23) + y23 - y3 >= -100
#
# _C222: - 124 x(3,24) + y24 - y3 >= -100
#
# _C223: - 124 x(3,25) + y25 - y3 >= -100
#
# _C224: - 102 x(3,26) + y26 - y3 >= -100
#
# _C225: - 120 x(3,27) + y27 - y3 >= -100
#
# _C226: - 115 x(3,28) + y28 - y3 >= -100
#
# _C227: - 102 x(3,29) + y29 - y3 >= -100
#
# _C228: - 114 x(3,30) - y3 + y30 >= -100
#
# _C229: - 109 x(3,31) - y3 + y31 >= -100
#
# _C230: - 100 x(3,32) - y3 + y32 >= -100
#
# _C231: - 100 x(4,0) + y0 - y4 >= -100
#
# _C232: - 119 x(4,1) + y1 - y4 >= -100
#
# _C233: - 121 x(4,2) + y2 - y4 >= -100
#
# _C234: - 106 x(4,3) + y3 - y4 >= -100
#
# _C235: - 119 x(4,4) + 0 y4 >= -100
#
# _C236: - 107 x(4,5) - y4 + y5 >= -100
#
# _C237: - 112 x(4,6) - y4 + y6 >= -100
#
# _C238: - 116 x(4,7) - y4 + y7 >= -100
#
# _C239: - 106 x(4,8) - y4 + y8 >= -100
#
# _C240: - 116 x(4,9) - y4 + y9 >= -100
#
# _C241: - 108 x(4,10) + y10 - y4 >= -100
#
# _C242: - 114 x(4,11) + y11 - y4 >= -100
#
# _C243: - 121 x(4,12) + y12 - y4 >= -100
#
# _C244: - 116 x(4,13) + y13 - y4 >= -100
#
# _C245: - 103 x(4,14) + y14 - y4 >= -100
#
# _C246: - 122 x(4,15) + y15 - y4 >= -100
#
# _C247: - 118 x(4,16) + y16 - y4 >= -100
#
# _C248: - 119 x(4,17) + y17 - y4 >= -100
#
# _C249: - 101 x(4,18) + y18 - y4 >= -100
#
# _C250: - 124 x(4,19) + y19 - y4 >= -100
#
# _C251: - 108 x(4,20) + y20 - y4 >= -100
#
# _C252: - 112 x(4,21) + y21 - y4 >= -100
#
# _C253: - 104 x(4,22) + y22 - y4 >= -100
#
# _C254: - 108 x(4,23) + y23 - y4 >= -100
#
# _C255: - 124 x(4,24) + y24 - y4 >= -100
#
# _C256: - 124 x(4,25) + y25 - y4 >= -100
#
# _C257: - 102 x(4,26) + y26 - y4 >= -100
#
# _C258: - 120 x(4,27) + y27 - y4 >= -100
#
# _C259: - 115 x(4,28) + y28 - y4 >= -100
#
# _C260: - 102 x(4,29) + y29 - y4 >= -100
#
# _C261: - 114 x(4,30) + y30 - y4 >= -100
#
# _C262: - 109 x(4,31) + y31 - y4 >= -100
#
# _C263: - 100 x(4,32) + y32 - y4 >= -100
#
# _C264: - 100 x(5,0) + y0 - y5 >= -100
#
# _C265: - 119 x(5,1) + y1 - y5 >= -100
#
# _C266: - 121 x(5,2) + y2 - y5 >= -100
#
# _C267: - 106 x(5,3) + y3 - y5 >= -100
#
# _C268: - 119 x(5,4) + y4 - y5 >= -100
#
# _C269: - 107 x(5,5) + 0 y5 >= -100
#
# _C270: - 112 x(5,6) - y5 + y6 >= -100
#
# _C271: - 116 x(5,7) - y5 + y7 >= -100
#
# _C272: - 106 x(5,8) - y5 + y8 >= -100
#
# _C273: - 116 x(5,9) - y5 + y9 >= -100
#
# _C274: - 108 x(5,10) + y10 - y5 >= -100
#
# _C275: - 114 x(5,11) + y11 - y5 >= -100
#
# _C276: - 121 x(5,12) + y12 - y5 >= -100
#
# _C277: - 116 x(5,13) + y13 - y5 >= -100
#
# _C278: - 103 x(5,14) + y14 - y5 >= -100
#
# _C279: - 122 x(5,15) + y15 - y5 >= -100
#
# _C280: - 118 x(5,16) + y16 - y5 >= -100
#
# _C281: - 119 x(5,17) + y17 - y5 >= -100
#
# _C282: - 101 x(5,18) + y18 - y5 >= -100
#
# _C283: - 124 x(5,19) + y19 - y5 >= -100
#
# _C284: - 108 x(5,20) + y20 - y5 >= -100
#
# _C285: - 112 x(5,21) + y21 - y5 >= -100
#
# _C286: - 104 x(5,22) + y22 - y5 >= -100
#
# _C287: - 108 x(5,23) + y23 - y5 >= -100
#
# _C288: - 124 x(5,24) + y24 - y5 >= -100
#
# _C289: - 124 x(5,25) + y25 - y5 >= -100
#
# _C290: - 102 x(5,26) + y26 - y5 >= -100
#
# _C291: - 120 x(5,27) + y27 - y5 >= -100
#
# _C292: - 115 x(5,28) + y28 - y5 >= -100
#
# _C293: - 102 x(5,29) + y29 - y5 >= -100
#
# _C294: - 114 x(5,30) + y30 - y5 >= -100
#
# _C295: - 109 x(5,31) + y31 - y5 >= -100
#
# _C296: - 100 x(5,32) + y32 - y5 >= -100
#
# _C297: - 100 x(6,0) + y0 - y6 >= -100
#
# _C298: - 119 x(6,1) + y1 - y6 >= -100
#
# _C299: - 121 x(6,2) + y2 - y6 >= -100
#
# _C300: - 106 x(6,3) + y3 - y6 >= -100
#
# _C301: - 119 x(6,4) + y4 - y6 >= -100
#
# _C302: - 107 x(6,5) + y5 - y6 >= -100
#
# _C303: - 112 x(6,6) + 0 y6 >= -100
#
# _C304: - 116 x(6,7) - y6 + y7 >= -100
#
# _C305: - 106 x(6,8) - y6 + y8 >= -100
#
# _C306: - 116 x(6,9) - y6 + y9 >= -100
#
# _C307: - 108 x(6,10) + y10 - y6 >= -100
#
# _C308: - 114 x(6,11) + y11 - y6 >= -100
#
# _C309: - 121 x(6,12) + y12 - y6 >= -100
#
# _C310: - 116 x(6,13) + y13 - y6 >= -100
#
# _C311: - 103 x(6,14) + y14 - y6 >= -100
#
# _C312: - 122 x(6,15) + y15 - y6 >= -100
#
# _C313: - 118 x(6,16) + y16 - y6 >= -100
#
# _C314: - 119 x(6,17) + y17 - y6 >= -100
#
# _C315: - 101 x(6,18) + y18 - y6 >= -100
#
# _C316: - 124 x(6,19) + y19 - y6 >= -100
#
# _C317: - 108 x(6,20) + y20 - y6 >= -100
#
# _C318: - 112 x(6,21) + y21 - y6 >= -100
#
# _C319: - 104 x(6,22) + y22 - y6 >= -100
#
# _C320: - 108 x(6,23) + y23 - y6 >= -100
#
# _C321: - 124 x(6,24) + y24 - y6 >= -100
#
# _C322: - 124 x(6,25) + y25 - y6 >= -100
#
# _C323: - 102 x(6,26) + y26 - y6 >= -100
#
# _C324: - 120 x(6,27) + y27 - y6 >= -100
#
# _C325: - 115 x(6,28) + y28 - y6 >= -100
#
# _C326: - 102 x(6,29) + y29 - y6 >= -100
#
# _C327: - 114 x(6,30) + y30 - y6 >= -100
#
# _C328: - 109 x(6,31) + y31 - y6 >= -100
#
# _C329: - 100 x(6,32) + y32 - y6 >= -100
#
# _C330: - 100 x(7,0) + y0 - y7 >= -100
#
# _C331: - 119 x(7,1) + y1 - y7 >= -100
#
# _C332: - 121 x(7,2) + y2 - y7 >= -100
#
# _C333: - 106 x(7,3) + y3 - y7 >= -100
#
# _C334: - 119 x(7,4) + y4 - y7 >= -100
#
# _C335: - 107 x(7,5) + y5 - y7 >= -100
#
# _C336: - 112 x(7,6) + y6 - y7 >= -100
#
# _C337: - 116 x(7,7) + 0 y7 >= -100
#
# _C338: - 106 x(7,8) - y7 + y8 >= -100
#
# _C339: - 116 x(7,9) - y7 + y9 >= -100
#
# _C340: - 108 x(7,10) + y10 - y7 >= -100
#
# _C341: - 114 x(7,11) + y11 - y7 >= -100
#
# _C342: - 121 x(7,12) + y12 - y7 >= -100
#
# _C343: - 116 x(7,13) + y13 - y7 >= -100
#
# _C344: - 103 x(7,14) + y14 - y7 >= -100
#
# _C345: - 122 x(7,15) + y15 - y7 >= -100
#
# _C346: - 118 x(7,16) + y16 - y7 >= -100
#
# _C347: - 119 x(7,17) + y17 - y7 >= -100
#
# _C348: - 101 x(7,18) + y18 - y7 >= -100
#
# _C349: - 124 x(7,19) + y19 - y7 >= -100
#
# _C350: - 108 x(7,20) + y20 - y7 >= -100
#
# _C351: - 112 x(7,21) + y21 - y7 >= -100
#
# _C352: - 104 x(7,22) + y22 - y7 >= -100
#
# _C353: - 108 x(7,23) + y23 - y7 >= -100
#
# _C354: - 124 x(7,24) + y24 - y7 >= -100
#
# _C355: - 124 x(7,25) + y25 - y7 >= -100
#
# _C356: - 102 x(7,26) + y26 - y7 >= -100
#
# _C357: - 120 x(7,27) + y27 - y7 >= -100
#
# _C358: - 115 x(7,28) + y28 - y7 >= -100
#
# _C359: - 102 x(7,29) + y29 - y7 >= -100
#
# _C360: - 114 x(7,30) + y30 - y7 >= -100
#
# _C361: - 109 x(7,31) + y31 - y7 >= -100
#
# _C362: - 100 x(7,32) + y32 - y7 >= -100
#
# _C363: - 100 x(8,0) + y0 - y8 >= -100
#
# _C364: - 119 x(8,1) + y1 - y8 >= -100
#
# _C365: - 121 x(8,2) + y2 - y8 >= -100
#
# _C366: - 106 x(8,3) + y3 - y8 >= -100
#
# _C367: - 119 x(8,4) + y4 - y8 >= -100
#
# _C368: - 107 x(8,5) + y5 - y8 >= -100
#
# _C369: - 112 x(8,6) + y6 - y8 >= -100
#
# _C370: - 116 x(8,7) + y7 - y8 >= -100
#
# _C371: - 106 x(8,8) + 0 y8 >= -100
#
# _C372: - 116 x(8,9) - y8 + y9 >= -100
#
# _C373: - 108 x(8,10) + y10 - y8 >= -100
#
# _C374: - 114 x(8,11) + y11 - y8 >= -100
#
# _C375: - 121 x(8,12) + y12 - y8 >= -100
#
# _C376: - 116 x(8,13) + y13 - y8 >= -100
#
# _C377: - 103 x(8,14) + y14 - y8 >= -100
#
# _C378: - 122 x(8,15) + y15 - y8 >= -100
#
# _C379: - 118 x(8,16) + y16 - y8 >= -100
#
# _C380: - 119 x(8,17) + y17 - y8 >= -100
#
# _C381: - 101 x(8,18) + y18 - y8 >= -100
#
# _C382: - 124 x(8,19) + y19 - y8 >= -100
#
# _C383: - 108 x(8,20) + y20 - y8 >= -100
#
# _C384: - 112 x(8,21) + y21 - y8 >= -100
#
# _C385: - 104 x(8,22) + y22 - y8 >= -100
#
# _C386: - 108 x(8,23) + y23 - y8 >= -100
#
# _C387: - 124 x(8,24) + y24 - y8 >= -100
#
# _C388: - 124 x(8,25) + y25 - y8 >= -100
#
# _C389: - 102 x(8,26) + y26 - y8 >= -100
#
# _C390: - 120 x(8,27) + y27 - y8 >= -100
#
# _C391: - 115 x(8,28) + y28 - y8 >= -100
#
# _C392: - 102 x(8,29) + y29 - y8 >= -100
#
# _C393: - 114 x(8,30) + y30 - y8 >= -100
#
# _C394: - 109 x(8,31) + y31 - y8 >= -100
#
# _C395: - 100 x(8,32) + y32 - y8 >= -100
#
# _C396: - 100 x(9,0) + y0 - y9 >= -100
#
# _C397: - 119 x(9,1) + y1 - y9 >= -100
#
# _C398: - 121 x(9,2) + y2 - y9 >= -100
#
# _C399: - 106 x(9,3) + y3 - y9 >= -100
#
# _C400: - 119 x(9,4) + y4 - y9 >= -100
#
# _C401: - 107 x(9,5) + y5 - y9 >= -100
#
# _C402: - 112 x(9,6) + y6 - y9 >= -100
#
# _C403: - 116 x(9,7) + y7 - y9 >= -100
#
# _C404: - 106 x(9,8) + y8 - y9 >= -100
#
# _C405: - 116 x(9,9) + 0 y9 >= -100
#
# _C406: - 108 x(9,10) + y10 - y9 >= -100
#
# _C407: - 114 x(9,11) + y11 - y9 >= -100
#
# _C408: - 121 x(9,12) + y12 - y9 >= -100
#
# _C409: - 116 x(9,13) + y13 - y9 >= -100
#
# _C410: - 103 x(9,14) + y14 - y9 >= -100
#
# _C411: - 122 x(9,15) + y15 - y9 >= -100
#
# _C412: - 118 x(9,16) + y16 - y9 >= -100
#
# _C413: - 119 x(9,17) + y17 - y9 >= -100
#
# _C414: - 101 x(9,18) + y18 - y9 >= -100
#
# _C415: - 124 x(9,19) + y19 - y9 >= -100
#
# _C416: - 108 x(9,20) + y20 - y9 >= -100
#
# _C417: - 112 x(9,21) + y21 - y9 >= -100
#
# _C418: - 104 x(9,22) + y22 - y9 >= -100
#
# _C419: - 108 x(9,23) + y23 - y9 >= -100
#
# _C420: - 124 x(9,24) + y24 - y9 >= -100
#
# _C421: - 124 x(9,25) + y25 - y9 >= -100
#
# _C422: - 102 x(9,26) + y26 - y9 >= -100
#
# _C423: - 120 x(9,27) + y27 - y9 >= -100
#
# _C424: - 115 x(9,28) + y28 - y9 >= -100
#
# _C425: - 102 x(9,29) + y29 - y9 >= -100
#
# _C426: - 114 x(9,30) + y30 - y9 >= -100
#
# _C427: - 109 x(9,31) + y31 - y9 >= -100
#
# _C428: - 100 x(9,32) + y32 - y9 >= -100
#
# _C429: - 100 x(10,0) + y0 - y10 >= -100
#
# _C430: - 119 x(10,1) + y1 - y10 >= -100
#
# _C431: - 121 x(10,2) - y10 + y2 >= -100
#
# _C432: - 106 x(10,3) - y10 + y3 >= -100
#
# _C433: - 119 x(10,4) - y10 + y4 >= -100
#
# _C434: - 107 x(10,5) - y10 + y5 >= -100
#
# _C435: - 112 x(10,6) - y10 + y6 >= -100
#
# _C436: - 116 x(10,7) - y10 + y7 >= -100
#
# _C437: - 106 x(10,8) - y10 + y8 >= -100
#
# _C438: - 116 x(10,9) - y10 + y9 >= -100
#
# _C439: - 108 x(10,10) + 0 y10 >= -100
#
# _C440: - 114 x(10,11) - y10 + y11 >= -100
#
# _C441: - 121 x(10,12) - y10 + y12 >= -100
#
# _C442: - 116 x(10,13) - y10 + y13 >= -100
#
# _C443: - 103 x(10,14) - y10 + y14 >= -100
#
# _C444: - 122 x(10,15) - y10 + y15 >= -100
#
# _C445: - 118 x(10,16) - y10 + y16 >= -100
#
# _C446: - 119 x(10,17) - y10 + y17 >= -100
#
# _C447: - 101 x(10,18) - y10 + y18 >= -100
#
# _C448: - 124 x(10,19) - y10 + y19 >= -100
#
# _C449: - 108 x(10,20) - y10 + y20 >= -100
#
# _C450: - 112 x(10,21) - y10 + y21 >= -100
#
# _C451: - 104 x(10,22) - y10 + y22 >= -100
#
# _C452: - 108 x(10,23) - y10 + y23 >= -100
#
# _C453: - 124 x(10,24) - y10 + y24 >= -100
#
# _C454: - 124 x(10,25) - y10 + y25 >= -100
#
# _C455: - 102 x(10,26) - y10 + y26 >= -100
#
# _C456: - 120 x(10,27) - y10 + y27 >= -100
#
# _C457: - 115 x(10,28) - y10 + y28 >= -100
#
# _C458: - 102 x(10,29) - y10 + y29 >= -100
#
# _C459: - 114 x(10,30) - y10 + y30 >= -100
#
# _C460: - 109 x(10,31) - y10 + y31 >= -100
#
# _C461: - 100 x(10,32) - y10 + y32 >= -100
#
# _C462: - 100 x(11,0) + y0 - y11 >= -100
#
# _C463: - 119 x(11,1) + y1 - y11 >= -100
#
# _C464: - 121 x(11,2) - y11 + y2 >= -100
#
# _C465: - 106 x(11,3) - y11 + y3 >= -100
#
# _C466: - 119 x(11,4) - y11 + y4 >= -100
#
# _C467: - 107 x(11,5) - y11 + y5 >= -100
#
# _C468: - 112 x(11,6) - y11 + y6 >= -100
#
# _C469: - 116 x(11,7) - y11 + y7 >= -100
#
# _C470: - 106 x(11,8) - y11 + y8 >= -100
#
# _C471: - 116 x(11,9) - y11 + y9 >= -100
#
# _C472: - 108 x(11,10) + y10 - y11 >= -100
#
# _C473: - 114 x(11,11) + 0 y11 >= -100
#
# _C474: - 121 x(11,12) - y11 + y12 >= -100
#
# _C475: - 116 x(11,13) - y11 + y13 >= -100
#
# _C476: - 103 x(11,14) - y11 + y14 >= -100
#
# _C477: - 122 x(11,15) - y11 + y15 >= -100
#
# _C478: - 118 x(11,16) - y11 + y16 >= -100
#
# _C479: - 119 x(11,17) - y11 + y17 >= -100
#
# _C480: - 101 x(11,18) - y11 + y18 >= -100
#
# _C481: - 124 x(11,19) - y11 + y19 >= -100
#
# _C482: - 108 x(11,20) - y11 + y20 >= -100
#
# _C483: - 112 x(11,21) - y11 + y21 >= -100
#
# _C484: - 104 x(11,22) - y11 + y22 >= -100
#
# _C485: - 108 x(11,23) - y11 + y23 >= -100
#
# _C486: - 124 x(11,24) - y11 + y24 >= -100
#
# _C487: - 124 x(11,25) - y11 + y25 >= -100
#
# _C488: - 102 x(11,26) - y11 + y26 >= -100
#
# _C489: - 120 x(11,27) - y11 + y27 >= -100
#
# _C490: - 115 x(11,28) - y11 + y28 >= -100
#
# _C491: - 102 x(11,29) - y11 + y29 >= -100
#
# _C492: - 114 x(11,30) - y11 + y30 >= -100
#
# _C493: - 109 x(11,31) - y11 + y31 >= -100
#
# _C494: - 100 x(11,32) - y11 + y32 >= -100
#
# _C495: - 100 x(12,0) + y0 - y12 >= -100
#
# _C496: - 119 x(12,1) + y1 - y12 >= -100
#
# _C497: - 121 x(12,2) - y12 + y2 >= -100
#
# _C498: - 106 x(12,3) - y12 + y3 >= -100
#
# _C499: - 119 x(12,4) - y12 + y4 >= -100
#
# _C500: - 107 x(12,5) - y12 + y5 >= -100
#
# _C501: - 112 x(12,6) - y12 + y6 >= -100
#
# _C502: - 116 x(12,7) - y12 + y7 >= -100
#
# _C503: - 106 x(12,8) - y12 + y8 >= -100
#
# _C504: - 116 x(12,9) - y12 + y9 >= -100
#
# _C505: - 108 x(12,10) + y10 - y12 >= -100
#
# _C506: - 114 x(12,11) + y11 - y12 >= -100
#
# _C507: - 121 x(12,12) + 0 y12 >= -100
#
# _C508: - 116 x(12,13) - y12 + y13 >= -100
#
# _C509: - 103 x(12,14) - y12 + y14 >= -100
#
# _C510: - 122 x(12,15) - y12 + y15 >= -100
#
# _C511: - 118 x(12,16) - y12 + y16 >= -100
#
# _C512: - 119 x(12,17) - y12 + y17 >= -100
#
# _C513: - 101 x(12,18) - y12 + y18 >= -100
#
# _C514: - 124 x(12,19) - y12 + y19 >= -100
#
# _C515: - 108 x(12,20) - y12 + y20 >= -100
#
# _C516: - 112 x(12,21) - y12 + y21 >= -100
#
# _C517: - 104 x(12,22) - y12 + y22 >= -100
#
# _C518: - 108 x(12,23) - y12 + y23 >= -100
#
# _C519: - 124 x(12,24) - y12 + y24 >= -100
#
# _C520: - 124 x(12,25) - y12 + y25 >= -100
#
# _C521: - 102 x(12,26) - y12 + y26 >= -100
#
# _C522: - 120 x(12,27) - y12 + y27 >= -100
#
# _C523: - 115 x(12,28) - y12 + y28 >= -100
#
# _C524: - 102 x(12,29) - y12 + y29 >= -100
#
# _C525: - 114 x(12,30) - y12 + y30 >= -100
#
# _C526: - 109 x(12,31) - y12 + y31 >= -100
#
# _C527: - 100 x(12,32) - y12 + y32 >= -100
#
# _C528: - 100 x(13,0) + y0 - y13 >= -100
#
# _C529: - 119 x(13,1) + y1 - y13 >= -100
#
# _C530: - 121 x(13,2) - y13 + y2 >= -100
#
# _C531: - 106 x(13,3) - y13 + y3 >= -100
#
# _C532: - 119 x(13,4) - y13 + y4 >= -100
#
# _C533: - 107 x(13,5) - y13 + y5 >= -100
#
# _C534: - 112 x(13,6) - y13 + y6 >= -100
#
# _C535: - 116 x(13,7) - y13 + y7 >= -100
#
# _C536: - 106 x(13,8) - y13 + y8 >= -100
#
# _C537: - 116 x(13,9) - y13 + y9 >= -100
#
# _C538: - 108 x(13,10) + y10 - y13 >= -100
#
# _C539: - 114 x(13,11) + y11 - y13 >= -100
#
# _C540: - 121 x(13,12) + y12 - y13 >= -100
#
# _C541: - 116 x(13,13) + 0 y13 >= -100
#
# _C542: - 103 x(13,14) - y13 + y14 >= -100
#
# _C543: - 122 x(13,15) - y13 + y15 >= -100
#
# _C544: - 118 x(13,16) - y13 + y16 >= -100
#
# _C545: - 119 x(13,17) - y13 + y17 >= -100
#
# _C546: - 101 x(13,18) - y13 + y18 >= -100
#
# _C547: - 124 x(13,19) - y13 + y19 >= -100
#
# _C548: - 108 x(13,20) - y13 + y20 >= -100
#
# _C549: - 112 x(13,21) - y13 + y21 >= -100
#
# _C550: - 104 x(13,22) - y13 + y22 >= -100
#
# _C551: - 108 x(13,23) - y13 + y23 >= -100
#
# _C552: - 124 x(13,24) - y13 + y24 >= -100
#
# _C553: - 124 x(13,25) - y13 + y25 >= -100
#
# _C554: - 102 x(13,26) - y13 + y26 >= -100
#
# _C555: - 120 x(13,27) - y13 + y27 >= -100
#
# _C556: - 115 x(13,28) - y13 + y28 >= -100
#
# _C557: - 102 x(13,29) - y13 + y29 >= -100
#
# _C558: - 114 x(13,30) - y13 + y30 >= -100
#
# _C559: - 109 x(13,31) - y13 + y31 >= -100
#
# _C560: - 100 x(13,32) - y13 + y32 >= -100
#
# _C561: - 100 x(14,0) + y0 - y14 >= -100
#
# _C562: - 119 x(14,1) + y1 - y14 >= -100
#
# _C563: - 121 x(14,2) - y14 + y2 >= -100
#
# _C564: - 106 x(14,3) - y14 + y3 >= -100
#
# _C565: - 119 x(14,4) - y14 + y4 >= -100
#
# _C566: - 107 x(14,5) - y14 + y5 >= -100
#
# _C567: - 112 x(14,6) - y14 + y6 >= -100
#
# _C568: - 116 x(14,7) - y14 + y7 >= -100
#
# _C569: - 106 x(14,8) - y14 + y8 >= -100
#
# _C570: - 116 x(14,9) - y14 + y9 >= -100
#
# _C571: - 108 x(14,10) + y10 - y14 >= -100
#
# _C572: - 114 x(14,11) + y11 - y14 >= -100
#
# _C573: - 121 x(14,12) + y12 - y14 >= -100
#
# _C574: - 116 x(14,13) + y13 - y14 >= -100
#
# _C575: - 103 x(14,14) + 0 y14 >= -100
#
# _C576: - 122 x(14,15) - y14 + y15 >= -100
#
# _C577: - 118 x(14,16) - y14 + y16 >= -100
#
# _C578: - 119 x(14,17) - y14 + y17 >= -100
#
# _C579: - 101 x(14,18) - y14 + y18 >= -100
#
# _C580: - 124 x(14,19) - y14 + y19 >= -100
#
# _C581: - 108 x(14,20) - y14 + y20 >= -100
#
# _C582: - 112 x(14,21) - y14 + y21 >= -100
#
# _C583: - 104 x(14,22) - y14 + y22 >= -100
#
# _C584: - 108 x(14,23) - y14 + y23 >= -100
#
# _C585: - 124 x(14,24) - y14 + y24 >= -100
#
# _C586: - 124 x(14,25) - y14 + y25 >= -100
#
# _C587: - 102 x(14,26) - y14 + y26 >= -100
#
# _C588: - 120 x(14,27) - y14 + y27 >= -100
#
# _C589: - 115 x(14,28) - y14 + y28 >= -100
#
# _C590: - 102 x(14,29) - y14 + y29 >= -100
#
# _C591: - 114 x(14,30) - y14 + y30 >= -100
#
# _C592: - 109 x(14,31) - y14 + y31 >= -100
#
# _C593: - 100 x(14,32) - y14 + y32 >= -100
#
# _C594: - 100 x(15,0) + y0 - y15 >= -100
#
# _C595: - 119 x(15,1) + y1 - y15 >= -100
#
# _C596: - 121 x(15,2) - y15 + y2 >= -100
#
# _C597: - 106 x(15,3) - y15 + y3 >= -100
#
# _C598: - 119 x(15,4) - y15 + y4 >= -100
#
# _C599: - 107 x(15,5) - y15 + y5 >= -100
#
# _C600: - 112 x(15,6) - y15 + y6 >= -100
#
# _C601: - 116 x(15,7) - y15 + y7 >= -100
#
# _C602: - 106 x(15,8) - y15 + y8 >= -100
#
# _C603: - 116 x(15,9) - y15 + y9 >= -100
#
# _C604: - 108 x(15,10) + y10 - y15 >= -100
#
# _C605: - 114 x(15,11) + y11 - y15 >= -100
#
# _C606: - 121 x(15,12) + y12 - y15 >= -100
#
# _C607: - 116 x(15,13) + y13 - y15 >= -100
#
# _C608: - 103 x(15,14) + y14 - y15 >= -100
#
# _C609: - 122 x(15,15) + 0 y15 >= -100
#
# _C610: - 118 x(15,16) - y15 + y16 >= -100
#
# _C611: - 119 x(15,17) - y15 + y17 >= -100
#
# _C612: - 101 x(15,18) - y15 + y18 >= -100
#
# _C613: - 124 x(15,19) - y15 + y19 >= -100
#
# _C614: - 108 x(15,20) - y15 + y20 >= -100
#
# _C615: - 112 x(15,21) - y15 + y21 >= -100
#
# _C616: - 104 x(15,22) - y15 + y22 >= -100
#
# _C617: - 108 x(15,23) - y15 + y23 >= -100
#
# _C618: - 124 x(15,24) - y15 + y24 >= -100
#
# _C619: - 124 x(15,25) - y15 + y25 >= -100
#
# _C620: - 102 x(15,26) - y15 + y26 >= -100
#
# _C621: - 120 x(15,27) - y15 + y27 >= -100
#
# _C622: - 115 x(15,28) - y15 + y28 >= -100
#
# _C623: - 102 x(15,29) - y15 + y29 >= -100
#
# _C624: - 114 x(15,30) - y15 + y30 >= -100
#
# _C625: - 109 x(15,31) - y15 + y31 >= -100
#
# _C626: - 100 x(15,32) - y15 + y32 >= -100
#
# _C627: - 100 x(16,0) + y0 - y16 >= -100
#
# _C628: - 119 x(16,1) + y1 - y16 >= -100
#
# _C629: - 121 x(16,2) - y16 + y2 >= -100
#
# _C630: - 106 x(16,3) - y16 + y3 >= -100
#
# _C631: - 119 x(16,4) - y16 + y4 >= -100
#
# _C632: - 107 x(16,5) - y16 + y5 >= -100
#
# _C633: - 112 x(16,6) - y16 + y6 >= -100
#
# _C634: - 116 x(16,7) - y16 + y7 >= -100
#
# _C635: - 106 x(16,8) - y16 + y8 >= -100
#
# _C636: - 116 x(16,9) - y16 + y9 >= -100
#
# _C637: - 108 x(16,10) + y10 - y16 >= -100
#
# _C638: - 114 x(16,11) + y11 - y16 >= -100
#
# _C639: - 121 x(16,12) + y12 - y16 >= -100
#
# _C640: - 116 x(16,13) + y13 - y16 >= -100
#
# _C641: - 103 x(16,14) + y14 - y16 >= -100
#
# _C642: - 122 x(16,15) + y15 - y16 >= -100
#
# _C643: - 118 x(16,16) + 0 y16 >= -100
#
# _C644: - 119 x(16,17) - y16 + y17 >= -100
#
# _C645: - 101 x(16,18) - y16 + y18 >= -100
#
# _C646: - 124 x(16,19) - y16 + y19 >= -100
#
# _C647: - 108 x(16,20) - y16 + y20 >= -100
#
# _C648: - 112 x(16,21) - y16 + y21 >= -100
#
# _C649: - 104 x(16,22) - y16 + y22 >= -100
#
# _C650: - 108 x(16,23) - y16 + y23 >= -100
#
# _C651: - 124 x(16,24) - y16 + y24 >= -100
#
# _C652: - 124 x(16,25) - y16 + y25 >= -100
#
# _C653: - 102 x(16,26) - y16 + y26 >= -100
#
# _C654: - 120 x(16,27) - y16 + y27 >= -100
#
# _C655: - 115 x(16,28) - y16 + y28 >= -100
#
# _C656: - 102 x(16,29) - y16 + y29 >= -100
#
# _C657: - 114 x(16,30) - y16 + y30 >= -100
#
# _C658: - 109 x(16,31) - y16 + y31 >= -100
#
# _C659: - 100 x(16,32) - y16 + y32 >= -100
#
# _C660: - 100 x(17,0) + y0 - y17 >= -100
#
# _C661: - 119 x(17,1) + y1 - y17 >= -100
#
# _C662: - 121 x(17,2) - y17 + y2 >= -100
#
# _C663: - 106 x(17,3) - y17 + y3 >= -100
#
# _C664: - 119 x(17,4) - y17 + y4 >= -100
#
# _C665: - 107 x(17,5) - y17 + y5 >= -100
#
# _C666: - 112 x(17,6) - y17 + y6 >= -100
#
# _C667: - 116 x(17,7) - y17 + y7 >= -100
#
# _C668: - 106 x(17,8) - y17 + y8 >= -100
#
# _C669: - 116 x(17,9) - y17 + y9 >= -100
#
# _C670: - 108 x(17,10) + y10 - y17 >= -100
#
# _C671: - 114 x(17,11) + y11 - y17 >= -100
#
# _C672: - 121 x(17,12) + y12 - y17 >= -100
#
# _C673: - 116 x(17,13) + y13 - y17 >= -100
#
# _C674: - 103 x(17,14) + y14 - y17 >= -100
#
# _C675: - 122 x(17,15) + y15 - y17 >= -100
#
# _C676: - 118 x(17,16) + y16 - y17 >= -100
#
# _C677: - 119 x(17,17) + 0 y17 >= -100
#
# _C678: - 101 x(17,18) - y17 + y18 >= -100
#
# _C679: - 124 x(17,19) - y17 + y19 >= -100
#
# _C680: - 108 x(17,20) - y17 + y20 >= -100
#
# _C681: - 112 x(17,21) - y17 + y21 >= -100
#
# _C682: - 104 x(17,22) - y17 + y22 >= -100
#
# _C683: - 108 x(17,23) - y17 + y23 >= -100
#
# _C684: - 124 x(17,24) - y17 + y24 >= -100
#
# _C685: - 124 x(17,25) - y17 + y25 >= -100
#
# _C686: - 102 x(17,26) - y17 + y26 >= -100
#
# _C687: - 120 x(17,27) - y17 + y27 >= -100
#
# _C688: - 115 x(17,28) - y17 + y28 >= -100
#
# _C689: - 102 x(17,29) - y17 + y29 >= -100
#
# _C690: - 114 x(17,30) - y17 + y30 >= -100
#
# _C691: - 109 x(17,31) - y17 + y31 >= -100
#
# _C692: - 100 x(17,32) - y17 + y32 >= -100
#
# _C693: - 100 x(18,0) + y0 - y18 >= -100
#
# _C694: - 119 x(18,1) + y1 - y18 >= -100
#
# _C695: - 121 x(18,2) - y18 + y2 >= -100
#
# _C696: - 106 x(18,3) - y18 + y3 >= -100
#
# _C697: - 119 x(18,4) - y18 + y4 >= -100
#
# _C698: - 107 x(18,5) - y18 + y5 >= -100
#
# _C699: - 112 x(18,6) - y18 + y6 >= -100
#
# _C700: - 116 x(18,7) - y18 + y7 >= -100
#
# _C701: - 106 x(18,8) - y18 + y8 >= -100
#
# _C702: - 116 x(18,9) - y18 + y9 >= -100
#
# _C703: - 108 x(18,10) + y10 - y18 >= -100
#
# _C704: - 114 x(18,11) + y11 - y18 >= -100
#
# _C705: - 121 x(18,12) + y12 - y18 >= -100
#
# _C706: - 116 x(18,13) + y13 - y18 >= -100
#
# _C707: - 103 x(18,14) + y14 - y18 >= -100
#
# _C708: - 122 x(18,15) + y15 - y18 >= -100
#
# _C709: - 118 x(18,16) + y16 - y18 >= -100
#
# _C710: - 119 x(18,17) + y17 - y18 >= -100
#
# _C711: - 101 x(18,18) + 0 y18 >= -100
#
# _C712: - 124 x(18,19) - y18 + y19 >= -100
#
# _C713: - 108 x(18,20) - y18 + y20 >= -100
#
# _C714: - 112 x(18,21) - y18 + y21 >= -100
#
# _C715: - 104 x(18,22) - y18 + y22 >= -100
#
# _C716: - 108 x(18,23) - y18 + y23 >= -100
#
# _C717: - 124 x(18,24) - y18 + y24 >= -100
#
# _C718: - 124 x(18,25) - y18 + y25 >= -100
#
# _C719: - 102 x(18,26) - y18 + y26 >= -100
#
# _C720: - 120 x(18,27) - y18 + y27 >= -100
#
# _C721: - 115 x(18,28) - y18 + y28 >= -100
#
# _C722: - 102 x(18,29) - y18 + y29 >= -100
#
# _C723: - 114 x(18,30) - y18 + y30 >= -100
#
# _C724: - 109 x(18,31) - y18 + y31 >= -100
#
# _C725: - 100 x(18,32) - y18 + y32 >= -100
#
# _C726: - 100 x(19,0) + y0 - y19 >= -100
#
# _C727: - 119 x(19,1) + y1 - y19 >= -100
#
# _C728: - 121 x(19,2) - y19 + y2 >= -100
#
# _C729: - 106 x(19,3) - y19 + y3 >= -100
#
# _C730: - 119 x(19,4) - y19 + y4 >= -100
#
# _C731: - 107 x(19,5) - y19 + y5 >= -100
#
# _C732: - 112 x(19,6) - y19 + y6 >= -100
#
# _C733: - 116 x(19,7) - y19 + y7 >= -100
#
# _C734: - 106 x(19,8) - y19 + y8 >= -100
#
# _C735: - 116 x(19,9) - y19 + y9 >= -100
#
# _C736: - 108 x(19,10) + y10 - y19 >= -100
#
# _C737: - 114 x(19,11) + y11 - y19 >= -100
#
# _C738: - 121 x(19,12) + y12 - y19 >= -100
#
# _C739: - 116 x(19,13) + y13 - y19 >= -100
#
# _C740: - 103 x(19,14) + y14 - y19 >= -100
#
# _C741: - 122 x(19,15) + y15 - y19 >= -100
#
# _C742: - 118 x(19,16) + y16 - y19 >= -100
#
# _C743: - 119 x(19,17) + y17 - y19 >= -100
#
# _C744: - 101 x(19,18) + y18 - y19 >= -100
#
# _C745: - 124 x(19,19) + 0 y19 >= -100
#
# _C746: - 108 x(19,20) - y19 + y20 >= -100
#
# _C747: - 112 x(19,21) - y19 + y21 >= -100
#
# _C748: - 104 x(19,22) - y19 + y22 >= -100
#
# _C749: - 108 x(19,23) - y19 + y23 >= -100
#
# _C750: - 124 x(19,24) - y19 + y24 >= -100
#
# _C751: - 124 x(19,25) - y19 + y25 >= -100
#
# _C752: - 102 x(19,26) - y19 + y26 >= -100
#
# _C753: - 120 x(19,27) - y19 + y27 >= -100
#
# _C754: - 115 x(19,28) - y19 + y28 >= -100
#
# _C755: - 102 x(19,29) - y19 + y29 >= -100
#
# _C756: - 114 x(19,30) - y19 + y30 >= -100
#
# _C757: - 109 x(19,31) - y19 + y31 >= -100
#
# _C758: - 100 x(19,32) - y19 + y32 >= -100
#
# _C759: - 100 x(20,0) + y0 - y20 >= -100
#
# _C760: - 119 x(20,1) + y1 - y20 >= -100
#
# _C761: - 121 x(20,2) + y2 - y20 >= -100
#
# _C762: - 106 x(20,3) - y20 + y3 >= -100
#
# _C763: - 119 x(20,4) - y20 + y4 >= -100
#
# _C764: - 107 x(20,5) - y20 + y5 >= -100
#
# _C765: - 112 x(20,6) - y20 + y6 >= -100
#
# _C766: - 116 x(20,7) - y20 + y7 >= -100
#
# _C767: - 106 x(20,8) - y20 + y8 >= -100
#
# _C768: - 116 x(20,9) - y20 + y9 >= -100
#
# _C769: - 108 x(20,10) + y10 - y20 >= -100
#
# _C770: - 114 x(20,11) + y11 - y20 >= -100
#
# _C771: - 121 x(20,12) + y12 - y20 >= -100
#
# _C772: - 116 x(20,13) + y13 - y20 >= -100
#
# _C773: - 103 x(20,14) + y14 - y20 >= -100
#
# _C774: - 122 x(20,15) + y15 - y20 >= -100
#
# _C775: - 118 x(20,16) + y16 - y20 >= -100
#
# _C776: - 119 x(20,17) + y17 - y20 >= -100
#
# _C777: - 101 x(20,18) + y18 - y20 >= -100
#
# _C778: - 124 x(20,19) + y19 - y20 >= -100
#
# _C779: - 108 x(20,20) + 0 y20 >= -100
#
# _C780: - 112 x(20,21) - y20 + y21 >= -100
#
# _C781: - 104 x(20,22) - y20 + y22 >= -100
#
# _C782: - 108 x(20,23) - y20 + y23 >= -100
#
# _C783: - 124 x(20,24) - y20 + y24 >= -100
#
# _C784: - 124 x(20,25) - y20 + y25 >= -100
#
# _C785: - 102 x(20,26) - y20 + y26 >= -100
#
# _C786: - 120 x(20,27) - y20 + y27 >= -100
#
# _C787: - 115 x(20,28) - y20 + y28 >= -100
#
# _C788: - 102 x(20,29) - y20 + y29 >= -100
#
# _C789: - 114 x(20,30) - y20 + y30 >= -100
#
# _C790: - 109 x(20,31) - y20 + y31 >= -100
#
# _C791: - 100 x(20,32) - y20 + y32 >= -100
#
# _C792: - 100 x(21,0) + y0 - y21 >= -100
#
# _C793: - 119 x(21,1) + y1 - y21 >= -100
#
# _C794: - 121 x(21,2) + y2 - y21 >= -100
#
# _C795: - 106 x(21,3) - y21 + y3 >= -100
#
# _C796: - 119 x(21,4) - y21 + y4 >= -100
#
# _C797: - 107 x(21,5) - y21 + y5 >= -100
#
# _C798: - 112 x(21,6) - y21 + y6 >= -100
#
# _C799: - 116 x(21,7) - y21 + y7 >= -100
#
# _C800: - 106 x(21,8) - y21 + y8 >= -100
#
# _C801: - 116 x(21,9) - y21 + y9 >= -100
#
# _C802: - 108 x(21,10) + y10 - y21 >= -100
#
# _C803: - 114 x(21,11) + y11 - y21 >= -100
#
# _C804: - 121 x(21,12) + y12 - y21 >= -100
#
# _C805: - 116 x(21,13) + y13 - y21 >= -100
#
# _C806: - 103 x(21,14) + y14 - y21 >= -100
#
# _C807: - 122 x(21,15) + y15 - y21 >= -100
#
# _C808: - 118 x(21,16) + y16 - y21 >= -100
#
# _C809: - 119 x(21,17) + y17 - y21 >= -100
#
# _C810: - 101 x(21,18) + y18 - y21 >= -100
#
# _C811: - 124 x(21,19) + y19 - y21 >= -100
#
# _C812: - 108 x(21,20) + y20 - y21 >= -100
#
# _C813: - 112 x(21,21) + 0 y21 >= -100
#
# _C814: - 104 x(21,22) - y21 + y22 >= -100
#
# _C815: - 108 x(21,23) - y21 + y23 >= -100
#
# _C816: - 124 x(21,24) - y21 + y24 >= -100
#
# _C817: - 124 x(21,25) - y21 + y25 >= -100
#
# _C818: - 102 x(21,26) - y21 + y26 >= -100
#
# _C819: - 120 x(21,27) - y21 + y27 >= -100
#
# _C820: - 115 x(21,28) - y21 + y28 >= -100
#
# _C821: - 102 x(21,29) - y21 + y29 >= -100
#
# _C822: - 114 x(21,30) - y21 + y30 >= -100
#
# _C823: - 109 x(21,31) - y21 + y31 >= -100
#
# _C824: - 100 x(21,32) - y21 + y32 >= -100
#
# _C825: - 100 x(22,0) + y0 - y22 >= -100
#
# _C826: - 119 x(22,1) + y1 - y22 >= -100
#
# _C827: - 121 x(22,2) + y2 - y22 >= -100
#
# _C828: - 106 x(22,3) - y22 + y3 >= -100
#
# _C829: - 119 x(22,4) - y22 + y4 >= -100
#
# _C830: - 107 x(22,5) - y22 + y5 >= -100
#
# _C831: - 112 x(22,6) - y22 + y6 >= -100
#
# _C832: - 116 x(22,7) - y22 + y7 >= -100
#
# _C833: - 106 x(22,8) - y22 + y8 >= -100
#
# _C834: - 116 x(22,9) - y22 + y9 >= -100
#
# _C835: - 108 x(22,10) + y10 - y22 >= -100
#
# _C836: - 114 x(22,11) + y11 - y22 >= -100
#
# _C837: - 121 x(22,12) + y12 - y22 >= -100
#
# _C838: - 116 x(22,13) + y13 - y22 >= -100
#
# _C839: - 103 x(22,14) + y14 - y22 >= -100
#
# _C840: - 122 x(22,15) + y15 - y22 >= -100
#
# _C841: - 118 x(22,16) + y16 - y22 >= -100
#
# _C842: - 119 x(22,17) + y17 - y22 >= -100
#
# _C843: - 101 x(22,18) + y18 - y22 >= -100
#
# _C844: - 124 x(22,19) + y19 - y22 >= -100
#
# _C845: - 108 x(22,20) + y20 - y22 >= -100
#
# _C846: - 112 x(22,21) + y21 - y22 >= -100
#
# _C847: - 104 x(22,22) + 0 y22 >= -100
#
# _C848: - 108 x(22,23) - y22 + y23 >= -100
#
# _C849: - 124 x(22,24) - y22 + y24 >= -100
#
# _C850: - 124 x(22,25) - y22 + y25 >= -100
#
# _C851: - 102 x(22,26) - y22 + y26 >= -100
#
# _C852: - 120 x(22,27) - y22 + y27 >= -100
#
# _C853: - 115 x(22,28) - y22 + y28 >= -100
#
# _C854: - 102 x(22,29) - y22 + y29 >= -100
#
# _C855: - 114 x(22,30) - y22 + y30 >= -100
#
# _C856: - 109 x(22,31) - y22 + y31 >= -100
#
# _C857: - 100 x(22,32) - y22 + y32 >= -100
#
# _C858: - 100 x(23,0) + y0 - y23 >= -100
#
# _C859: - 119 x(23,1) + y1 - y23 >= -100
#
# _C860: - 121 x(23,2) + y2 - y23 >= -100
#
# _C861: - 106 x(23,3) - y23 + y3 >= -100
#
# _C862: - 119 x(23,4) - y23 + y4 >= -100
#
# _C863: - 107 x(23,5) - y23 + y5 >= -100
#
# _C864: - 112 x(23,6) - y23 + y6 >= -100
#
# _C865: - 116 x(23,7) - y23 + y7 >= -100
#
# _C866: - 106 x(23,8) - y23 + y8 >= -100
#
# _C867: - 116 x(23,9) - y23 + y9 >= -100
#
# _C868: - 108 x(23,10) + y10 - y23 >= -100
#
# _C869: - 114 x(23,11) + y11 - y23 >= -100
#
# _C870: - 121 x(23,12) + y12 - y23 >= -100
#
# _C871: - 116 x(23,13) + y13 - y23 >= -100
#
# _C872: - 103 x(23,14) + y14 - y23 >= -100
#
# _C873: - 122 x(23,15) + y15 - y23 >= -100
#
# ...
# 0 <= x(22,13) <= 1 Integer
# 0 <= x(22,14) <= 1 Integer
# 0 <= x(22,15) <= 1 Integer
# 0 <= x(22,16) <= 1 Integer
# 0 <= x(22,17) <= 1 Integer
# 0 <= x(22,18) <= 1 Integer
# 0 <= x(22,19) <= 1 Integer
# 0 <= x(22,2) <= 1 Integer
# 0 <= x(22,20) <= 1 Integer
# 0 <= x(22,21) <= 1 Integer
# 0 <= x(22,22) <= 1 Integer
# 0 <= x(22,23) <= 1 Integer
# 0 <= x(22,24) <= 1 Integer
# 0 <= x(22,25) <= 1 Integer
# 0 <= x(22,26) <= 1 Integer
# 0 <= x(22,27) <= 1 Integer
# 0 <= x(22,28) <= 1 Integer
# 0 <= x(22,29) <= 1 Integer
# 0 <= x(22,3) <= 1 Integer
# 0 <= x(22,30) <= 1 Integer
# 0 <= x(22,31) <= 1 Integer
# 0 <= x(22,32) <= 1 Integer
# 0 <= x(22,4) <= 1 Integer
# 0 <= x(22,5) <= 1 Integer
# 0 <= x(22,6) <= 1 Integer
# 0 <= x(22,7) <= 1 Integer
# 0 <= x(22,8) <= 1 Integer
# 0 <= x(22,9) <= 1 Integer
# 0 <= x(23,0) <= 1 Integer
# 0 <= x(23,1) <= 1 Integer
# 0 <= x(23,10) <= 1 Integer
# 0 <= x(23,11) <= 1 Integer
# 0 <= x(23,12) <= 1 Integer
# 0 <= x(23,13) <= 1 Integer
# 0 <= x(23,14) <= 1 Integer
# 0 <= x(23,15) <= 1 Integer
# 0 <= x(23,16) <= 1 Integer
# 0 <= x(23,17) <= 1 Integer
# 0 <= x(23,18) <= 1 Integer
# 0 <= x(23,19) <= 1 Integer
# 0 <= x(23,2) <= 1 Integer
# 0 <= x(23,20) <= 1 Integer
# 0 <= x(23,21) <= 1 Integer
# 0 <= x(23,22) <= 1 Integer
# 0 <= x(23,23) <= 1 Integer
# 0 <= x(23,24) <= 1 Integer
# 0 <= x(23,25) <= 1 Integer
# 0 <= x(23,26) <= 1 Integer
# 0 <= x(23,27) <= 1 Integer
# 0 <= x(23,28) <= 1 Integer
# 0 <= x(23,29) <= 1 Integer
# 0 <= x(23,3) <= 1 Integer
# 0 <= x(23,30) <= 1 Integer
# 0 <= x(23,31) <= 1 Integer
# 0 <= x(23,32) <= 1 Integer
# 0 <= x(23,4) <= 1 Integer
# 0 <= x(23,5) <= 1 Integer
# 0 <= x(23,6) <= 1 Integer
# 0 <= x(23,7) <= 1 Integer
# 0 <= x(23,8) <= 1 Integer
# 0 <= x(23,9) <= 1 Integer
# 0 <= x(24,0) <= 1 Integer
# 0 <= x(24,1) <= 1 Integer
# 0 <= x(24,10) <= 1 Integer
# 0 <= x(24,11) <= 1 Integer
# 0 <= x(24,12) <= 1 Integer
# 0 <= x(24,13) <= 1 Integer
# 0 <= x(24,14) <= 1 Integer
# 0 <= x(24,15) <= 1 Integer
# 0 <= x(24,16) <= 1 Integer
# 0 <= x(24,17) <= 1 Integer
# 0 <= x(24,18) <= 1 Integer
# 0 <= x(24,19) <= 1 Integer
# 0 <= x(24,2) <= 1 Integer
# 0 <= x(24,20) <= 1 Integer
# 0 <= x(24,21) <= 1 Integer
# 0 <= x(24,22) <= 1 Integer
# 0 <= x(24,23) <= 1 Integer
# 0 <= x(24,24) <= 1 Integer
# 0 <= x(24,25) <= 1 Integer
# 0 <= x(24,26) <= 1 Integer
# 0 <= x(24,27) <= 1 Integer
# 0 <= x(24,28) <= 1 Integer
# 0 <= x(24,29) <= 1 Integer
# 0 <= x(24,3) <= 1 Integer
# 0 <= x(24,30) <= 1 Integer
# 0 <= x(24,31) <= 1 Integer
# 0 <= x(24,32) <= 1 Integer
# 0 <= x(24,4) <= 1 Integer
# 0 <= x(24,5) <= 1 Integer
# 0 <= x(24,6) <= 1 Integer
# 0 <= x(24,7) <= 1 Integer
# 0 <= x(24,8) <= 1 Integer
# 0 <= x(24,9) <= 1 Integer
# 0 <= x(25,0) <= 1 Integer
# 0 <= x(25,1) <= 1 Integer
# 0 <= x(25,10) <= 1 Integer
# 0 <= x(25,11) <= 1 Integer
# 0 <= x(25,12) <= 1 Integer
# 0 <= x(25,13) <= 1 Integer
# 0 <= x(25,14) <= 1 Integer
# 0 <= x(25,15) <= 1 Integer
# 0 <= x(25,16) <= 1 Integer
# 0 <= x(25,17) <= 1 Integer
# 0 <= x(25,18) <= 1 Integer
# 0 <= x(25,19) <= 1 Integer
# 0 <= x(25,2) <= 1 Integer
# 0 <= x(25,20) <= 1 Integer
# 0 <= x(25,21) <= 1 Integer
# 0 <= x(25,22) <= 1 Integer
# 0 <= x(25,23) <= 1 Integer
# 0 <= x(25,24) <= 1 Integer
# 0 <= x(25,25) <= 1 Integer
# 0 <= x(25,26) <= 1 Integer
# 0 <= x(25,27) <= 1 Integer
# 0 <= x(25,28) <= 1 Integer
# 0 <= x(25,29) <= 1 Integer
# 0 <= x(25,3) <= 1 Integer
# 0 <= x(25,30) <= 1 Integer
# 0 <= x(25,31) <= 1 Integer
# 0 <= x(25,32) <= 1 Integer
# 0 <= x(25,4) <= 1 Integer
# 0 <= x(25,5) <= 1 Integer
# 0 <= x(25,6) <= 1 Integer
# 0 <= x(25,7) <= 1 Integer
# 0 <= x(25,8) <= 1 Integer
# 0 <= x(25,9) <= 1 Integer
# 0 <= x(26,0) <= 1 Integer
# 0 <= x(26,1) <= 1 Integer
# 0 <= x(26,10) <= 1 Integer
# 0 <= x(26,11) <= 1 Integer
# 0 <= x(26,12) <= 1 Integer
# 0 <= x(26,13) <= 1 Integer
# 0 <= x(26,14) <= 1 Integer
# 0 <= x(26,15) <= 1 Integer
# 0 <= x(26,16) <= 1 Integer
# 0 <= x(26,17) <= 1 Integer
# 0 <= x(26,18) <= 1 Integer
# 0 <= x(26,19) <= 1 Integer
# 0 <= x(26,2) <= 1 Integer
# 0 <= x(26,20) <= 1 Integer
# 0 <= x(26,21) <= 1 Integer
# 0 <= x(26,22) <= 1 Integer
# 0 <= x(26,23) <= 1 Integer
# 0 <= x(26,24) <= 1 Integer
# 0 <= x(26,25) <= 1 Integer
# 0 <= x(26,26) <= 1 Integer
# 0 <= x(26,27) <= 1 Integer
# 0 <= x(26,28) <= 1 Integer
# 0 <= x(26,29) <= 1 Integer
# 0 <= x(26,3) <= 1 Integer
# 0 <= x(26,30) <= 1 Integer
# 0 <= x(26,31) <= 1 Integer
# 0 <= x(26,32) <= 1 Integer
# 0 <= x(26,4) <= 1 Integer
# 0 <= x(26,5) <= 1 Integer
# 0 <= x(26,6) <= 1 Integer
# 0 <= x(26,7) <= 1 Integer
# 0 <= x(26,8) <= 1 Integer
# 0 <= x(26,9) <= 1 Integer
# 0 <= x(27,0) <= 1 Integer
# 0 <= x(27,1) <= 1 Integer
# 0 <= x(27,10) <= 1 Integer
# 0 <= x(27,11) <= 1 Integer
# 0 <= x(27,12) <= 1 Integer
# 0 <= x(27,13) <= 1 Integer
# 0 <= x(27,14) <= 1 Integer
# 0 <= x(27,15) <= 1 Integer
# 0 <= x(27,16) <= 1 Integer
# 0 <= x(27,17) <= 1 Integer
# 0 <= x(27,18) <= 1 Integer
# 0 <= x(27,19) <= 1 Integer
# 0 <= x(27,2) <= 1 Integer
# 0 <= x(27,20) <= 1 Integer
# 0 <= x(27,21) <= 1 Integer
# 0 <= x(27,22) <= 1 Integer
# 0 <= x(27,23) <= 1 Integer
# 0 <= x(27,24) <= 1 Integer
# 0 <= x(27,25) <= 1 Integer
# 0 <= x(27,26) <= 1 Integer
# 0 <= x(27,27) <= 1 Integer
# 0 <= x(27,28) <= 1 Integer
# 0 <= x(27,29) <= 1 Integer
# 0 <= x(27,3) <= 1 Integer
# 0 <= x(27,30) <= 1 Integer
# 0 <= x(27,31) <= 1 Integer
# 0 <= x(27,32) <= 1 Integer
# 0 <= x(27,4) <= 1 Integer
# 0 <= x(27,5) <= 1 Integer
# 0 <= x(27,6) <= 1 Integer
# 0 <= x(27,7) <= 1 Integer
# 0 <= x(27,8) <= 1 Integer
# 0 <= x(27,9) <= 1 Integer
# 0 <= x(28,0) <= 1 Integer
# 0 <= x(28,1) <= 1 Integer
# 0 <= x(28,10) <= 1 Integer
# 0 <= x(28,11) <= 1 Integer
# 0 <= x(28,12) <= 1 Integer
# 0 <= x(28,13) <= 1 Integer
# 0 <= x(28,14) <= 1 Integer
# 0 <= x(28,15) <= 1 Integer
# 0 <= x(28,16) <= 1 Integer
# 0 <= x(28,17) <= 1 Integer
# 0 <= x(28,18) <= 1 Integer
# 0 <= x(28,19) <= 1 Integer
# 0 <= x(28,2) <= 1 Integer
# 0 <= x(28,20) <= 1 Integer
# 0 <= x(28,21) <= 1 Integer
# 0 <= x(28,22) <= 1 Integer
# 0 <= x(28,23) <= 1 Integer
# 0 <= x(28,24) <= 1 Integer
# 0 <= x(28,25) <= 1 Integer
# 0 <= x(28,26) <= 1 Integer
# 0 <= x(28,27) <= 1 Integer
# 0 <= x(28,28) <= 1 Integer
# 0 <= x(28,29) <= 1 Integer
# 0 <= x(28,3) <= 1 Integer
# 0 <= x(28,30) <= 1 Integer
# 0 <= x(28,31) <= 1 Integer
# 0 <= x(28,32) <= 1 Integer
# 0 <= x(28,4) <= 1 Integer
# 0 <= x(28,5) <= 1 Integer
# 0 <= x(28,6) <= 1 Integer
# 0 <= x(28,7) <= 1 Integer
# 0 <= x(28,8) <= 1 Integer
# 0 <= x(28,9) <= 1 Integer
# 0 <= x(29,0) <= 1 Integer
# 0 <= x(29,1) <= 1 Integer
# 0 <= x(29,10) <= 1 Integer
# 0 <= x(29,11) <= 1 Integer
# 0 <= x(29,12) <= 1 Integer
# 0 <= x(29,13) <= 1 Integer
# 0 <= x(29,14) <= 1 Integer
# 0 <= x(29,15) <= 1 Integer
# 0 <= x(29,16) <= 1 Integer
# 0 <= x(29,17) <= 1 Integer
# 0 <= x(29,18) <= 1 Integer
# 0 <= x(29,19) <= 1 Integer
# 0 <= x(29,2) <= 1 Integer
# 0 <= x(29,20) <= 1 Integer
# 0 <= x(29,21) <= 1 Integer
# 0 <= x(29,22) <= 1 Integer
# 0 <= x(29,23) <= 1 Integer
# 0 <= x(29,24) <= 1 Integer
# 0 <= x(29,25) <= 1 Integer
# 0 <= x(29,26) <= 1 Integer
# 0 <= x(29,27) <= 1 Integer
# 0 <= x(29,28) <= 1 Integer
# 0 <= x(29,29) <= 1 Integer
# 0 <= x(29,3) <= 1 Integer
# 0 <= x(29,30) <= 1 Integer
# 0 <= x(29,31) <= 1 Integer
# 0 <= x(29,32) <= 1 Integer
# 0 <= x(29,4) <= 1 Integer
# 0 <= x(29,5) <= 1 Integer
# 0 <= x(29,6) <= 1 Integer
# 0 <= x(29,7) <= 1 Integer
# 0 <= x(29,8) <= 1 Integer
# 0 <= x(29,9) <= 1 Integer
# 0 <= x(3,0) <= 1 Integer
# 0 <= x(3,1) <= 1 Integer
# 0 <= x(3,10) <= 1 Integer
# 0 <= x(3,11) <= 1 Integer
# 0 <= x(3,12) <= 1 Integer
# 0 <= x(3,13) <= 1 Integer
# 0 <= x(3,14) <= 1 Integer
# 0 <= x(3,15) <= 1 Integer
# 0 <= x(3,16) <= 1 Integer
# 0 <= x(3,17) <= 1 Integer
# 0 <= x(3,18) <= 1 Integer
# 0 <= x(3,19) <= 1 Integer
# 0 <= x(3,2) <= 1 Integer
# 0 <= x(3,20) <= 1 Integer
# 0 <= x(3,21) <= 1 Integer
# 0 <= x(3,22) <= 1 Integer
# 0 <= x(3,23) <= 1 Integer
# 0 <= x(3,24) <= 1 Integer
# 0 <= x(3,25) <= 1 Integer
# 0 <= x(3,26) <= 1 Integer
# 0 <= x(3,27) <= 1 Integer
# 0 <= x(3,28) <= 1 Integer
# 0 <= x(3,29) <= 1 Integer
# 0 <= x(3,3) <= 1 Integer
# 0 <= x(3,30) <= 1 Integer
# 0 <= x(3,31) <= 1 Integer
# 0 <= x(3,32) <= 1 Integer
# 0 <= x(3,4) <= 1 Integer
# 0 <= x(3,5) <= 1 Integer
# 0 <= x(3,6) <= 1 Integer
# 0 <= x(3,7) <= 1 Integer
# 0 <= x(3,8) <= 1 Integer
# 0 <= x(3,9) <= 1 Integer
# 0 <= x(30,0) <= 1 Integer
# 0 <= x(30,1) <= 1 Integer
# 0 <= x(30,10) <= 1 Integer
# 0 <= x(30,11) <= 1 Integer
# 0 <= x(30,12) <= 1 Integer
# 0 <= x(30,13) <= 1 Integer
# 0 <= x(30,14) <= 1 Integer
# 0 <= x(30,15) <= 1 Integer
# 0 <= x(30,16) <= 1 Integer
# 0 <= x(30,17) <= 1 Integer
# 0 <= x(30,18) <= 1 Integer
# 0 <= x(30,19) <= 1 Integer
# 0 <= x(30,2) <= 1 Integer
# 0 <= x(30,20) <= 1 Integer
# 0 <= x(30,21) <= 1 Integer
# 0 <= x(30,22) <= 1 Integer
# 0 <= x(30,23) <= 1 Integer
# 0 <= x(30,24) <= 1 Integer
# 0 <= x(30,25) <= 1 Integer
# 0 <= x(30,26) <= 1 Integer
# 0 <= x(30,27) <= 1 Integer
# 0 <= x(30,28) <= 1 Integer
# 0 <= x(30,29) <= 1 Integer
# 0 <= x(30,3) <= 1 Integer
# 0 <= x(30,30) <= 1 Integer
# 0 <= x(30,31) <= 1 Integer
# 0 <= x(30,32) <= 1 Integer
# 0 <= x(30,4) <= 1 Integer
# 0 <= x(30,5) <= 1 Integer
# 0 <= x(30,6) <= 1 Integer
# 0 <= x(30,7) <= 1 Integer
# 0 <= x(30,8) <= 1 Integer
# 0 <= x(30,9) <= 1 Integer
# 0 <= x(31,0) <= 1 Integer
# 0 <= x(31,1) <= 1 Integer
# 0 <= x(31,10) <= 1 Integer
# 0 <= x(31,11) <= 1 Integer
# 0 <= x(31,12) <= 1 Integer
# 0 <= x(31,13) <= 1 Integer
# 0 <= x(31,14) <= 1 Integer
# 0 <= x(31,15) <= 1 Integer
# 0 <= x(31,16) <= 1 Integer
# 0 <= x(31,17) <= 1 Integer
# 0 <= x(31,18) <= 1 Integer
# 0 <= x(31,19) <= 1 Integer
# 0 <= x(31,2) <= 1 Integer
# 0 <= x(31,20) <= 1 Integer
# 0 <= x(31,21) <= 1 Integer
# 0 <= x(31,22) <= 1 Integer
# 0 <= x(31,23) <= 1 Integer
# 0 <= x(31,24) <= 1 Integer
# 0 <= x(31,25) <= 1 Integer
# 0 <= x(31,26) <= 1 Integer
# 0 <= x(31,27) <= 1 Integer
# 0 <= x(31,28) <= 1 Integer
# 0 <= x(31,29) <= 1 Integer
# 0 <= x(31,3) <= 1 Integer
# 0 <= x(31,30) <= 1 Integer
# 0 <= x(31,31) <= 1 Integer
# 0 <= x(31,32) <= 1 Integer
# 0 <= x(31,4) <= 1 Integer
# 0 <= x(31,5) <= 1 Integer
# 0 <= x(31,6) <= 1 Integer
# 0 <= x(31,7) <= 1 Integer
# 0 <= x(31,8) <= 1 Integer
# 0 <= x(31,9) <= 1 Integer
# 0 <= x(32,0) <= 1 Integer
# 0 <= x(32,1) <= 1 Integer
# 0 <= x(32,10) <= 1 Integer
# 0 <= x(32,11) <= 1 Integer
# 0 <= x(32,12) <= 1 Integer
# 0 <= x(32,13) <= 1 Integer
# 0 <= x(32,14) <= 1 Integer
# 0 <= x(32,15) <= 1 Integer
# 0 <= x(32,16) <= 1 Integer
# 0 <= x(32,17) <= 1 Integer
# 0 <= x(32,18) <= 1 Integer
# 0 <= x(32,19) <= 1 Integer
# 0 <= x(32,2) <= 1 Integer
# 0 <= x(32,20) <= 1 Integer
# 0 <= x(32,21) <= 1 Integer
# 0 <= x(32,22) <= 1 Integer
# 0 <= x(32,23) <= 1 Integer
# 0 <= x(32,24) <= 1 Integer
# 0 <= x(32,25) <= 1 Integer
# 0 <= x(32,26) <= 1 Integer
# 0 <= x(32,27) <= 1 Integer
# 0 <= x(32,28) <= 1 Integer
# 0 <= x(32,29) <= 1 Integer
# 0 <= x(32,3) <= 1 Integer
# 0 <= x(32,30) <= 1 Integer
# 0 <= x(32,31) <= 1 Integer
# 0 <= x(32,32) <= 1 Integer
# 0 <= x(32,4) <= 1 Integer
# 0 <= x(32,5) <= 1 Integer
# 0 <= x(32,6) <= 1 Integer
# 0 <= x(32,7) <= 1 Integer
# 0 <= x(32,8) <= 1 Integer
# 0 <= x(32,9) <= 1 Integer
# 0 <= x(4,0) <= 1 Integer
# 0 <= x(4,1) <= 1 Integer
# 0 <= x(4,10) <= 1 Integer
# 0 <= x(4,11) <= 1 Integer
# 0 <= x(4,12) <= 1 Integer
# 0 <= x(4,13) <= 1 Integer
# 0 <= x(4,14) <= 1 Integer
# 0 <= x(4,15) <= 1 Integer
# 0 <= x(4,16) <= 1 Integer
# 0 <= x(4,17) <= 1 Integer
# 0 <= x(4,18) <= 1 Integer
# 0 <= x(4,19) <= 1 Integer
# 0 <= x(4,2) <= 1 Integer
# 0 <= x(4,20) <= 1 Integer
# 0 <= x(4,21) <= 1 Integer
# 0 <= x(4,22) <= 1 Integer
# 0 <= x(4,23) <= 1 Integer
# 0 <= x(4,24) <= 1 Integer
# 0 <= x(4,25) <= 1 Integer
# 0 <= x(4,26) <= 1 Integer
# 0 <= x(4,27) <= 1 Integer
# 0 <= x(4,28) <= 1 Integer
# 0 <= x(4,29) <= 1 Integer
# 0 <= x(4,3) <= 1 Integer
# 0 <= x(4,30) <= 1 Integer
# 0 <= x(4,31) <= 1 Integer
# 0 <= x(4,32) <= 1 Integer
# 0 <= x(4,4) <= 1 Integer
# 0 <= x(4,5) <= 1 Integer
# 0 <= x(4,6) <= 1 Integer
# 0 <= x(4,7) <= 1 Integer
# 0 <= x(4,8) <= 1 Integer
# 0 <= x(4,9) <= 1 Integer
# 0 <= x(5,0) <= 1 Integer
# 0 <= x(5,1) <= 1 Integer
# 0 <= x(5,10) <= 1 Integer
# 0 <= x(5,11) <= 1 Integer
# 0 <= x(5,12) <= 1 Integer
# 0 <= x(5,13) <= 1 Integer
# 0 <= x(5,14) <= 1 Integer
# 0 <= x(5,15) <= 1 Integer
# 0 <= x(5,16) <= 1 Integer
# 0 <= x(5,17) <= 1 Integer
# 0 <= x(5,18) <= 1 Integer
# 0 <= x(5,19) <= 1 Integer
# 0 <= x(5,2) <= 1 Integer
# 0 <= x(5,20) <= 1 Integer
# 0 <= x(5,21) <= 1 Integer
# 0 <= x(5,22) <= 1 Integer
# 0 <= x(5,23) <= 1 Integer
# 0 <= x(5,24) <= 1 Integer
# 0 <= x(5,25) <= 1 Integer
# 0 <= x(5,26) <= 1 Integer
# 0 <= x(5,27) <= 1 Integer
# 0 <= x(5,28) <= 1 Integer
# 0 <= x(5,29) <= 1 Integer
# 0 <= x(5,3) <= 1 Integer
# 0 <= x(5,30) <= 1 Integer
# 0 <= x(5,31) <= 1 Integer
# 0 <= x(5,32) <= 1 Integer
# 0 <= x(5,4) <= 1 Integer
# 0 <= x(5,5) <= 1 Integer
# 0 <= x(5,6) <= 1 Integer
# 0 <= x(5,7) <= 1 Integer
# 0 <= x(5,8) <= 1 Integer
# 0 <= x(5,9) <= 1 Integer
# 0 <= x(6,0) <= 1 Integer
# 0 <= x(6,1) <= 1 Integer
# 0 <= x(6,10) <= 1 Integer
# 0 <= x(6,11) <= 1 Integer
# 0 <= x(6,12) <= 1 Integer
# 0 <= x(6,13) <= 1 Integer
# 0 <= x(6,14) <= 1 Integer
# 0 <= x(6,15) <= 1 Integer
# 0 <= x(6,16) <= 1 Integer
# 0 <= x(6,17) <= 1 Integer
# 0 <= x(6,18) <= 1 Integer
# 0 <= x(6,19) <= 1 Integer
# 0 <= x(6,2) <= 1 Integer
# 0 <= x(6,20) <= 1 Integer
# 0 <= x(6,21) <= 1 Integer
# 0 <= x(6,22) <= 1 Integer
# 0 <= x(6,23) <= 1 Integer
# 0 <= x(6,24) <= 1 Integer
# 0 <= x(6,25) <= 1 Integer
# 0 <= x(6,26) <= 1 Integer
# 0 <= x(6,27) <= 1 Integer
# 0 <= x(6,28) <= 1 Integer
# 0 <= x(6,29) <= 1 Integer
# 0 <= x(6,3) <= 1 Integer
# 0 <= x(6,30) <= 1 Integer
# 0 <= x(6,31) <= 1 Integer
# 0 <= x(6,32) <= 1 Integer
# 0 <= x(6,4) <= 1 Integer
# 0 <= x(6,5) <= 1 Integer
# 0 <= x(6,6) <= 1 Integer
# 0 <= x(6,7) <= 1 Integer
# 0 <= x(6,8) <= 1 Integer
# 0 <= x(6,9) <= 1 Integer
# 0 <= x(7,0) <= 1 Integer
# 0 <= x(7,1) <= 1 Integer
# 0 <= x(7,10) <= 1 Integer
# 0 <= x(7,11) <= 1 Integer
# 0 <= x(7,12) <= 1 Integer
# 0 <= x(7,13) <= 1 Integer
# 0 <= x(7,14) <= 1 Integer
# 0 <= x(7,15) <= 1 Integer
# 0 <= x(7,16) <= 1 Integer
# 0 <= x(7,17) <= 1 Integer
# 0 <= x(7,18) <= 1 Integer
# 0 <= x(7,19) <= 1 Integer
# 0 <= x(7,2) <= 1 Integer
# 0 <= x(7,20) <= 1 Integer
# 0 <= x(7,21) <= 1 Integer
# 0 <= x(7,22) <= 1 Integer
# 0 <= x(7,23) <= 1 Integer
# 0 <= x(7,24) <= 1 Integer
# 0 <= x(7,25) <= 1 Integer
# 0 <= x(7,26) <= 1 Integer
# 0 <= x(7,27) <= 1 Integer
# 0 <= x(7,28) <= 1 Integer
# 0 <= x(7,29) <= 1 Integer
# 0 <= x(7,3) <= 1 Integer
# 0 <= x(7,30) <= 1 Integer
# 0 <= x(7,31) <= 1 Integer
# 0 <= x(7,32) <= 1 Integer
# 0 <= x(7,4) <= 1 Integer
# 0 <= x(7,5) <= 1 Integer
# 0 <= x(7,6) <= 1 Integer
# 0 <= x(7,7) <= 1 Integer
# 0 <= x(7,8) <= 1 Integer
# 0 <= x(7,9) <= 1 Integer
# 0 <= x(8,0) <= 1 Integer
# 0 <= x(8,1) <= 1 Integer
# 0 <= x(8,10) <= 1 Integer
# 0 <= x(8,11) <= 1 Integer
# 0 <= x(8,12) <= 1 Integer
# 0 <= x(8,13) <= 1 Integer
# 0 <= x(8,14) <= 1 Integer
# 0 <= x(8,15) <= 1 Integer
# 0 <= x(8,16) <= 1 Integer
# 0 <= x(8,17) <= 1 Integer
# 0 <= x(8,18) <= 1 Integer
# 0 <= x(8,19) <= 1 Integer
# 0 <= x(8,2) <= 1 Integer
# 0 <= x(8,20) <= 1 Integer
# 0 <= x(8,21) <= 1 Integer
# 0 <= x(8,22) <= 1 Integer
# 0 <= x(8,23) <= 1 Integer
# 0 <= x(8,24) <= 1 Integer
# 0 <= x(8,25) <= 1 Integer
# 0 <= x(8,26) <= 1 Integer
# 0 <= x(8,27) <= 1 Integer
# 0 <= x(8,28) <= 1 Integer
# 0 <= x(8,29) <= 1 Integer
# 0 <= x(8,3) <= 1 Integer
# 0 <= x(8,30) <= 1 Integer
# 0 <= x(8,31) <= 1 Integer
# 0 <= x(8,32) <= 1 Integer
# 0 <= x(8,4) <= 1 Integer
# 0 <= x(8,5) <= 1 Integer
# 0 <= x(8,6) <= 1 Integer
# 0 <= x(8,7) <= 1 Integer
# 0 <= x(8,8) <= 1 Integer
# 0 <= x(8,9) <= 1 Integer
# 0 <= x(9,0) <= 1 Integer
# 0 <= x(9,1) <= 1 Integer
# 0 <= x(9,10) <= 1 Integer
# 0 <= x(9,11) <= 1 Integer
# 0 <= x(9,12) <= 1 Integer
# 0 <= x(9,13) <= 1 Integer
# 0 <= x(9,14) <= 1 Integer
# 0 <= x(9,15) <= 1 Integer
# 0 <= x(9,16) <= 1 Integer
# 0 <= x(9,17) <= 1 Integer
# 0 <= x(9,18) <= 1 Integer
# 0 <= x(9,19) <= 1 Integer
# 0 <= x(9,2) <= 1 Integer
# 0 <= x(9,20) <= 1 Integer
# 0 <= x(9,21) <= 1 Integer
# 0 <= x(9,22) <= 1 Integer
# 0 <= x(9,23) <= 1 Integer
# 0 <= x(9,24) <= 1 Integer
# 0 <= x(9,25) <= 1 Integer
# 0 <= x(9,26) <= 1 Integer
# 0 <= x(9,27) <= 1 Integer
# 0 <= x(9,28) <= 1 Integer
# 0 <= x(9,29) <= 1 Integer
# 0 <= x(9,3) <= 1 Integer
# 0 <= x(9,30) <= 1 Integer
# 0 <= x(9,31) <= 1 Integer
# 0 <= x(9,32) <= 1 Integer
# 0 <= x(9,4) <= 1 Integer
# 0 <= x(9,5) <= 1 Integer
# 0 <= x(9,6) <= 1 Integer
# 0 <= x(9,7) <= 1 Integer
# 0 <= x(9,8) <= 1 Integer
# 0 <= x(9,9) <= 1 Integer
# y0 Continuous
# y1 Continuous
# y10 Continuous
# y11 Continuous
# y12 Continuous
# y13 Continuous
# y14 Continuous
# y15 Continuous
# y16 Continuous
# y17 Continuous
# y18 Continuous
# y19 Continuous
# y2 Continuous
# y20 Continuous
# y21 Continuous
# y22 Continuous
# y23 Continuous
# y24 Continuous
# y25 Continuous
# y26 Continuous
# y27 Continuous
# y28 Continuous
# y29 Continuous
# y3 Continuous
# y30 Continuous
# y31 Continuous
# y32 Continuous
# y4 Continuous
# y5 Continuous
# y6 Continuous
# y7 Continuous
# y8 Continuous
# y9 Continuous

# %%
lp.solve()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-393-34bddfdcab75> in <module>
# ----> 1 lp.solve()
#
# <ipython-input-382-4292d75fb8f4> in solve(self)
#      80
#      81     def solve(self):
# ---> 82         status = self.cvrpLP.solve()
#      83         print(pulp.LpStatus[self.cvrpLP.status])
#      84
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pulp/pulp.py in solve(self, solver, **kwargs)
#    1662         #time it
#    1663         self.solutionTime = -clock()
# -> 1664         status = solver.actualSolve(self, **kwargs)
#    1665         self.solutionTime += clock()
#    1666         self.restoreObjective(wasNone, dummyVar)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pulp/solvers.py in actualSolve(self, lp, **kwargs)
#    1360     def actualSolve(self, lp, **kwargs):
#    1361         """Solve a well formulated lp problem"""
# -> 1362         return self.solve_CBC(lp, **kwargs)
#    1363
#    1364     def available(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pulp/solvers.py in solve_CBC(self, lp, use_mps)
#    1419         cbc = subprocess.Popen((self.path + cmds).split(), stdout = pipe,
#    1420                              stderr = pipe)
# -> 1421         if cbc.wait() != 0:
#    1422             raise PulpSolverError("Pulp: Error while trying to execute " +  \
#    1423                                     self.path)
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#     988             endtime = _time() + timeout
#     989         try:
# --> 990             return self._wait(timeout=timeout)
#     991         except KeyboardInterrupt:
#     992             # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1622                         if self.returncode is not None:
#    1623                             break  # Another thread waited.
# -> 1624                         (pid, sts) = self._try_wait(0)
#    1625                         # Check the pid and loop as waitpid has been known to
#    1626                         # return 0 even without WNOHANG in odd situations.
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1580             """All callers to this function MUST hold self._waitpid_lock."""
#    1581             try:
# -> 1582                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1583             except ChildProcessError:
#    1584                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
lp.getResult()

# %% [markdown]
# ### TESTING 2

# %%
numberOfCustomers = 15
capacityOfVehicle = 35
numberOfVehicles = 8
C = [i for i in range(1, numberOfCustomers+1)] #set of customers
V = [0] + C + [numberOfCustomers+1] #depot + customer nodes
demandOfCustomers = {0:0,1:19,2:30,3:16,4:23,5:11,6:31,7:15,8:28,9:8,10:8,11:7,12:14,13:6,14:19,15:11}
# demandOfCustomers[0] = 0
demandOfCustomers[numberOfCustomers+1] = 0

# %%
xCoordinates = [30,37,49,52,31,52,42,52,57,62,42,27,43,58,58,37,30]
yCoordinates = [40,52,49,64,62,33,41,41,58,42,57,68,67,48,27,69,40]

# Cost matrix
costMatrix = np.ndarray(shape=(len(V),len(V)))
for i in range(len(V)):
    for j in range(len(V)):
        if(i == 0 and j == len(V)-1):
            costMatrix[i][j] = 0
            continue
        
        if(j == 0 and i == len(V)-1):
            costMatrix[i][j] = 0
            continue
        
        if(i!=j):
            costMatrix[i][j] = int(distance.euclidean([xCoordinates[i],yCoordinates[i]], [xCoordinates[j],yCoordinates[j]]))
        else:
            costMatrix[i][j] = 999999

# %%
lp = CVRP(numberOfCustomers, numberOfVehicles, capacityOfVehicle, demandOfCustomers, costMatrix)
# Out:
# CVRP:
# MINIMIZE
# 999999.0*x(0,0) + 13.0*x(0,1) + 20.0*x(0,10) + 28.0*x(0,11) + 29.0*x(0,12) + 29.0*x(0,13) + 30.0*x(0,14) + 29.0*x(0,15) + 21.0*x(0,2) + 32.0*x(0,3) + 22.0*x(0,4) + 23.0*x(0,5) + 12.0*x(0,6) + 22.0*x(0,7) + 32.0*x(0,8) + 32.0*x(0,9) + 13.0*x(1,0) + 999999.0*x(1,1) + 7.0*x(1,10) + 18.0*x(1,11) + 16.0*x(1,12) + 21.0*x(1,13) + 32.0*x(1,14) + 17.0*x(1,15) + 13.0*x(1,16) + 12.0*x(1,2) + 19.0*x(1,3) + 11.0*x(1,4) + 24.0*x(1,5) + 12.0*x(1,6) + 18.0*x(1,7) + 20.0*x(1,8) + 26.0*x(1,9) + 20.0*x(10,0) + 7.0*x(10,1) + 999999.0*x(10,10) + 18.0*x(10,11) + 10.0*x(10,12) + 18.0*x(10,13) + 34.0*x(10,14) + 13.0*x(10,15) + 20.0*x(10,16) + 10.0*x(10,2) + 12.0*x(10,3) + 12.0*x(10,4) + 26.0*x(10,5) + 16.0*x(10,6) + 18.0*x(10,7) + 15.0*x(10,8) + 25.0*x(10,9) + 28.0*x(11,0) + 18.0*x(11,1) + 18.0*x(11,10) + 999999.0*x(11,11) + 16.0*x(11,12) + 36.0*x(11,13) + 51.0*x(11,14) + 10.0*x(11,15) + 28.0*x(11,16) + 29.0*x(11,2) + 25.0*x(11,3) + 7.0*x(11,4) + 43.0*x(11,5) + 30.0*x(11,6) + 36.0*x(11,7) + 31.0*x(11,8) + 43.0*x(11,9) + 29.0*x(12,0) + 16.0*x(12,1) + 10.0*x(12,10) + 16.0*x(12,11) + 999999.0*x(12,12) + 24.0*x(12,13) + 42.0*x(12,14) + 6.0*x(12,15) + 29.0*x(12,16) + 18.0*x(12,2) + 9.0*x(12,3) + 13.0*x(12,4) + 35.0*x(12,5) + 26.0*x(12,6) + 27.0*x(12,7) + 16.0*x(12,8) + 31.0*x(12,9) + 29.0*x(13,0) + 21.0*x(13,1) + 18.0*x(13,10) + 36.0*x(13,11) + 24.0*x(13,12) + 999999.0*x(13,13) + 21.0*x(13,14) + 29.0*x(13,15) + 29.0*x(13,16) + 9.0*x(13,2) + 17.0*x(13,3) + 30.0*x(13,4) + 16.0*x(13,5) + 17.0*x(13,6) + 9.0*x(13,7) + 10.0*x(13,8) + 7.0*x(13,9) + 30.0*x(14,0) + 32.0*x(14,1) + 34.0*x(14,10) + 51.0*x(14,11) + 42.0*x(14,12) + 21.0*x(14,13) + 999999.0*x(14,14) + 46.0*x(14,15) + 30.0*x(14,16) + 23.0*x(14,2) + 37.0*x(14,3) + 44.0*x(14,4) + 8.0*x(14,5) + 21.0*x(14,6) + 15.0*x(14,7) + 31.0*x(14,8) + 15.0*x(14,9) + 29.0*x(15,0) + 17.0*x(15,1) + 13.0*x(15,10) + 10.0*x(15,11) + 6.0*x(15,12) + 29.0*x(15,13) + 46.0*x(15,14) + 999999.0*x(15,15) + 29.0*x(15,16) + 23.0*x(15,2) + 15.0*x(15,3) + 9.0*x(15,4) + 39.0*x(15,5) + 28.0*x(15,6) + 31.0*x(15,7) + 22.0*x(15,8) + 36.0*x(15,9) + 13.0*x(16,1) + 20.0*x(16,10) + 28.0*x(16,11) + 29.0*x(16,12) + 29.0*x(16,13) + 30.0*x(16,14) + 29.0*x(16,15) + 999999.0*x(16,16) + 21.0*x(16,2) + 32.0*x(16,3) + 22.0*x(16,4) + 23.0*x(16,5) + 12.0*x(16,6) + 22.0*x(16,7) + 32.0*x(16,8) + 32.0*x(16,9) + 21.0*x(2,0) + 12.0*x(2,1) + 10.0*x(2,10) + 29.0*x(2,11) + 18.0*x(2,12) + 9.0*x(2,13) + 23.0*x(2,14) + 23.0*x(2,15) + 21.0*x(2,16) + 999999.0*x(2,2) + 15.0*x(2,3) + 22.0*x(2,4) + 16.0*x(2,5) + 10.0*x(2,6) + 8.0*x(2,7) + 12.0*x(2,8) + 14.0*x(2,9) + 32.0*x(3,0) + 19.0*x(3,1) + 12.0*x(3,10) + 25.0*x(3,11) + 9.0*x(3,12) + 17.0*x(3,13) + 37.0*x(3,14) + 15.0*x(3,15) + 32.0*x(3,16) + 15.0*x(3,2) + 999999.0*x(3,3) + 21.0*x(3,4) + 31.0*x(3,5) + 25.0*x(3,6) + 23.0*x(3,7) + 7.0*x(3,8) + 24.0*x(3,9) + 22.0*x(4,0) + 11.0*x(4,1) + 12.0*x(4,10) + 7.0*x(4,11) + 13.0*x(4,12) + 30.0*x(4,13) + 44.0*x(4,14) + 9.0*x(4,15) + 22.0*x(4,16) + 22.0*x(4,2) + 21.0*x(4,3) + 999999.0*x(4,4) + 35.0*x(4,5) + 23.0*x(4,6) + 29.0*x(4,7) + 26.0*x(4,8) + 36.0*x(4,9) + 23.0*x(5,0) + 24.0*x(5,1) + 26.0*x(5,10) + 43.0*x(5,11) + 35.0*x(5,12) + 16.0*x(5,13) + 8.0*x(5,14) + 39.0*x(5,15) + 23.0*x(5,16) + 16.0*x(5,2) + 31.0*x(5,3) + 35.0*x(5,4) + 999999.0*x(5,5) + 12.0*x(5,6) + 8.0*x(5,7) + 25.0*x(5,8) + 13.0*x(5,9) + 12.0*x(6,0) + 12.0*x(6,1) + 16.0*x(6,10) + 30.0*x(6,11) + 26.0*x(6,12) + 17.0*x(6,13) + 21.0*x(6,14) + 28.0*x(6,15) + 12.0*x(6,16) + 10.0*x(6,2) + 25.0*x(6,3) + 23.0*x(6,4) + 12.0*x(6,5) + 999999.0*x(6,6) + 10.0*x(6,7) + 22.0*x(6,8) + 20.0*x(6,9) + 22.0*x(7,0) + 18.0*x(7,1) + 18.0*x(7,10) + 36.0*x(7,11) + 27.0*x(7,12) + 9.0*x(7,13) + 15.0*x(7,14) + 31.0*x(7,15) + 22.0*x(7,16) + 8.0*x(7,2) + 23.0*x(7,3) + 29.0*x(7,4) + 8.0*x(7,5) + 10.0*x(7,6) + 999999.0*x(7,7) + 17.0*x(7,8) + 10.0*x(7,9) + 32.0*x(8,0) + 20.0*x(8,1) + 15.0*x(8,10) + 31.0*x(8,11) + 16.0*x(8,12) + 10.0*x(8,13) + 31.0*x(8,14) + 22.0*x(8,15) + 32.0*x(8,16) + 12.0*x(8,2) + 7.0*x(8,3) + 26.0*x(8,4) + 25.0*x(8,5) + 22.0*x(8,6 ...
# SUBJECT TO
# _C1: x(1,10) + x(1,11) + x(1,12) + x(1,13) + x(1,14) + x(1,15) + x(1,16)
#  + x(1,2) + x(1,3) + x(1,4) + x(1,5) + x(1,6) + x(1,7) + x(1,8) + x(1,9) = 1
#
# _C2: x(2,1) + x(2,10) + x(2,11) + x(2,12) + x(2,13) + x(2,14) + x(2,15)
#  + x(2,16) + x(2,3) + x(2,4) + x(2,5) + x(2,6) + x(2,7) + x(2,8) + x(2,9) = 1
#
# _C3: x(3,1) + x(3,10) + x(3,11) + x(3,12) + x(3,13) + x(3,14) + x(3,15)
#  + x(3,16) + x(3,2) + x(3,4) + x(3,5) + x(3,6) + x(3,7) + x(3,8) + x(3,9) = 1
#
# _C4: x(4,1) + x(4,10) + x(4,11) + x(4,12) + x(4,13) + x(4,14) + x(4,15)
#  + x(4,16) + x(4,2) + x(4,3) + x(4,5) + x(4,6) + x(4,7) + x(4,8) + x(4,9) = 1
#
# _C5: x(5,1) + x(5,10) + x(5,11) + x(5,12) + x(5,13) + x(5,14) + x(5,15)
#  + x(5,16) + x(5,2) + x(5,3) + x(5,4) + x(5,6) + x(5,7) + x(5,8) + x(5,9) = 1
#
# _C6: x(6,1) + x(6,10) + x(6,11) + x(6,12) + x(6,13) + x(6,14) + x(6,15)
#  + x(6,16) + x(6,2) + x(6,3) + x(6,4) + x(6,5) + x(6,7) + x(6,8) + x(6,9) = 1
#
# _C7: x(7,1) + x(7,10) + x(7,11) + x(7,12) + x(7,13) + x(7,14) + x(7,15)
#  + x(7,16) + x(7,2) + x(7,3) + x(7,4) + x(7,5) + x(7,6) + x(7,8) + x(7,9) = 1
#
# _C8: x(8,1) + x(8,10) + x(8,11) + x(8,12) + x(8,13) + x(8,14) + x(8,15)
#  + x(8,16) + x(8,2) + x(8,3) + x(8,4) + x(8,5) + x(8,6) + x(8,7) + x(8,9) = 1
#
# _C9: x(9,1) + x(9,10) + x(9,11) + x(9,12) + x(9,13) + x(9,14) + x(9,15)
#  + x(9,16) + x(9,2) + x(9,3) + x(9,4) + x(9,5) + x(9,6) + x(9,7) + x(9,8) = 1
#
# _C10: x(10,1) + x(10,11) + x(10,12) + x(10,13) + x(10,14) + x(10,15)
#  + x(10,16) + x(10,2) + x(10,3) + x(10,4) + x(10,5) + x(10,6) + x(10,7)
#  + x(10,8) + x(10,9) = 1
#
# _C11: x(11,1) + x(11,10) + x(11,12) + x(11,13) + x(11,14) + x(11,15)
#  + x(11,16) + x(11,2) + x(11,3) + x(11,4) + x(11,5) + x(11,6) + x(11,7)
#  + x(11,8) + x(11,9) = 1
#
# _C12: x(12,1) + x(12,10) + x(12,11) + x(12,13) + x(12,14) + x(12,15)
#  + x(12,16) + x(12,2) + x(12,3) + x(12,4) + x(12,5) + x(12,6) + x(12,7)
#  + x(12,8) + x(12,9) = 1
#
# _C13: x(13,1) + x(13,10) + x(13,11) + x(13,12) + x(13,14) + x(13,15)
#  + x(13,16) + x(13,2) + x(13,3) + x(13,4) + x(13,5) + x(13,6) + x(13,7)
#  + x(13,8) + x(13,9) = 1
#
# _C14: x(14,1) + x(14,10) + x(14,11) + x(14,12) + x(14,13) + x(14,15)
#  + x(14,16) + x(14,2) + x(14,3) + x(14,4) + x(14,5) + x(14,6) + x(14,7)
#  + x(14,8) + x(14,9) = 1
#
# _C15: x(15,1) + x(15,10) + x(15,11) + x(15,12) + x(15,13) + x(15,14)
#  + x(15,16) + x(15,2) + x(15,3) + x(15,4) + x(15,5) + x(15,6) + x(15,7)
#  + x(15,8) + x(15,9) = 1
#
# _C16: x(0,1) + x(0,10) + x(0,11) + x(0,12) + x(0,13) + x(0,14) + x(0,15)
#  + x(0,2) + x(0,3) + x(0,4) + x(0,5) + x(0,6) + x(0,7) + x(0,8) + x(0,9) <= 8
#
# _C17: y0 <= 35
#
# _C18: y1 <= 35
#
# _C19: y2 <= 35
#
# _C20: y3 <= 35
#
# _C21: y4 <= 35
#
# _C22: y5 <= 35
#
# _C23: y6 <= 35
#
# _C24: y7 <= 35
#
# _C25: y8 <= 35
#
# _C26: y9 <= 35
#
# _C27: y10 <= 35
#
# _C28: y11 <= 35
#
# _C29: y12 <= 35
#
# _C30: y13 <= 35
#
# _C31: y14 <= 35
#
# _C32: y15 <= 35
#
# _C33: y16 <= 35
#
# _C34: - 35 x(0,0) + 0 y0 >= -35
#
# _C35: - 54 x(0,1) - y0 + y1 >= -35
#
# _C36: - 65 x(0,2) - y0 + y2 >= -35
#
# _C37: - 51 x(0,3) - y0 + y3 >= -35
#
# _C38: - 58 x(0,4) - y0 + y4 >= -35
#
# _C39: - 46 x(0,5) - y0 + y5 >= -35
#
# _C40: - 66 x(0,6) - y0 + y6 >= -35
#
# _C41: - 50 x(0,7) - y0 + y7 >= -35
#
# _C42: - 63 x(0,8) - y0 + y8 >= -35
#
# _C43: - 43 x(0,9) - y0 + y9 >= -35
#
# _C44: - 43 x(0,10) - y0 + y10 >= -35
#
# _C45: - 42 x(0,11) - y0 + y11 >= -35
#
# _C46: - 49 x(0,12) - y0 + y12 >= -35
#
# _C47: - 41 x(0,13) - y0 + y13 >= -35
#
# _C48: - 54 x(0,14) - y0 + y14 >= -35
#
# _C49: - 46 x(0,15) - y0 + y15 >= -35
#
# _C50: - 35 x(0,16) - y0 + y16 >= -35
#
# _C51: - 35 x(1,0) + y0 - y1 >= -35
#
# _C52: - 54 x(1,1) + 0 y1 >= -35
#
# _C53: - 65 x(1,2) - y1 + y2 >= -35
#
# _C54: - 51 x(1,3) - y1 + y3 >= -35
#
# _C55: - 58 x(1,4) - y1 + y4 >= -35
#
# _C56: - 46 x(1,5) - y1 + y5 >= -35
#
# _C57: - 66 x(1,6) - y1 + y6 >= -35
#
# _C58: - 50 x(1,7) - y1 + y7 >= -35
#
# _C59: - 63 x(1,8) - y1 + y8 >= -35
#
# _C60: - 43 x(1,9) - y1 + y9 >= -35
#
# _C61: - 43 x(1,10) - y1 + y10 >= -35
#
# _C62: - 42 x(1,11) - y1 + y11 >= -35
#
# _C63: - 49 x(1,12) - y1 + y12 >= -35
#
# _C64: - 41 x(1,13) - y1 + y13 >= -35
#
# _C65: - 54 x(1,14) - y1 + y14 >= -35
#
# _C66: - 46 x(1,15) - y1 + y15 >= -35
#
# _C67: - 35 x(1,16) - y1 + y16 >= -35
#
# _C68: - 35 x(2,0) + y0 - y2 >= -35
#
# _C69: - 54 x(2,1) + y1 - y2 >= -35
#
# _C70: - 65 x(2,2) + 0 y2 >= -35
#
# _C71: - 51 x(2,3) - y2 + y3 >= -35
#
# _C72: - 58 x(2,4) - y2 + y4 >= -35
#
# _C73: - 46 x(2,5) - y2 + y5 >= -35
#
# _C74: - 66 x(2,6) - y2 + y6 >= -35
#
# _C75: - 50 x(2,7) - y2 + y7 >= -35
#
# _C76: - 63 x(2,8) - y2 + y8 >= -35
#
# _C77: - 43 x(2,9) - y2 + y9 >= -35
#
# _C78: - 43 x(2,10) + y10 - y2 >= -35
#
# _C79: - 42 x(2,11) + y11 - y2 >= -35
#
# _C80: - 49 x(2,12) + y12 - y2 >= -35
#
# _C81: - 41 x(2,13) + y13 - y2 >= -35
#
# _C82: - 54 x(2,14) + y14 - y2 >= -35
#
# _C83: - 46 x(2,15) + y15 - y2 >= -35
#
# _C84: - 35 x(2,16) + y16 - y2 >= -35
#
# _C85: - 35 x(3,0) + y0 - y3 >= -35
#
# _C86: - 54 x(3,1) + y1 - y3 >= -35
#
# _C87: - 65 x(3,2) + y2 - y3 >= -35
#
# _C88: - 51 x(3,3) + 0 y3 >= -35
#
# _C89: - 58 x(3,4) - y3 + y4 >= -35
#
# _C90: - 46 x(3,5) - y3 + y5 >= -35
#
# _C91: - 66 x(3,6) - y3 + y6 >= -35
#
# _C92: - 50 x(3,7) - y3 + y7 >= -35
#
# _C93: - 63 x(3,8) - y3 + y8 >= -35
#
# _C94: - 43 x(3,9) - y3 + y9 >= -35
#
# _C95: - 43 x(3,10) + y10 - y3 >= -35
#
# _C96: - 42 x(3,11) + y11 - y3 >= -35
#
# _C97: - 49 x(3,12) + y12 - y3 >= -35
#
# _C98: - 41 x(3,13) + y13 - y3 >= -35
#
# _C99: - 54 x(3,14) + y14 - y3 >= -35
#
# _C100: - 46 x(3,15) + y15 - y3 >= -35
#
# _C101: - 35 x(3,16) + y16 - y3 >= -35
#
# _C102: - 35 x(4,0) + y0 - y4 >= -35
#
# _C103: - 54 x(4,1) + y1 - y4 >= -35
#
# _C104: - 65 x(4,2) + y2 - y4 >= -35
#
# _C105: - 51 x(4,3) + y3 - y4 >= -35
#
# _C106: - 58 x(4,4) + 0 y4 >= -35
#
# _C107: - 46 x(4,5) - y4 + y5 >= -35
#
# _C108: - 66 x(4,6) - y4 + y6 >= -35
#
# _C109: - 50 x(4,7) - y4 + y7 >= -35
#
# _C110: - 63 x(4,8) - y4 + y8 >= -35
#
# _C111: - 43 x(4,9) - y4 + y9 >= -35
#
# _C112: - 43 x(4,10) + y10 - y4 >= -35
#
# _C113: - 42 x(4,11) + y11 - y4 >= -35
#
# _C114: - 49 x(4,12) + y12 - y4 >= -35
#
# _C115: - 41 x(4,13) + y13 - y4 >= -35
#
# _C116: - 54 x(4,14) + y14 - y4 >= -35
#
# _C117: - 46 x(4,15) + y15 - y4 >= -35
#
# _C118: - 35 x(4,16) + y16 - y4 >= -35
#
# _C119: - 35 x(5,0) + y0 - y5 >= -35
#
# _C120: - 54 x(5,1) + y1 - y5 >= -35
#
# _C121: - 65 x(5,2) + y2 - y5 >= -35
#
# _C122: - 51 x(5,3) + y3 - y5 >= -35
#
# _C123: - 58 x(5,4) + y4 - y5 >= -35
#
# _C124: - 46 x(5,5) + 0 y5 >= -35
#
# _C125: - 66 x(5,6) - y5 + y6 >= -35
#
# _C126: - 50 x(5,7) - y5 + y7 >= -35
#
# _C127: - 63 x(5,8) - y5 + y8 >= -35
#
# _C128: - 43 x(5,9) - y5 + y9 >= -35
#
# _C129: - 43 x(5,10) + y10 - y5 >= -35
#
# _C130: - 42 x(5,11) + y11 - y5 >= -35
#
# _C131: - 49 x(5,12) + y12 - y5 >= -35
#
# _C132: - 41 x(5,13) + y13 - y5 >= -35
#
# _C133: - 54 x(5,14) + y14 - y5 >= -35
#
# _C134: - 46 x(5,15) + y15 - y5 >= -35
#
# _C135: - 35 x(5,16) + y16 - y5 >= -35
#
# _C136: - 35 x(6,0) + y0 - y6 >= -35
#
# _C137: - 54 x(6,1) + y1 - y6 >= -35
#
# _C138: - 65 x(6,2) + y2 - y6 >= -35
#
# _C139: - 51 x(6,3) + y3 - y6 >= -35
#
# _C140: - 58 x(6,4) + y4 - y6 >= -35
#
# _C141: - 46 x(6,5) + y5 - y6 >= -35
#
# _C142: - 66 x(6,6) + 0 y6 >= -35
#
# _C143: - 50 x(6,7) - y6 + y7 >= -35
#
# _C144: - 63 x(6,8) - y6 + y8 >= -35
#
# _C145: - 43 x(6,9) - y6 + y9 >= -35
#
# _C146: - 43 x(6,10) + y10 - y6 >= -35
#
# _C147: - 42 x(6,11) + y11 - y6 >= -35
#
# _C148: - 49 x(6,12) + y12 - y6 >= -35
#
# _C149: - 41 x(6,13) + y13 - y6 >= -35
#
# _C150: - 54 x(6,14) + y14 - y6 >= -35
#
# _C151: - 46 x(6,15) + y15 - y6 >= -35
#
# _C152: - 35 x(6,16) + y16 - y6 >= -35
#
# _C153: - 35 x(7,0) + y0 - y7 >= -35
#
# _C154: - 54 x(7,1) + y1 - y7 >= -35
#
# _C155: - 65 x(7,2) + y2 - y7 >= -35
#
# _C156: - 51 x(7,3) + y3 - y7 >= -35
#
# _C157: - 58 x(7,4) + y4 - y7 >= -35
#
# _C158: - 46 x(7,5) + y5 - y7 >= -35
#
# _C159: - 66 x(7,6) + y6 - y7 >= -35
#
# _C160: - 50 x(7,7) + 0 y7 >= -35
#
# _C161: - 63 x(7,8) - y7 + y8 >= -35
#
# _C162: - 43 x(7,9) - y7 + y9 >= -35
#
# _C163: - 43 x(7,10) + y10 - y7 >= -35
#
# _C164: - 42 x(7,11) + y11 - y7 >= -35
#
# _C165: - 49 x(7,12) + y12 - y7 >= -35
#
# _C166: - 41 x(7,13) + y13 - y7 >= -35
#
# _C167: - 54 x(7,14) + y14 - y7 >= -35
#
# _C168: - 46 x(7,15) + y15 - y7 >= -35
#
# _C169: - 35 x(7,16) + y16 - y7 >= -35
#
# _C170: - 35 x(8,0) + y0 - y8 >= -35
#
# _C171: - 54 x(8,1) + y1 - y8 >= -35
#
# _C172: - 65 x(8,2) + y2 - y8 >= -35
#
# _C173: - 51 x(8,3) + y3 - y8 >= -35
#
# _C174: - 58 x(8,4) + y4 - y8 >= -35
#
# _C175: - 46 x(8,5) + y5 - y8 >= -35
#
# _C176: - 66 x(8,6) + y6 - y8 >= -35
#
# _C177: - 50 x(8,7) + y7 - y8 >= -35
#
# _C178: - 63 x(8,8) + 0 y8 >= -35
#
# _C179: - 43 x(8,9) - y8 + y9 >= -35
#
# _C180: - 43 x(8,10) + y10 - y8 >= -35
#
# _C181: - 42 x(8,11) + y11 - y8 >= -35
#
# _C182: - 49 x(8,12) + y12 - y8 >= -35
#
# _C183: - 41 x(8,13) + y13 - y8 >= -35
#
# _C184: - 54 x(8,14) + y14 - y8 >= -35
#
# _C185: - 46 x(8,15) + y15 - y8 >= -35
#
# _C186: - 35 x(8,16) + y16 - y8 >= -35
#
# _C187: - 35 x(9,0) + y0 - y9 >= -35
#
# _C188: - 54 x(9,1) + y1 - y9 >= -35
#
# _C189: - 65 x(9,2) + y2 - y9 >= -35
#
# _C190: - 51 x(9,3) + y3 - y9 >= -35
#
# _C191: - 58 x(9,4) + y4 - y9 >= -35
#
# _C192: - 46 x(9,5) + y5 - y9 >= -35
#
# _C193: - 66 x(9,6) + y6 - y9 >= -35
#
# _C194: - 50 x(9,7) + y7 - y9 >= -35
#
# _C195: - 63 x(9,8) + y8 - y9 >= -35
#
# _C196: - 43 x(9,9) + 0 y9 >= -35
#
# _C197: - 43 x(9,10) + y10 - y9 >= -35
#
# _C198: - 42 x(9,11) + y11 - y9 >= -35
#
# _C199: - 49 x(9,12) + y12 - y9 >= -35
#
# _C200: - 41 x(9,13) + y13 - y9 >= -35
#
# _C201: - 54 x(9,14) + y14 - y9 >= -35
#
# _C202: - 46 x(9,15) + y15 - y9 >= -35
#
# _C203: - 35 x(9,16) + y16 - y9 >= -35
#
# _C204: - 35 x(10,0) + y0 - y10 >= -35
#
# _C205: - 54 x(10,1) + y1 - y10 >= -35
#
# _C206: - 65 x(10,2) - y10 + y2 >= -35
#
# _C207: - 51 x(10,3) - y10 + y3 >= -35
#
# _C208: - 58 x(10,4) - y10 + y4 >= -35
#
# _C209: - 46 x(10,5) - y10 + y5 >= -35
#
# _C210: - 66 x(10,6) - y10 + y6 >= -35
#
# _C211: - 50 x(10,7) - y10 + y7 >= -35
#
# _C212: - 63 x(10,8) - y10 + y8 >= -35
#
# _C213: - 43 x(10,9) - y10 + y9 >= -35
#
# _C214: - 43 x(10,10) + 0 y10 >= -35
#
# _C215: - 42 x(10,11) - y10 + y11 >= -35
#
# _C216: - 49 x(10,12) - y10 + y12 >= -35
#
# _C217: - 41 x(10,13) - y10 + y13 >= -35
#
# _C218: - 54 x(10,14) - y10 + y14 >= -35
#
# _C219: - 46 x(10,15) - y10 + y15 >= -35
#
# _C220: - 35 x(10,16) - y10 + y16 >= -35
#
# _C221: - 35 x(11,0) + y0 - y11 >= -35
#
# _C222: - 54 x(11,1) + y1 - y11 >= -35
#
# _C223: - 65 x(11,2) - y11 + y2 >= -35
#
# _C224: - 51 x(11,3) - y11 + y3 >= -35
#
# _C225: - 58 x(11,4) - y11 + y4 >= -35
#
# _C226: - 46 x(11,5) - y11 + y5 >= -35
#
# _C227: - 66 x(11,6) - y11 + y6 >= -35
#
# _C228: - 50 x(11,7) - y11 + y7 >= -35
#
# _C229: - 63 x(11,8) - y11 + y8 >= -35
#
# _C230: - 43 x(11,9) - y11 + y9 >= -35
#
# _C231: - 43 x(11,10) + y10 - y11 >= -35
#
# _C232: - 42 x(11,11) + 0 y11 >= -35
#
# _C233: - 49 x(11,12) - y11 + y12 >= -35
#
# _C234: - 41 x(11,13) - y11 + y13 >= -35
#
# _C235: - 54 x(11,14) - y11 + y14 >= -35
#
# _C236: - 46 x(11,15) - y11 + y15 >= -35
#
# _C237: - 35 x(11,16) - y11 + y16 >= -35
#
# _C238: - 35 x(12,0) + y0 - y12 >= -35
#
# _C239: - 54 x(12,1) + y1 - y12 >= -35
#
# _C240: - 65 x(12,2) - y12 + y2 >= -35
#
# _C241: - 51 x(12,3) - y12 + y3 >= -35
#
# _C242: - 58 x(12,4) - y12 + y4 >= -35
#
# _C243: - 46 x(12,5) - y12 + y5 >= -35
#
# _C244: - 66 x(12,6) - y12 + y6 >= -35
#
# _C245: - 50 x(12,7) - y12 + y7 >= -35
#
# _C246: - 63 x(12,8) - y12 + y8 >= -35
#
# _C247: - 43 x(12,9) - y12 + y9 >= -35
#
# _C248: - 43 x(12,10) + y10 - y12 >= -35
#
# _C249: - 42 x(12,11) + y11 - y12 >= -35
#
# _C250: - 49 x(12,12) + 0 y12 >= -35
#
# _C251: - 41 x(12,13) - y12 + y13 >= -35
#
# _C252: - 54 x(12,14) - y12 + y14 >= -35
#
# _C253: - 46 x(12,15) - y12 + y15 >= -35
#
# _C254: - 35 x(12,16) - y12 + y16 >= -35
#
# _C255: - 35 x(13,0) + y0 - y13 >= -35
#
# _C256: - 54 x(13,1) + y1 - y13 >= -35
#
# _C257: - 65 x(13,2) - y13 + y2 >= -35
#
# _C258: - 51 x(13,3) - y13 + y3 >= -35
#
# _C259: - 58 x(13,4) - y13 + y4 >= -35
#
# _C260: - 46 x(13,5) - y13 + y5 >= -35
#
# _C261: - 66 x(13,6) - y13 + y6 >= -35
#
# _C262: - 50 x(13,7) - y13 + y7 >= -35
#
# _C263: - 63 x(13,8) - y13 + y8 >= -35
#
# _C264: - 43 x(13,9) - y13 + y9 >= -35
#
# _C265: - 43 x(13,10) + y10 - y13 >= -35
#
# _C266: - 42 x(13,11) + y11 - y13 >= -35
#
# _C267: - 49 x(13,12) + y12 - y13 >= -35
#
# _C268: - 41 x(13,13) + 0 y13 >= -35
#
# _C269: - 54 x(13,14) - y13 + y14 >= -35
#
# _C270: - 46 x(13,15) - y13 + y15 >= -35
#
# _C271: - 35 x(13,16) - y13 + y16 >= -35
#
# _C272: - 35 x(14,0) + y0 - y14 >= -35
#
# _C273: - 54 x(14,1) + y1 - y14 >= -35
#
# _C274: - 65 x(14,2) - y14 + y2 >= -35
#
# _C275: - 51 x(14,3) - y14 + y3 >= -35
#
# _C276: - 58 x(14,4) - y14 + y4 >= -35
#
# _C277: - 46 x(14,5) - y14 + y5 >= -35
#
# _C278: - 66 x(14,6) - y14 + y6 >= -35
#
# _C279: - 50 x(14,7) - y14 + y7 >= -35
#
# _C280: - 63 x(14,8) - y14 + y8 >= -35
#
# _C281: - 43 x(14,9) - y14 + y9 >= -35
#
# _C282: - 43 x(14,10) + y10 - y14 >= -35
#
# _C283: - 42 x(14,11) + y11 - y14 >= -35
#
# _C284: - 49 x(14,12) + y12 - y14 >= -35
#
# _C285: - 41 x(14,13) + y13 - y14 >= -35
#
# _C286: - 54 x(14,14) + 0 y14 >= -35
#
# _C287: - 46 x(14,15) - y14 + y15 >= -35
#
# _C288: - 35 x(14,16) - y14 + y16 >= -35
#
# _C289: - 35 x(15,0) + y0 - y15 >= -35
#
# _C290: - 54 x(15,1) + y1 - y15 >= -35
#
# _C291: - 65 x(15,2) - y15 + y2 >= -35
#
# _C292: - 51 x(15,3) - y15 + y3 >= -35
#
# _C293: - 58 x(15,4) - y15 + y4 >= -35
#
# _C294: - 46 x(15,5) - y15 + y5 >= -35
#
# _C295: - 66 x(15,6) - y15 + y6 >= -35
#
# _C296: - 50 x(15,7) - y15 + y7 >= -35
#
# _C297: - 63 x(15,8) - y15 + y8 >= -35
#
# _C298: - 43 x(15,9) - y15 + y9 >= -35
#
# _C299: - 43 x(15,10) + y10 - y15 >= -35
#
# _C300: - 42 x(15,11) + y11 - y15 >= -35
#
# _C301: - 49 x(15,12) + y12 - y15 >= -35
#
# _C302: - 41 x(15,13) + y13 - y15 >= -35
#
# _C303: - 54 x(15,14) + y14 - y15 >= -35
#
# _C304: - 46 x(15,15) + 0 y15 >= -35
#
# _C305: - 35 x(15,16) - y15 + y16 >= -35
#
# _C306: - 35 x(16,0) + y0 - y16 >= -35
#
# _C307: - 54 x(16,1) + y1 - y16 >= -35
#
# _C308: - 65 x(16,2) - y16 + y2 >= -35
#
# _C309: - 51 x(16,3) - y16 + y3 >= -35
#
# _C310: - 58 x(16,4) - y16 + y4 >= -35
#
# _C311: - 46 x(16,5) - y16 + y5 >= -35
#
# _C312: - 66 x(16,6) - y16 + y6 >= -35
#
# _C313: - 50 x(16,7) - y16 + y7 >= -35
#
# _C314: - 63 x(16,8) - y16 + y8 >= -35
#
# _C315: - 43 x(16,9) - y16 + y9 >= -35
#
# _C316: - 43 x(16,10) + y10 - y16 >= -35
#
# _C317: - 42 x(16,11) + y11 - y16 >= -35
#
# _C318: - 49 x(16,12) + y12 - y16 >= -35
#
# _C319: - 41 x(16,13) + y13 - y16 >= -35
#
# _C320: - 54 x(16,14) + y14 - y16 >= -35
#
# _C321: - 46 x(16,15) + y15 - y16 >= -35
#
# _C322: - 35 x(16,16) + 0 y16 >= -35
#
# _C323: x(0,1) - x(1,10) - x(1,11) - x(1,12) - x(1,13) - x(1,14) - x(1,15)
#  - x(1,16) - x(1,2) - x(1,3) - x(1,4) - x(1,5) - x(1,6) - x(1,7) - x(1,8)
#  - x(1,9) + x(10,1) + x(11,1) + x(12,1) + x(13,1) + x(14,1) + x(15,1) + x(2,1)
#  + x(3,1) + x(4,1) + x(5,1) + x(6,1) + x(7,1) + x(8,1) + x(9,1) = 0
#
# _C324: x(0,2) + x(1,2) + x(10,2) + x(11,2) + x(12,2) + x(13,2) + x(14,2)
#  + x(15,2) - x(2,1) - x(2,10) - x(2,11) - x(2,12) - x(2,13) - x(2,14)
#  - x(2,15) - x(2,16) - x(2,3) - x(2,4) - x(2,5) - x(2,6) - x(2,7) - x(2,8)
#  - x(2,9) + x(3,2) + x(4,2) + x(5,2) + x(6,2) + x(7,2) + x(8,2) + x(9,2) = 0
#
# _C325: x(0,3) + x(1,3) + x(10,3) + x(11,3) + x(12,3) + x(13,3) + x(14,3)
#  + x(15,3) + x(2,3) - x(3,1) - x(3,10) - x(3,11) - x(3,12) - x(3,13) - x(3,14)
#  - x(3,15) - x(3,16) - x(3,2) - x(3,4) - x(3,5) - x(3,6) - x(3,7) - x(3,8)
#  - x(3,9) + x(4,3) + x(5,3) + x(6,3) + x(7,3) + x(8,3) + x(9,3) = 0
#
# _C326: x(0,4) + x(1,4) + x(10,4) + x(11,4) + x(12,4) + x(13,4) + x(14,4)
#  + x(15,4) + x(2,4) + x(3,4) - x(4,1) - x(4,10) - x(4,11) - x(4,12) - x(4,13)
#  - x(4,14) - x(4,15) - x(4,16) - x(4,2) - x(4,3) - x(4,5) - x(4,6) - x(4,7)
#  - x(4,8) - x(4,9) + x(5,4) + x(6,4) + x(7,4) + x(8,4) + x(9,4) = 0
#
# _C327: x(0,5) + x(1,5) + x(10,5) + x(11,5) + x(12,5) + x(13,5) + x(14,5)
#  + x(15,5) + x(2,5) + x(3,5) + x(4,5) - x(5,1) - x(5,10) - x(5,11) - x(5,12)
#  - x(5,13) - x(5,14) - x(5,15) - x(5,16) - x(5,2) - x(5,3) - x(5,4) - x(5,6)
#  - x(5,7) - x(5,8) - x(5,9) + x(6,5) + x(7,5) + x(8,5) + x(9,5) = 0
#
# _C328: x(0,6) + x(1,6) + x(10,6) + x(11,6) + x(12,6) + x(13,6) + x(14,6)
#  + x(15,6) + x(2,6) + x(3,6) + x(4,6) + x(5,6) - x(6,1) - x(6,10) - x(6,11)
#  - x(6,12) - x(6,13) - x(6,14) - x(6,15) - x(6,16) - x(6,2) - x(6,3) - x(6,4)
#  - x(6,5) - x(6,7) - x(6,8) - x(6,9) + x(7,6) + x(8,6) + x(9,6) = 0
#
# _C329: x(0,7) + x(1,7) + x(10,7) + x(11,7) + x(12,7) + x(13,7) + x(14,7)
#  + x(15,7) + x(2,7) + x(3,7) + x(4,7) + x(5,7) + x(6,7) - x(7,1) - x(7,10)
#  - x(7,11) - x(7,12) - x(7,13) - x(7,14) - x(7,15) - x(7,16) - x(7,2) - x(7,3)
#  - x(7,4) - x(7,5) - x(7,6) - x(7,8) - x(7,9) + x(8,7) + x(9,7) = 0
#
# _C330: x(0,8) + x(1,8) + x(10,8) + x(11,8) + x(12,8) + x(13,8) + x(14,8)
#  + x(15,8) + x(2,8) + x(3,8) + x(4,8) + x(5,8) + x(6,8) + x(7,8) - x(8,1)
#  - x(8,10) - x(8,11) - x(8,12) - x(8,13) - x(8,14) - x(8,15) - x(8,16)
#  - x(8,2) - x(8,3) - x(8,4) - x(8,5) - x(8,6) - x(8,7) - x(8,9) + x(9,8) = 0
#
# _C331: x(0,9) + x(1,9) + x(10,9) + x(11,9) + x(12,9) + x(13,9) + x(14,9)
#  + x(15,9) + x(2,9) + x(3,9) + x(4,9) + x(5,9) + x(6,9) + x(7,9) + x(8,9)
#  - x(9,1) - x(9,10) - x(9,11) - x(9,12) - x(9,13) - x(9,14) - x(9,15)
#  - x(9,16) - x(9,2) - x(9,3) - x(9,4) - x(9,5) - x(9,6) - x(9,7) - x(9,8) = 0
#
# _C332: x(0,10) + x(1,10) - x(10,1) - x(10,11) - x(10,12) - x(10,13) - x(10,14)
#  - x(10,15) - x(10,16) - x(10,2) - x(10,3) - x(10,4) - x(10,5) - x(10,6)
#  - x(10,7) - x(10,8) - x(10,9) + x(11,10) + x(12,10) + x(13,10) + x(14,10)
#  + x(15,10) + x(2,10) + x(3,10) + x(4,10) + x(5,10) + x(6,10) + x(7,10)
#  + x(8,10) + x(9,10) = 0
#
# _C333: x(0,11) + x(1,11) + x(10,11) - x(11,1) - x(11,10) - x(11,12) - x(11,13)
#  - x(11,14) - x(11,15) - x(11,16) - x(11,2) - x(11,3) - x(11,4) - x(11,5)
#  - x(11,6) - x(11,7) - x(11,8) - x(11,9) + x(12,11) + x(13,11) + x(14,11)
#  + x(15,11) + x(2,11) + x(3,11) + x(4,11) + x(5,11) + x(6,11) + x(7,11)
#  + x(8,11) + x(9,11) = 0
#
# _C334: x(0,12) + x(1,12) + x(10,12) + x(11,12) - x(12,1) - x(12,10) - x(12,11)
#  - x(12,13) - x(12,14) - x(12,15) - x(12,16) - x(12,2) - x(12,3) - x(12,4)
#  - x(12,5) - x(12,6) - x(12,7) - x(12,8) - x(12,9) + x(13,12) + x(14,12)
#  + x(15,12) + x(2,12) + x(3,12) + x(4,12) + x(5,12) + x(6,12) + x(7,12)
#  + x(8,12) + x(9,12) = 0
#
# _C335: x(0,13) + x(1,13) + x(10,13) + x(11,13) + x(12,13) - x(13,1) - x(13,10)
#  - x(13,11) - x(13,12) - x(13,14) - x(13,15) - x(13,16) - x(13,2) - x(13,3)
#  - x(13,4) - x(13,5) - x(13,6) - x(13,7) - x(13,8) - x(13,9) + x(14,13)
#  + x(15,13) + x(2,13) + x(3,13) + x(4,13) + x(5,13) + x(6,13) + x(7,13)
#  + x(8,13) + x(9,13) = 0
#
# _C336: x(0,14) + x(1,14) + x(10,14) + x(11,14) + x(12,14) + x(13,14) - x(14,1)
#  - x(14,10) - x(14,11) - x(14,12) - x(14,13) - x(14,15) - x(14,16) - x(14,2)
#  - x(14,3) - x(14,4) - x(14,5) - x(14,6) - x(14,7) - x(14,8) - x(14,9)
#  + x(15,14) + x(2,14) + x(3,14) + x(4,14) + x(5,14) + x(6,14) + x(7,14)
#  + x(8,14) + x(9,14) = 0
#
# _C337: x(0,15) + x(1,15) + x(10,15) + x(11,15) + x(12,15) + x(13,15)
#  + x(14,15) - x(15,1) - x(15,10) - x(15,11) - x(15,12) - x(15,13) - x(15,14)
#  - x(15,16) - x(15,2) - x(15,3) - x(15,4) - x(15,5) - x(15,6) - x(15,7)
#  - x(15,8) - x(15,9) + x(2,15) + x(3,15) + x(4,15) + x(5,15) + x(6,15)
#  + x(7,15) + x(8,15) + x(9,15) = 0
#
# VARIABLES
# 0 <= x(0,0) <= 1 Integer
# 0 <= x(0,1) <= 1 Integer
# 0 <= x(0,10) <= 1 Integer
# 0 <= x(0,11) <= 1 Integer
# 0 <= x(0,12) <= 1 Integer
# 0 <= x(0,13) <= 1 Integer
# 0 <= x(0,14) <= 1 Integer
# 0 <= x(0,15) <= 1 Integer
# 0 <= x(0,16) <= 1 Integer
# 0 <= x(0,2) <= 1 Integer
# 0 <= x(0,3) <= 1 Integer
# 0 <= x(0,4) <= 1 Integer
# 0 <= x(0,5) <= 1 Integer
# 0 <= x(0,6) <= 1 Integer
# 0 <= x(0,7) <= 1 Integer
# 0 <= x(0,8) <= 1 Integer
# 0 <= x(0,9) <= 1 Integer
# 0 <= x(1,0) <= 1 Integer
# 0 <= x(1,1) <= 1 Integer
# 0 <= x(1,10) <= 1 Integer
# 0 <= x(1,11) <= 1 Integer
# 0 <= x(1,12) <= 1 Integer
# 0 <= x(1,13) <= 1 Integer
# 0 <= x(1,14) <= 1 Integer
# 0 <= x(1,15) <= 1 Integer
# 0 <= x(1,16) <= 1 Integer
# 0 <= x(1,2) <= 1 Integer
# 0 <= x(1,3) <= 1 Integer
# 0 <= x(1,4) <= 1 Integer
# 0 <= x(1,5) <= 1 Integer
# 0 <= x(1,6) <= 1 Integer
# 0 <= x(1,7) <= 1 Integer
# 0 <= x(1,8) <= 1 Integer
# 0 <= x(1,9) <= 1 Integer
# 0 <= x(10,0) <= 1 Integer
# 0 <= x(10,1) <= 1 Integer
# 0 <= x(10,10) <= 1 Integer
# 0 <= x(10,11) <= 1 Integer
# 0 <= x(10,12) <= 1 Integer
# 0 <= x(10,13) <= 1 Integer
# 0 <= x(10,14) <= 1 Integer
# 0 <= x(10,15) <= 1 Integer
# 0 <= x(10,16) <= 1 Integer
# 0 <= x(10,2) <= 1 Integer
# 0 <= x(10,3) <= 1 Integer
# 0 <= x(10,4) <= 1 Integer
# 0 <= x(10,5) <= 1 Integer
# 0 <= x(10,6) <= 1 Integer
# 0 <= x(10,7) <= 1 Integer
# 0 <= x(10,8) <= 1 Integer
# 0 <= x(10,9) <= 1 Integer
# 0 <= x(11,0) <= 1 Integer
# 0 <= x(11,1) <= 1 Integer
# 0 <= x(11,10) <= 1 Integer
# 0 <= x(11,11) <= 1 Integer
# 0 <= x(11,12) <= 1 Integer
# 0 <= x(11,13) <= 1 Integer
# 0 <= x(11,14) <= 1 Integer
# 0 <= x(11,15) <= 1 Integer
# 0 <= x(11,16) <= 1 Integer
# 0 <= x(11,2) <= 1 Integer
# 0 <= x(11,3) <= 1 Integer
# 0 <= x(11,4) <= 1 Integer
# 0 <= x(11,5) <= 1 Integer
# 0 <= x(11,6) <= 1 Integer
# 0 <= x(11,7) <= 1 Integer
# 0 <= x(11,8) <= 1 Integer
# 0 <= x(11,9) <= 1 Integer
# 0 <= x(12,0) <= 1 Integer
# 0 <= x(12,1) <= 1 Integer
# 0 <= x(12,10) <= 1 Integer
# 0 <= x(12,11) <= 1 Integer
# 0 <= x(12,12) <= 1 Integer
# 0 <= x(12,13) <= 1 Integer
# 0 <= x(12,14) <= 1 Integer
# 0 <= x(12,15) <= 1 Integer
# 0 <= x(12,16) <= 1 Integer
# 0 <= x(12,2) <= 1 Integer
# 0 <= x(12,3) <= 1 Integer
# 0 <= x(12,4) <= 1 Integer
# 0 <= x(12,5) <= 1 Integer
# 0 <= x(12,6) <= 1 Integer
# 0 <= x(12,7) <= 1 Integer
# 0 <= x(12,8) <= 1 Integer
# 0 <= x(12,9) <= 1 Integer
# 0 <= x(13,0) <= 1 Integer
# 0 <= x(13,1) <= 1 Integer
# 0 <= x(13,10) <= 1 Integer
# 0 <= x(13,11) <= 1 Integer
# 0 <= x(13,12) <= 1 Integer
# 0 <= x(13,13) <= 1 Integer
# 0 <= x(13,14) <= 1 Integer
# 0 <= x(13,15) <= 1 Integer
# 0 <= x(13,16) <= 1 Integer
# 0 <= x(13,2) <= 1 Integer
# 0 <= x(13,3) <= 1 Integer
# 0 <= x(13,4) <= 1 Integer
# 0 <= x(13,5) <= 1 Integer
# 0 <= x(13,6) <= 1 Integer
# 0 <= x(13,7) <= 1 Integer
# 0 <= x(13,8) <= 1 Integer
# 0 <= x(13,9) <= 1 Integer
# 0 <= x(14,0) <= 1 Integer
# 0 <= x(14,1) <= 1 Integer
# 0 <= x(14,10) <= 1 Integer
# 0 <= x(14,11) <= 1 Integer
# 0 <= x(14,12) <= 1 Integer
# 0 <= x(14,13) <= 1 Integer
# 0 <= x(14,14) <= 1 Integer
# 0 <= x(14,15) <= 1 Integer
# 0 <= x(14,16) <= 1 Integer
# 0 <= x(14,2) <= 1 Integer
# 0 <= x(14,3) <= 1 Integer
# 0 <= x(14,4) <= 1 Integer
# 0 <= x(14,5) <= 1 Integer
# 0 <= x(14,6) <= 1 Integer
# 0 <= x(14,7) <= 1 Integer
# 0 <= x(14,8) <= 1 Integer
# 0 <= x(14,9) <= 1 Integer
# 0 <= x(15,0) <= 1 Integer
# 0 <= x(15,1) <= 1 Integer
# 0 <= x(15,10) <= 1 Integer
# 0 <= x(15,11) <= 1 Integer
# 0 <= x(15,12) <= 1 Integer
# 0 <= x(15,13) <= 1 Integer
# 0 <= x(15,14) <= 1 Integer
# 0 <= x(15,15) <= 1 Integer
# 0 <= x(15,16) <= 1 Integer
# 0 <= x(15,2) <= 1 Integer
# 0 <= x(15,3) <= 1 Integer
# 0 <= x(15,4) <= 1 Integer
# 0 <= x(15,5) <= 1 Integer
# 0 <= x(15,6) <= 1 Integer
# 0 <= x(15,7) <= 1 Integer
# 0 <= x(15,8) <= 1 Integer
# 0 <= x(15,9) <= 1 Integer
# 0 <= x(16,0) <= 1 Integer
# 0 <= x(16,1) <= 1 Integer
# 0 <= x(16,10) <= 1 Integer
# 0 <= x(16,11) <= 1 Integer
# 0 <= x(16,12) <= 1 Integer
# 0 <= x(16,13) <= 1 Integer
# 0 <= x(16,14) <= 1 Integer
# 0 <= x(16,15) <= 1 Integer
# 0 <= x(16,16) <= 1 Integer
# 0 <= x(16,2) <= 1 Integer
# 0 <= x(16,3) <= 1 Integer
# 0 <= x(16,4) <= 1 Integer
# 0 <= x(16,5) <= 1 Integer
# 0 <= x(16,6) <= 1 Integer
# 0 <= x(16,7) <= 1 Integer
# 0 <= x(16,8) <= 1 Integer
# 0 <= x(16,9) <= 1 Integer
# 0 <= x(2,0) <= 1 Integer
# 0 <= x(2,1) <= 1 Integer
# 0 <= x(2,10) <= 1 Integer
# 0 <= x(2,11) <= 1 Integer
# 0 <= x(2,12) <= 1 Integer
# 0 <= x(2,13) <= 1 Integer
# 0 <= x(2,14) <= 1 Integer
# 0 <= x(2,15) <= 1 Integer
# 0 <= x(2,16) <= 1 Integer
# 0 <= x(2,2) <= 1 Integer
# 0 <= x(2,3) <= 1 Integer
# 0 <= x(2,4) <= 1 Integer
# 0 <= x(2,5) <= 1 Integer
# 0 <= x(2,6) <= 1 Integer
# 0 <= x(2,7) <= 1 Integer
# 0 <= x(2,8) <= 1 Integer
# 0 <= x(2,9) <= 1 Integer
# 0 <= x(3,0) <= 1 Integer
# 0 <= x(3,1) <= 1 Integer
# 0 <= x(3,10) <= 1 Integer
# 0 <= x(3,11) <= 1 Integer
# 0 <= x(3,12) <= 1 Integer
# 0 <= x(3,13) <= 1 Integer
# 0 <= x(3,14) <= 1 Integer
# 0 <= x(3,15) <= 1 Integer
# 0 <= x(3,16) <= 1 Integer
# 0 <= x(3,2) <= 1 Integer
# 0 <= x(3,3) <= 1 Integer
# 0 <= x(3,4) <= 1 Integer
# 0 <= x(3,5) <= 1 Integer
# 0 <= x(3,6) <= 1 Integer
# 0 <= x(3,7) <= 1 Integer
# 0 <= x(3,8) <= 1 Integer
# 0 <= x(3,9) <= 1 Integer
# 0 <= x(4,0) <= 1 Integer
# 0 <= x(4,1) <= 1 Integer
# 0 <= x(4,10) <= 1 Integer
# 0 <= x(4,11) <= 1 Integer
# 0 <= x(4,12) <= 1 Integer
# 0 <= x(4,13) <= 1 Integer
# 0 <= x(4,14) <= 1 Integer
# 0 <= x(4,15) <= 1 Integer
# 0 <= x(4,16) <= 1 Integer
# 0 <= x(4,2) <= 1 Integer
# 0 <= x(4,3) <= 1 Integer
# 0 <= x(4,4) <= 1 Integer
# 0 <= x(4,5) <= 1 Integer
# 0 <= x(4,6) <= 1 Integer
# 0 <= x(4,7) <= 1 Integer
# 0 <= x(4,8) <= 1 Integer
# 0 <= x(4,9) <= 1 Integer
# 0 <= x(5,0) <= 1 Integer
# 0 <= x(5,1) <= 1 Integer
# 0 <= x(5,10) <= 1 Integer
# 0 <= x(5,11) <= 1 Integer
# 0 <= x(5,12) <= 1 Integer
# 0 <= x(5,13) <= 1 Integer
# 0 <= x(5,14) <= 1 Integer
# 0 <= x(5,15) <= 1 Integer
# 0 <= x(5,16) <= 1 Integer
# 0 <= x(5,2) <= 1 Integer
# 0 <= x(5,3) <= 1 Integer
# 0 <= x(5,4) <= 1 Integer
# 0 <= x(5,5) <= 1 Integer
# 0 <= x(5,6) <= 1 Integer
# 0 <= x(5,7) <= 1 Integer
# 0 <= x(5,8) <= 1 Integer
# 0 <= x(5,9) <= 1 Integer
# 0 <= x(6,0) <= 1 Integer
# 0 <= x(6,1) <= 1 Integer
# 0 <= x(6,10) <= 1 Integer
# 0 <= x(6,11) <= 1 Integer
# 0 <= x(6,12) <= 1 Integer
# 0 <= x(6,13) <= 1 Integer
# 0 <= x(6,14) <= 1 Integer
# 0 <= x(6,15) <= 1 Integer
# 0 <= x(6,16) <= 1 Integer
# 0 <= x(6,2) <= 1 Integer
# 0 <= x(6,3) <= 1 Integer
# 0 <= x(6,4) <= 1 Integer
# 0 <= x(6,5) <= 1 Integer
# 0 <= x(6,6) <= 1 Integer
# 0 <= x(6,7) <= 1 Integer
# 0 <= x(6,8) <= 1 Integer
# 0 <= x(6,9) <= 1 Integer
# 0 <= x(7,0) <= 1 Integer
# 0 <= x(7,1) <= 1 Integer
# 0 <= x(7,10) <= 1 Integer
# 0 <= x(7,11) <= 1 Integer
# 0 <= x(7,12) <= 1 Integer
# 0 <= x(7,13) <= 1 Integer
# 0 <= x(7,14) <= 1 Integer
# 0 <= x(7,15) <= 1 Integer
# 0 <= x(7,16) <= 1 Integer
# 0 <= x(7,2) <= 1 Integer
# 0 <= x(7,3) <= 1 Integer
# 0 <= x(7,4) <= 1 Integer
# 0 <= x(7,5) <= 1 Integer
# 0 <= x(7,6) <= 1 Integer
# 0 <= x(7,7) <= 1 Integer
# 0 <= x(7,8) <= 1 Integer
# 0 <= x(7,9) <= 1 Integer
# 0 <= x(8,0) <= 1 Integer
# 0 <= x(8,1) <= 1 Integer
# 0 <= x(8,10) <= 1 Integer
# 0 <= x(8,11) <= 1 Integer
# 0 <= x(8,12) <= 1 Integer
# 0 <= x(8,13) <= 1 Integer
# 0 <= x(8,14) <= 1 Integer
# 0 <= x(8,15) <= 1 Integer
# 0 <= x(8,16) <= 1 Integer
# 0 <= x(8,2) <= 1 Integer
# 0 <= x(8,3) <= 1 Integer
# 0 <= x(8,4) <= 1 Integer
# 0 <= x(8,5) <= 1 Integer
# 0 <= x(8,6) <= 1 Integer
# 0 <= x(8,7) <= 1 Integer
# 0 <= x(8,8) <= 1 Integer
# 0 <= x(8,9) <= 1 Integer
# 0 <= x(9,0) <= 1 Integer
# 0 <= x(9,1) <= 1 Integer
# 0 <= x(9,10) <= 1 Integer
# 0 <= x(9,11) <= 1 Integer
# 0 <= x(9,12) <= 1 Integer
# 0 <= x(9,13) <= 1 Integer
# 0 <= x(9,14) <= 1 Integer
# 0 <= x(9,15) <= 1 Integer
# 0 <= x(9,16) <= 1 Integer
# 0 <= x(9,2) <= 1 Integer
# 0 <= x(9,3) <= 1 Integer
# 0 <= x(9,4) <= 1 Integer
# 0 <= x(9,5) <= 1 Integer
# 0 <= x(9,6) <= 1 Integer
# 0 <= x(9,7) <= 1 Integer
# 0 <= x(9,8) <= 1 Integer
# 0 <= x(9,9) <= 1 Integer
# y0 Continuous
# y1 Continuous
# y10 Continuous
# y11 Continuous
# y12 Continuous
# y13 Continuous
# y14 Continuous
# y15 Continuous
# y16 Continuous
# y2 Continuous
# y3 Continuous
# y4 Continuous
# y5 Continuous
# y6 Continuous
# y7 Continuous
# y8 Continuous
# y9 Continuous

# %%
lp.solve()
# Out:
# Optimal

# %%
lp.getResult()
# Out:
# Objective value:  444.0
# x(0,0)  =  0.0
# x(0,1)  =  1.0
# x(0,10)  =  1.0
# x(0,11)  =  1.0
# x(0,12)  =  0.0
# x(0,13)  =  1.0
# x(0,14)  =  1.0
# x(0,15)  =  0.0
# x(0,16)  =  0.0
# x(0,2)  =  1.0
# x(0,3)  =  1.0
# x(0,4)  =  0.0
# x(0,5)  =  0.0
# x(0,6)  =  1.0
# x(0,7)  =  0.0
# x(0,8)  =  0.0
# x(0,9)  =  0.0
# x(1,0)  =  0.0
# x(1,1)  =  0.0
# x(1,10)  =  0.0
# x(1,11)  =  0.0
# x(1,12)  =  0.0
# x(1,13)  =  0.0
# x(1,14)  =  0.0
# x(1,15)  =  0.0
# x(1,16)  =  1.0
# x(1,2)  =  0.0
# x(1,3)  =  0.0
# x(1,4)  =  0.0
# x(1,5)  =  0.0
# x(1,6)  =  0.0
# x(1,7)  =  0.0
# x(1,8)  =  0.0
# x(1,9)  =  0.0
# x(10,0)  =  0.0
# x(10,1)  =  0.0
# x(10,10)  =  0.0
# x(10,11)  =  0.0
# x(10,12)  =  1.0
# x(10,13)  =  0.0
# x(10,14)  =  0.0
# x(10,15)  =  0.0
# x(10,16)  =  0.0
# x(10,2)  =  0.0
# x(10,3)  =  0.0
# x(10,4)  =  0.0
# x(10,5)  =  0.0
# x(10,6)  =  0.0
# x(10,7)  =  0.0
# x(10,8)  =  0.0
# x(10,9)  =  0.0
# x(11,0)  =  0.0
# x(11,1)  =  0.0
# x(11,10)  =  0.0
# x(11,11)  =  0.0
# x(11,12)  =  0.0
# x(11,13)  =  0.0
# x(11,14)  =  0.0
# x(11,15)  =  0.0
# x(11,16)  =  0.0
# x(11,2)  =  0.0
# x(11,3)  =  0.0
# x(11,4)  =  1.0
# x(11,5)  =  0.0
# x(11,6)  =  0.0
# x(11,7)  =  0.0
# x(11,8)  =  0.0
# x(11,9)  =  0.0
# x(12,0)  =  0.0
# x(12,1)  =  0.0
# x(12,10)  =  0.0
# x(12,11)  =  0.0
# x(12,12)  =  0.0
# x(12,13)  =  0.0
# x(12,14)  =  0.0
# x(12,15)  =  1.0
# x(12,16)  =  0.0
# x(12,2)  =  0.0
# x(12,3)  =  0.0
# x(12,4)  =  0.0
# x(12,5)  =  0.0
# x(12,6)  =  0.0
# x(12,7)  =  0.0
# x(12,8)  =  0.0
# x(12,9)  =  0.0
# x(13,0)  =  0.0
# x(13,1)  =  0.0
# x(13,10)  =  0.0
# x(13,11)  =  0.0
# x(13,12)  =  0.0
# x(13,13)  =  0.0
# x(13,14)  =  0.0
# x(13,15)  =  0.0
# x(13,16)  =  0.0
# x(13,2)  =  0.0
# x(13,3)  =  0.0
# x(13,4)  =  0.0
# x(13,5)  =  0.0
# x(13,6)  =  0.0
# x(13,7)  =  0.0
# x(13,8)  =  1.0
# x(13,9)  =  0.0
# x(14,0)  =  0.0
# x(14,1)  =  0.0
# x(14,10)  =  0.0
# x(14,11)  =  0.0
# x(14,12)  =  0.0
# x(14,13)  =  0.0
# x(14,14)  =  0.0
# x(14,15)  =  0.0
# x(14,16)  =  0.0
# x(14,2)  =  0.0
# x(14,3)  =  0.0
# x(14,4)  =  0.0
# x(14,5)  =  0.0
# x(14,6)  =  0.0
# x(14,7)  =  1.0
# x(14,8)  =  0.0
# x(14,9)  =  0.0
# x(15,0)  =  0.0
# x(15,1)  =  0.0
# x(15,10)  =  0.0
# x(15,11)  =  0.0
# x(15,12)  =  0.0
# x(15,13)  =  0.0
# x(15,14)  =  0.0
# x(15,15)  =  0.0
# x(15,16)  =  1.0
# x(15,2)  =  0.0
# x(15,3)  =  0.0
# x(15,4)  =  0.0
# x(15,5)  =  0.0
# x(15,6)  =  0.0
# x(15,7)  =  0.0
# x(15,8)  =  0.0
# x(15,9)  =  0.0
# x(16,0)  =  0.0
# x(16,1)  =  0.0
# x(16,10)  =  0.0
# x(16,11)  =  0.0
# x(16,12)  =  0.0
# x(16,13)  =  0.0
# x(16,14)  =  0.0
# x(16,15)  =  0.0
# x(16,16)  =  0.0
# x(16,2)  =  0.0
# x(16,3)  =  0.0
# x(16,4)  =  0.0
# x(16,5)  =  0.0
# x(16,6)  =  0.0
# x(16,7)  =  0.0
# x(16,8)  =  0.0
# x(16,9)  =  0.0
# x(2,0)  =  0.0
# x(2,1)  =  0.0
# x(2,10)  =  0.0
# x(2,11)  =  0.0
# x(2,12)  =  0.0
# x(2,13)  =  0.0
# x(2,14)  =  0.0
# x(2,15)  =  0.0
# x(2,16)  =  1.0
# x(2,2)  =  0.0
# x(2,3)  =  0.0
# x(2,4)  =  0.0
# x(2,5)  =  0.0
# x(2,6)  =  0.0
# x(2,7)  =  0.0
# x(2,8)  =  0.0
# x(2,9)  =  0.0
# x(3,0)  =  0.0
# x(3,1)  =  0.0
# x(3,10)  =  0.0
# x(3,11)  =  0.0
# x(3,12)  =  0.0
# x(3,13)  =  0.0
# x(3,14)  =  0.0
# x(3,15)  =  0.0
# x(3,16)  =  0.0
# x(3,2)  =  0.0
# x(3,3)  =  0.0
# x(3,4)  =  0.0
# x(3,5)  =  0.0
# x(3,6)  =  0.0
# x(3,7)  =  0.0
# x(3,8)  =  0.0
# x(3,9)  =  1.0
# x(4,0)  =  0.0
# x(4,1)  =  0.0
# x(4,10)  =  0.0
# x(4,11)  =  0.0
# x(4,12)  =  0.0
# x(4,13)  =  0.0
# x(4,14)  =  0.0
# x(4,15)  =  0.0
# x(4,16)  =  1.0
# x(4,2)  =  0.0
# x(4,3)  =  0.0
# x(4,4)  =  0.0
# x(4,5)  =  0.0
# x(4,6)  =  0.0
# x(4,7)  =  0.0
# x(4,8)  =  0.0
# x(4,9)  =  0.0
# x(5,0)  =  0.0
# x(5,1)  =  0.0
# x(5,10)  =  0.0
# x(5,11)  =  0.0
# x(5,12)  =  0.0
# x(5,13)  =  0.0
# x(5,14)  =  0.0
# x(5,15)  =  0.0
# x(5,16)  =  1.0
# x(5,2)  =  0.0
# x(5,3)  =  0.0
# x(5,4)  =  0.0
# x(5,5)  =  0.0
# x(5,6)  =  0.0
# x(5,7)  =  0.0
# x(5,8)  =  0.0
# x(5,9)  =  0.0
# x(6,0)  =  0.0
# x(6,1)  =  0.0
# x(6,10)  =  0.0
# x(6,11)  =  0.0
# x(6,12)  =  0.0
# x(6,13)  =  0.0
# x(6,14)  =  0.0
# x(6,15)  =  0.0
# x(6,16)  =  1.0
# x(6,2)  =  0.0
# x(6,3)  =  0.0
# x(6,4)  =  0.0
# x(6,5)  =  0.0
# x(6,6)  =  0.0
# x(6,7)  =  0.0
# x(6,8)  =  0.0
# x(6,9)  =  0.0
# x(7,0)  =  0.0
# x(7,1)  =  0.0
# x(7,10)  =  0.0
# x(7,11)  =  0.0
# x(7,12)  =  0.0
# x(7,13)  =  0.0
# x(7,14)  =  0.0
# x(7,15)  =  0.0
# x(7,16)  =  1.0
# x(7,2)  =  0.0
# x(7,3)  =  0.0
# x(7,4)  =  0.0
# x(7,5)  =  0.0
# x(7,6)  =  0.0
# x(7,7)  =  0.0
# x(7,8)  =  0.0
# x(7,9)  =  0.0
# x(8,0)  =  0.0
# x(8,1)  =  0.0
# x(8,10)  =  0.0
# x(8,11)  =  0.0
# x(8,12)  =  0.0
# x(8,13)  =  0.0
# x(8,14)  =  0.0
# x(8,15)  =  0.0
# x(8,16)  =  1.0
# x(8,2)  =  0.0
# x(8,3)  =  0.0
# x(8,4)  =  0.0
# x(8,5)  =  0.0
# x(8,6)  =  0.0
# x(8,7)  =  0.0
# x(8,8)  =  0.0
# x(8,9)  =  0.0
# x(9,0)  =  0.0
# x(9,1)  =  0.0
# x(9,10)  =  0.0
# x(9,11)  =  0.0
# x(9,12)  =  0.0
# x(9,13)  =  0.0
# x(9,14)  =  0.0
# x(9,15)  =  0.0
# x(9,16)  =  0.0
# x(9,2)  =  0.0
# x(9,3)  =  0.0
# x(9,4)  =  0.0
# x(9,5)  =  1.0
# x(9,6)  =  0.0
# x(9,7)  =  0.0
# x(9,8)  =  0.0
# x(9,9)  =  0.0
# y0  =  0.0
# y1  =  19.0
# y10  =  8.0
# y11  =  7.0
# y12  =  22.0
# y13  =  6.0
# y14  =  19.0
# y15  =  35.0
# y16  =  35.0
# y2  =  30.0
# y3  =  16.0
# y4  =  35.0
# y5  =  35.0
# y6  =  31.0
# y7  =  35.0
# y8  =  35.0
# y9  =  24.0
